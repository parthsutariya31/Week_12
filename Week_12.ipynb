# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import re
import nltk

nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# Now, Procedure of Train_data

# %%
train_data = pd.read_csv('train_data.csv')
train_data
# Out:
#           id  label                                              tweet
# 0          1      0   @user when a father is dysfunctional and is s...
# 1          2      0  @user @user thanks for #lyft credit i can't us...
# 2          3      0                                bihday your majesty
# 3          4      0  #model   i love u take with u all the time in ...
# 4          5      0             factsguide: society now    #motivation
# ...      ...    ...                                                ...
# 31957  31958      0  ate @user isz that youuu?ðððððð...
# 31958  31959      0    to see nina turner on the airwaves trying to...
# 31959  31960      0  listening to sad songs on a monday morning otw...
# 31960  31961      1  @user #sikh #temple vandalised in in #calgary,...
# 31961  31962      0                   thank you @user for you follow
#
# [31962 rows x 3 columns]

# %%
train_data.isnull().sum()
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %% [markdown]
# From above output we can say there is not NA values in Train_Data too.

# %%
X_train = train_data.iloc[:,:]
X_train
# Out:
#           id  label                                              tweet
# 0          1      0   @user when a father is dysfunctional and is s...
# 1          2      0  @user @user thanks for #lyft credit i can't us...
# 2          3      0                                bihday your majesty
# 3          4      0  #model   i love u take with u all the time in ...
# 4          5      0             factsguide: society now    #motivation
# ...      ...    ...                                                ...
# 31957  31958      0  ate @user isz that youuu?ðððððð...
# 31958  31959      0    to see nina turner on the airwaves trying to...
# 31959  31960      0  listening to sad songs on a monday morning otw...
# 31960  31961      1  @user #sikh #temple vandalised in in #calgary,...
# 31961  31962      0                   thank you @user for you follow
#
# [31962 rows x 3 columns]

# %%
corpus = []
for tweet in X_train['tweet']:
        tokens = re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?', ' ',tweet)
        tokens = tokens.lower()
        tokens = tokens.split()
        ps = PorterStemmer()
        all_words = stopwords.words('english')
        tokens = [ps.stem(words) for words in tokens if not words in set(all_words)]
        tokens_1 = ' '.join(tokens)
        corpus.append(tokens_1)

# %%
X_train['corpus'] = corpus

# %%
X_train = X_train.drop('tweet',axis = 1)

# %%
X_train = X_train.rename(columns ={'corpus':'tweet'})
X_train
# Out:
#           id  label                                              tweet
# 0          1      0      father dysfunct selfish drag kid dysfunct run
# 1          2      0  thank lyft credit use caus offer wheelchair va...
# 2          3      0                                     bihday majesti
# 3          4      0                        model love u take u time ur
# 4          5      0                            factsguid societi motiv
# ...      ...    ...                                                ...
# 31957  31958      0                                      ate isz youuu
# 31958  31959      0  see nina turner airwav tri wrap mantl genuin h...
# 31959  31960      0           listen sad song monday morn otw work sad
# 31960  31961      1        sikh templ vandalis calgari wso condemn act
# 31961  31962      0                                       thank follow
#
# [31962 rows x 3 columns]

# %% [markdown]
# Test Data Procedure

# %%
test_data = pd.read_csv('test_data.csv')
test_data
# Out:
#           id                                              tweet
# 0      31963  #studiolife #aislife #requires #passion #dedic...
# 1      31964   @user #white #supremacists want everyone to s...
# 2      31965  safe ways to heal your #acne!!    #altwaystohe...
# 3      31966  is the hp and the cursed child book up for res...
# 4      31967    3rd #bihday to my amazing, hilarious #nephew...
# ...      ...                                                ...
# 17192  49155  thought factory: left-right polarisation! #tru...
# 17193  49156  feeling like a mermaid ð #hairflip #neverre...
# 17194  49157  #hillary #campaigned today in #ohio((omg)) &am...
# 17195  49158  happy, at work conference: right mindset leads...
# 17196  49159  my   song "so glad" free download!  #shoegaze ...
#
# [17197 rows x 2 columns]

# %%
test_data.isnull().sum()
# Out:
# id       0
# tweet    0
# dtype: int64

# %% [markdown]
# From here we can say there is not null value in Test_data

# %%
X_test = test_data.iloc[:,:]
X_test
# Out:
#           id                                              tweet
# 0      31963  #studiolife #aislife #requires #passion #dedic...
# 1      31964   @user #white #supremacists want everyone to s...
# 2      31965  safe ways to heal your #acne!!    #altwaystohe...
# 3      31966  is the hp and the cursed child book up for res...
# 4      31967    3rd #bihday to my amazing, hilarious #nephew...
# ...      ...                                                ...
# 17192  49155  thought factory: left-right polarisation! #tru...
# 17193  49156  feeling like a mermaid ð #hairflip #neverre...
# 17194  49157  #hillary #campaigned today in #ohio((omg)) &am...
# 17195  49158  happy, at work conference: right mindset leads...
# 17196  49159  my   song "so glad" free download!  #shoegaze ...
#
# [17197 rows x 2 columns]

# %% [markdown]
# Cleaning of Test deta.. Removing special character using NLTK and RE

# %%
corpus_test = []
for tweet in X_test['tweet']:
        tokens = re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?', ' ',tweet)
        tokens = tokens.lower()
        tokens = tokens.split()
        ps = PorterStemmer()
        all_words = stopwords.words('english')
        tokens = [ps.stem(words) for words in tokens if not words in set(all_words)]
        tokens = ' '.join(tokens)
        corpus_test.append(tokens)

# %%
X_test['corpus'] = corpus_test
X_test = X_test.drop('tweet',axis = 1)
X_test = X_test.rename(columns ={'corpus':'tweet'})
X_test
# Out:
#           id                                              tweet
# 0      31963  studiolif aislif requir passion dedic willpow ...
# 1      31964   white supremacist want everyon see new bird movi
# 2      31965          safe way heal acn altwaystoh healthi heal
# 3      31966  hp curs child book reserv alreadi ye harrypott...
# 4      31967  3rd bihday amaz hilari nephew eli ahmir uncl d...
# ...      ...                                                ...
# 17192  49155  thought factori left right polaris trump usele...
# 17193  49156  feel like mermaid hairflip neverreadi formal w...
# 17194  49157  hillari campaign today ohio omg amp use word l...
# 17195  49158  happi work confer right mindset lead cultur de...
# 17196  49159     song glad free download shoegaz newmus newsong
#
# [17197 rows x 2 columns]

# %% [markdown]
# Here, We get Final_test data as X_test

# %% [markdown]
# There us no need to find Outliers....

# %% [markdown]
# Till here, We have done Date Cleansing and Transformation.

# %% [markdown]
# #EDA

# %%
#For_Train_Data
from collections import Counter
occurrences= Counter(X_train['tweet'])
occurrences.most_common()
# Out:
# [('model love u take u time ur', 325),
#  ('final found way delet old tweet might find use well deletetweet', 83),
#  ('aww yeah good bing bong bing bong', 75),
#  ('might libtard libtard sjw liber polit', 72),
#  ('grate affirm', 57),
#  ('love instagood photooftheday top tag tbt cute beauti followm follow', 36),
#  ('happi work confer right mindset lead cultur develop organ work mindset',
#   35),
#  ('father day', 32),
#  ('lighttherapi help depress altwaystoh healthi happi', 31),
#  ('', 31),
#  ('lover stop angri visit us gt gt gt lover friend astrolog love', 26),
#  ('best essentialoil anxieti healthi peac altwaystoh', 26),
#  ('sikh templ vandalis calgari wso condemn act', 26),
#  ('lighttherapi help sad depress altwaystoh healthi', 24),
#  ('black amp feel like stomp listen retweet tampa miami', 23),
#  ('flagday2016 flag day 2016 30 photo buy thing flag day 2016', 22),
#  ('get get get enjoy music today free app free music', 21),
#  ('feminismiscanc feminismisterror feminismmuktbharat malevot ignor', 20),
#  ('sea shepherd suppoer racist antirac seashepherd', 17),
#  ('save login x broker chang meme love educ univers', 17),
#  ('magnettherapi realli work altwaystoh heal healthi', 15),
#  ('detoxdiet altwaystoh healthi', 15),
#  ('safe way heal acn altwaystoh healthi heal', 14),
#  ('best lawofattract resourc heal altwaystoh healthi idwp', 14),
#  ('music therapi tool heal altwaystoh healthi', 14),
#  ('best essenti oil heal altwaystoh healthi', 14),
#  ('tgif ff gamedev indiedev indiegamedev squad', 13),
#  ('herbal sleep remedi work altwaystoh healthi heal', 13),
#  ('look feel joy join 20 speaker free summit unleashyourjoy', 13),
#  ('love instagood photooftheday top tag tbt cute beauti followm', 13),
#  ('stuck rat race find freedom masterkeyexperi', 12),
#  ('wed impoant celebr life possibl ann hathaway wed love', 12),
#  ('make', 12),
#  ('raw food diet benefit altwaystoh healthi heal peac joy love', 12),
#  ('lawofattract heal altwaystoh healthi', 12),
#  ('peopl protest trump republican trump fuher amp', 11),
#  ('saysometh bull domin bull direct whatev want', 11),
#  ('bihday', 11),
#  ('atherapi musictherapi heal life altwaystoh healthi heal', 11),
#  ('photo accept amp sale photographi', 11),
#  ('happi day altwaystoh healthi', 11),
#  ('love abrahamhick lawofattract healthi heal joytrain', 10),
#  ('watch weddingplan peopl', 10),
#  ('bird amp bad piggi finger famili nurseri rhyme lyric via', 10),
#  ('food heal bodi doplant healthi', 10),
#  ('love', 10),
#  ('use power mind heal bodi altwaystoh healthi peac', 9),
#  ('dreamcatch bull domin bull direct whatev want', 9),
#  ('lawofattract heal loa healthi well idwp', 9),
#  ('amp grate money come increas quantiti multipl sourc continu basi', 9),
#  ('hispan amp feel like stomp listen retweet boricua', 9),
#  ('herbalremedi anxieti work altwaystoh healthi heal peac', 9),
#  ('7 impoant thing allow child', 9),
#  ('luv hottweet like venusexchang', 8),
#  ('100 amaz health benefit cucumb healthi altwaystoh', 8),
#  ('thank thank posit', 8),
#  ('payintheusa polar bear climb race angri polar bear climb race polar bear live cold place',
#   8),
#  ('use power mind heal bodi altwaystoh healthi', 8),
#  ('save thousand free search x login x broker actor seeklearn stafresh', 8),
#  ('tattoosleev gorilla simul need adapt environ need tear citi', 8),
#  ('today perfect day happi lifecoach reinventimposs', 8),
#  ('life make let make motiv', 8),
#  ('teen girl kill 3 other injur downtown oakland shoot gun mentalil gang orlando',
#   8),
#  ('make overweight dog dog health problem', 8),
#  ('thank love thank posit', 8),
#  ('snow white gt open gt sleepi sneezi bash dm us today', 8),
#  ('olath polar bear climb race angri polar bear climb race polar bear live cold place looki',
#   8),
#  ('germanyhetalia bull domin bull direct whatev want wh', 8),
#  ('food heal bodi altwaystoh healthi', 8),
#  ('happi work c onfer right mindset lead cultur develop organ work mindset',
#   8),
#  ('fathersday gift proud dad avail 1 day', 8),
#  ('makeuptransform rooster simul want climb vast expans mountain reach le', 8),
#  ('bihday rg', 8),
#  ('seek probe udtapunjab leak point finger amarind aap', 7),
#  ('best homeopath remedi anxieti altwaystoh heal peac', 7),
#  ('buffalo bull domin bull direct whatev want', 7),
#  ('thank vacat day thank posit', 7),
#  ('lightroom bull domin bull direct whatev want yo', 7),
#  ('instagram come join myhappycaptur blogger', 7),
#  ('damn realli made tear littl mustread', 7),
#  ('altwaystoh healthi peac think altern idwp', 7),
#  ('augusta buffalo simul buffalo take vicin home way yo', 7),
#  ('glamor posit affirm', 7),
#  ('weekend', 7),
#  ('anyon els notic suppoer pageant girl year intern femal oppress system', 7),
#  ('electron music bogota colombia puntohost cedm edm dj fashion music', 7),
#  ('thank coffe thank posit', 7),
#  ('vehicl gorilla simul need adapt environ need tear citi materia', 7),
#  ('fallschurch gorilla simul need adapt environ need tear citi mat', 7),
#  ('fitnessaddict attack bull chase leav lot despit fact strong sourc', 7),
#  ('grow old along best yet robe brown wed love', 7),
#  ('newstar bull domin bull direct whatev want', 7),
#  ('angel archangel high help live spiritu anf live', 7),
#  ('healthandfit attack bull game 3d realli think head empti around citi', 7),
#  ('thank imagin thank posit', 7),
#  ('thank sunshin thank posit', 6),
#  ('thank good night sleep thank posit', 6),
#  ('want creativ worker give enough time play success quot', 6),
#  ('find make school place educationfest', 6),
#  ('success order', 6),
#  ('team new mc amp show phillysuppophilli amp combat', 6),
#  ('gameshow bull hill climb reach target complet task surviv strong excit', 6),
#  ('terrif posit affirm', 6),
#  ('thrive posit affirm', 6),
#  ('instaaoftheday buffalo simul buffalo take vicin home thi', 6),
#  ('jacksonvil rooster simul want climb vast expans mountain reach leakag co',
#   6),
#  ('arianagrandedraw attack bull game 3d realli think head empti around citi eac',
#   6),
#  ('introduct happi day day', 6),
#  ('best essentialoil weightloss altwaystoh healthi', 6),
#  ('winterfashion bull domin bull direct whatev want whe', 6),
#  ('noth would danger give putinschoic impress accept stoprac boycott', 6),
#  ('igersbnw attack bull game 3d realli think head empti around citi side', 6),
#  ('memori rome end yummi cooki pleas amp click recip', 6),
#  ('nice posit affirm', 6),
#  ('thank knowledg thank posit', 6),
#  ('optimist posit affirm', 6),
#  ('arkansa gorilla simul need adapt environ need tear citi materi', 6),
#  ('thank home thank posit', 6),
#  ('samsunggalaxys2 rooster simul want climb vast expans mountain reach leakag',
#   6),
#  ('film bull domin bull direct whatev want sta', 6),
#  ('100 amaz health benefit cucumb healthi doplant', 6),
#  ('highest happi eah happi marriag william lyon phelp wed love', 6),
#  ('cotd polar bear climb race angri polar bear climb race polar bear live cold place look',
#   5),
#  ('creativ posit affirm', 5),
#  ('brilliant posit affirm', 5),
#  ('truth posit affirm', 5),
#  ('black amp feel like stomp retweet tampa miami', 5),
#  ('thank friend thank posit', 5),
#  ('move posit affirm', 5),
#  ('natur perfect bull hill climb reach target complet task surviv str', 5),
#  ('drakeandjosh buffalo simul buffalo take vicin home wa', 5),
#  ('decor buffalo simul buffalo take vicin home way', 5),
#  ('awesom beginn gopro mount super use', 5),
#  ('intellig posit affirm', 5),
#  ('kejriw must accept role make udtapunjab conspiraci defam punjab', 5),
#  ('playinggam buffalo simul buffalo take vicin home wa', 5),
#  ('thank freedom thank posit', 5),
#  ('toptag day top tag day smile fun instahappi goodmood sohappi', 5),
#  ('peppa pig bird finger famili nurseri rhyme lyric via', 5),
#  ('60 power minut free podcast anxieti stress life success nowplay', 5),
#  ('smilepowerday show us best cheesi grin pearli white smile teeth', 5),
#  ('thank spring thank posit', 5),
#  ('wholesom posit affirm', 5),
#  ('tag someon quot beauti beach lifestyl blue instas f4f fashion', 5),
#  ('heal lawofattract loa altwaystoh healthi well', 5),
#  ('end day gotta', 5),
#  ('natur posit affirm', 5),
#  ('childhood bull domin bull direct whatev want yo', 5),
#  ('bestsel inspir golf never go bed without dream wakeup without hope', 5),
#  ('petal polar bear climb race angri polar bear climb race polar bear live cold place lookin',
#   5),
#  ('thank best friend thank posit', 5),
#  ('ink polar bear climb race angri polar bear climb race polar bear live cold place lookin',
#   5),
#  ('genuin posit affirm', 5),
#  ('straight chaser music video', 5),
#  ('thank famili vacat thank posit', 5),
#  ('thank summer thank posit', 5),
#  ('flowerlov bull domin bull direct whatev want', 5),
#  ('garden wisdom wisdom saturdaymorn flower saterday vine vine', 5),
#  ('brave posit affirm', 5),
#  ('thank forgiv thank posit', 5),
#  ('marathon bull domin bull direct whatev want', 5),
#  ('haford buffalo simul buffalo take vicin home way', 5),
#  ('thank health thank posit', 5),
#  ('joy posit affirm', 5),
#  ('parent bull domin bull direct whatev want', 5),
#  ('fo attack bull chase leav lot despit fact strong sourc food f', 5),
#  ('medit gorilla simul need adapt environ need tear citi mate', 5),
#  ('cedarrapid bull domin bull direct whatev want', 5),
#  ('thank smile thank posit', 5),
#  ('studio attack bull game 3d realli think head empti around citi side sup',
#   5),
#  ('pleas like amp share agre dna dnaquot quot quoteoftheday love proverb lifestyl',
#   5),
#  ('grace posit affirm', 5),
#  ('facebook attack bull chase leav lot despit fact strong sourc fo', 5),
#  ('respect posit affirm', 5),
#  ('justinb gorilla simul need adapt environ need tear citi materia', 5),
#  ('smile smile top tag toptag smile beautifulsmil smiley smile pretti', 5),
#  ('fathersday look someth see trend commun', 5),
#  ('get post seen make other happi come join nowlinkup blogger via', 5),
#  ('likescam bull hill climb reach target complet task surviv strong excit', 5),
#  ('enchant posit affirm', 5),
#  ('founat posit affirm', 5),
#  ('beachbodi bull domin bull direct whatev want yo', 5),
#  ('vivaci posit affirm', 5),
#  ('warn rahulgandhi play polit udtapunjab', 5),
#  ('grow posit affirm', 5),
#  ('thank paner thank posit', 4),
#  ('taylorswift1989 bull domin bull direct whatev want w', 4),
#  ('thank cat thank posit', 4),
#  ('twinklatinboy na slut snapshot hot nasti naughti sexi horni shi porn nude kinki xxx',
#   4),
#  ('thank saturday thank posit', 4),
#  ('stephcurri outburst beg question christian get nbafin', 4),
#  ('impress posit affirm', 4),
#  ('smaphon bull domin bull direct whatev want', 4),
#  ('knowledg posit affirm', 4),
#  ('great insight trust profess emea growth hack confer growthwithhubspot', 4),
#  ('sukhbir badal announc offic bearer eastcoast zone canada', 4),
#  ('quot day bless thank optimist posit faith strong motiv', 4),
#  ('today donkey zionazi proud murder real palestinian semit children that call',
#   4),
#  ('alway', 4),
#  ('bestsel inspir motiv never go bed without dream wakeup without hope', 4),
#  ('wait', 4),
#  ('sad', 4),
#  ('thank abl learn thank posit', 4),
#  ('nation best friend day', 4),
#  ('cloudchas bull hill climb reach target complet task surviv strong ex', 4),
#  ('reassur posit affirm', 4),
#  ('hispan amp like stomp listen retweet boricua miami', 4),
#  ('thank good hug thank posit', 4),
#  ('know anyon need shop wonder could purchas gift card funni humor', 4),
#  ('life come around whatev make', 4),
#  ('present moment fill joy happi thinkbigsundaywithmarsha', 4),
#  ('thank apolog thank posit', 4),
#  ('readi posit affirm', 4),
#  ('bjp govt transform punjab say sukhbir jaitley list achiev nda', 4),
#  ('springfield bull domin bull direct whatev want', 4),
#  ('toptweet like one venusexchang', 4),
#  ('peppa pig bird lollipop finger famili nurseri rhyme lyric via', 4),
#  ('friendli posit affirm', 4),
#  ('cute posit affirm', 4),
#  ('thank', 4),
#  ('flourish posit affirm', 4),
#  ('safe posit affirm', 4),
#  ('thank get encourag thank posit', 4),
#  ('blackheathstandard summerfair', 4),
#  ('smile dog dogsarejoy', 4),
#  ('man come last race declar winner putinschoic putinspuppet retweet', 4),
#  ('aap congress hell bent vitiat commun harmoni punjab bjp leader', 4),
#  ('happi marriag union two good forgiv robe quillen wed love', 4),
#  ('visit gorilla simul need adapt environ need tear citi materi', 4),
#  ('sunday', 4),
#  ('posit posit affirm', 4),
#  ('end 2016 hope messag music industri via', 4),
#  ('thank sens touch thank posit', 4),
#  ('lessismor polar bear climb race angri polar bear climb race polar bear live cold place l',
#   4),
#  ('thank hope thank posit', 4),
#  ('thank new place thank posit', 4),
#  ('thank inspir thank posit', 4),
#  ('posit affirm', 4),
#  ('fathersday father day god toni smith buy thing happ', 4),
#  ('watch angri grandpa react gift new hous video grandpa hous', 4),
#  ('black amp feel like listen retweet tampa miami newyork', 4),
#  ('wed teaser amp c photographi wed photographi bride groom moment', 4),
#  ('thank abl rememb thank posit', 4),
#  ('hispan amp feel like listen retweet boricua miami', 4),
#  ('want increas level hormon', 4),
#  ('angri squeak frog video frog natur anim cute ador', 4),
#  ('macbook gorilla simul need adapt environ need tear citi materia', 4),
#  ('watch udtapunjab know realiti bhagwantmann ghuggi tell bjp', 4),
#  ('sirf ashiq log follow karen iqbal galib wasi faraz mohsin ki full poetri add follow send 4o4o4',
#   4),
#  ('thank happi thank posit', 4),
#  ('bestsel motiv spo never go bed without dream wakeup without hope', 4),
#  ('good morn nice day happi fast fast fashionillustr', 4),
#  ('thank farmer farmer market thank posit', 4),
#  ('secret marriag famili', 4),
#  ('thank much follow pleas read flightofalifetim glad smile', 4),
#  ('thank rain thank posit', 4),
#  ('true', 4),
#  ('thank sens tast thank posit', 4),
#  ('thank sunset thank posit', 4),
#  ('adventur posit affirm', 4),
#  ('thank peac thank posit', 4),
#  ('quoteoftheday bull domin bull direct whatev want whe', 4),
#  ('thank tear thank posit', 4),
#  ('thank school thank posit', 4),
#  ('boston buffalo simul buffalo take vicin home way', 4),
#  ('broken buffalo simul buffalo take vicin home way', 4),
#  ('bihday majesti', 3),
#  ('thank good friend thank posit', 3),
#  ('challeng aap claim 70 punjabi drugaddict dare prove', 3),
#  ('spirit posit affirm', 3),
#  ('legendari posit affirm', 3),
#  ('thank hike trail thank posit', 3),
#  ('thank challeng thank posit', 3),
#  ('end', 3),
#  ('oscar tabarez talk lui suarez angri reaction spo lui oscar', 3),
#  ('thank memori thank posit', 3),
#  ('thank freezer thank posit', 3),
#  ('fathersday father day dad skinni singl buy thing h', 3),
#  ('sunday hug', 3),
#  ('bride woman fine prospect happi behind ambros bierc wed love', 3),
#  ('video get excit futur tech augment futur mobil', 3),
#  ('secur posit affirm', 3),
#  ('father day love u papa', 3),
#  ('ha ppi work confer right mindset lead cultur develop organ work mindset',
#   3),
#  ('thank comfo thank posit', 3),
#  ('calm posit affirm', 3),
#  ('young stop worri', 3),
#  ('honest posit affirm', 3),
#  ('love instagood follow photooftheday tagsforlik beauti selfi g', 3),
#  ('thank honest convers thank posit', 3),
#  ('thank bed thank posit', 3),
#  ('someth make happi 5 second retrain brain happi', 3),
#  ('green bull hill climb reach target complet task surviv strong excitem', 3),
#  ('dust piano gummi beatz beat', 3),
#  ('get easili risk help health let neg emot get best health', 3),
#  ('victori posit affirm', 3),
#  ('thrill posit affirm', 3),
#  ('ok posit affirm', 3),
#  ('happi wor k confer right mindset lead cultur develop organ work mindset',
#   3),
#  ('thank holiday sale thank posit', 3),
#  ('thank passion thank posit', 3),
#  ('multipl type racism america us america', 3),
#  ('happi wo rk confer right mindset lead cultur develop organ work mindset',
#   3),
#  ('take time make soul happi owlashop via quot giftidea', 3),
#  ('dog kind way say worri dogsarejoy', 3),
#  ('surpris read make gt gt gt betray ka lt lt lt scifi kindleunlimit', 3),
#  ('bihday good day puppi anim cute funni special day special', 3),
#  ('one 64 2 mil american reject bigotri amp hatr fli flag half mast jan', 3),
#  ('mother take care ten children sometim ten children take care mother', 3),
#  ('good stuff multivitamin weekend 06 11 16', 3),
#  ('beauti posit affirm', 3),
#  ('whiski connoisseur kit fathersday whiski', 3),
#  ('engag posit affirm', 3),
#  ('thank good health thank posit', 3),
#  ('thank time thank posit', 3),
#  ('send trump inaugur join today', 3),
#  ('3 key found comput enjoy life inspir advic', 3),
#  ('thank therapi thank posit', 3),
#  ('popular posit affirm', 3),
#  ('enough 2 say notmypr wtf2016 neverump unpresid bigot', 3),
#  ('mountain rooster simul want climb vast expans mountain reach leakag cock',
#   3),
#  ('harmoni posit affirm', 3),
#  ('wow posit affirm', 3),
#  ('sad dukhi shairi urdu shairi love poetri gazal nice poetri daili free poetri dosti msg plz 1 tri follow snd 40404',
#   3),
#  ('unwav posit affirm', 3),
#  ('ecstat posit affirm', 3),
#  ('thank laughter thank posit', 3),
#  ('miss much', 3),
#  ('remark posit affirm', 3),
#  ('hispan feel like stomp listen retweet boricua', 3),
#  ('sunni posit affirm', 3),
#  ('holiday fun social relev podcast celebr 70 bewitch xma ep', 3),
#  ('join trump melania way', 3),
#  ('alt right promot new kind genet mt', 3),
#  ('6pc happi smile kitti cat home butto 6pc smile kitti', 3),
#  ('punjab govt bjp noth udtapunjab row vineet joshi', 3),
#  ('stop look reason unhappi think reason instead', 3),
#  ('pleas kind like page thank celebrain', 3),
#  ('success posit affirm', 3),
#  ('charm posit affirm', 3),
#  ('photographi attack bull game 3d realli think head empti around citi side',
#   3),
#  ('thank much', 3),
#  ('acquaint punjabi cultur kejriw tri lure punjabi', 3),
#  ('well said', 3),
#  ('late ff gamedev indiedev indiegamedev squad', 3),
#  ('thank puppi thank posit', 3),
#  ('thank flip flop thank posit', 3),
#  ('allahsoil like religion islam strong unifi forc teambt', 3),
#  ('attract posit affirm', 3),
#  ('courag posit affirm', 3),
#  ('zaynmalik bull domin bull direct whatev want yo', 3),
#  ('preorder live 99c 99p swiftli sharpen fang dystopian tale', 3),
#  ('book endur convict fred korematsu amp quest justic humanright ht', 3),
#  ('still', 3),
#  ('trainhard polar bear climb race angri polar bear climb race polar bear live cold place lo',
#   3),
#  ('thank internet connect thank posit', 3),
#  ('feel bodi huge affect', 3),
#  ('ase bull domin bull direct whatev want', 3),
#  ('good luck', 3),
#  ('remov aap spokesperson alkalamba showcas dictatori mindset kejriw', 3),
#  ('emtec angri bird 4 gb usb 2 0 flash dri emtec bird 4 gb u', 3),
#  ('hi friend lokiday', 3),
#  ('rainbowrowel bull domin bull direct whatev want whe', 3),
#  ('retweet sweeti bbw curvi bbw big ass pussi sex sexi thick bbwlover kik vip retweet',
#   3),
#  ('sta laugh cri make sad laugh cri distress anxiou chang mindset depress', 3),
#  ('rss xactaccount tinyplanet love picoftheday beauti cute tinyplanetbuf', 3),
#  ('thank grandpar thank posit', 3),
#  ('allahsoil cold war fought oil teambt teamsuperjunior', 3),
#  ('overcom loneli mind medit happi medit', 3),
#  ('compos posit affirm', 3),
#  ('anim cat cat grumpi cat happi camper treat play', 3),
#  ('lucki posit affirm', 3),
#  ('bestsel motiv never go bed without dream wakeup without hope', 3),
#  ('plz sign japan bulli tweet4taiji', 3),
#  ('independ posit affirm', 3),
#  ('love instagood photooftheday tbt cute beauti followm follow fashion selfi',
#   3),
#  ('thank moon star thank posit', 3),
#  ('happi happi selfrespect respect life lifehack love diy blog blogger', 3),
#  ('thank music thank posit', 3),
#  ('thank countri thank posit', 3),
#  ('thank fun thank posit', 3),
#  ('h appi work confer right mindset lead cultur develop organ work mindset',
#   3),
#  ('peopl origin meant white landhold male 2016in4word', 3),
#  ('thank kind stranger thank posit', 3),
#  ('happi work confer rig ht mindset lead cultur develop organ work mindset',
#   3),
#  ('nuur posit affirm', 3),
#  ('thank cloth thank posit', 3),
#  ('thank warm run water thank posit', 3),
#  ('marvel posit affirm', 3),
#  ('comic make smile laugh', 3),
#  ('end selfi love messi cr7 religion christian mecca live', 3),
#  ('thank internet thank posit', 3),
#  ('give posit affirm', 3),
#  ('make morn coffe sunni pineappl sunshin starbuck wakeup shine', 3),
#  ('huaweiceifiedspecialist pre sale accessnetwork deliv ye stress sno', 3),
#  ('thank dream thank posit', 3),
#  ('carmineryderrr na xxx horni young sexi porn snapshot kinki wet hot slut naughti nude n',
#   3),
#  ('retweet nuascannan', 3),
#  ('sometim take smile smile via', 3),
#  ('lack sleep caus lack memori momtip', 3),
#  ('allahsoil term jihad highli contest concept teambt teamsuperjunior', 3),
#  ('pueorico environment injustic inflam protest coal ash ty', 3),
#  ('delight posit affirm', 3),
#  ('happ work confer right mindset lead cultur develop organ work mindset', 3),
#  ('jackblair na wet snapshot shi hot kinki horni naughti xxx nasti nude sexi porn slut young',
#   3),
#  ('1 week go', 3),
#  ('msnbc cnn amjoy joe biden want thank trump unmask america', 3),
#  ('pa 64 2 mil reject putinschoic boycott busi amp hatr must stopp', 3),
#  ('amp babi eli ontheredcarpet 4 r back 4 cousin 2 watch teletubbiesusa', 3),
#  ('massiv censorship', 3),
#  ('koala bear', 3),
#  ('5 tip wipe neg life success flourish', 3),
#  ('see', 3),
#  ('thank fall leav thank posit', 3),
#  ('cute', 3),
#  ('valu posit affirm', 3),
#  ('help kid cope feel ece classroom activ play', 3),
#  ('thank vaccin thank posit', 3),
#  ('thank friendship thank posit', 3),
#  ('thank emot thank posit', 3),
#  ('advanc valu chain video valuechain', 3),
#  ('bliss posit affirm', 3),
#  ('watch record excel shock repo', 3),
#  ('invent posit affirm', 3),
#  ('cnn call michigan middl school build wall chant tcot', 2),
#  ('life social network embrac day', 2),
#  ('amaz posit affirm', 2),
#  ('whenev im someth goe wrong', 2),
#  ('let scum baggeri begin', 2),
#  ('ascot time babe ascot fashion monochrom style instahappyday', 2),
#  ('white establish blk folx run around love promot great', 2),
#  ('good morn journey begin travel yeah thejourneybegin hello', 2),
#  ('much stuff happen florida first orlando shoot disneygatorattack two year old kid',
#   2),
#  ('greathonour careerconvo', 2),
#  ('altright use amp insecur lure men whitesupremaci', 2),
#  ('woohoo 5 week go', 2),
#  ('ye ye ye ihavenofriend someonecomewithm', 2),
#  ('get angri muslim assassin 50 much', 2),
#  ('nochebuena lasvega usa la vega strip', 2),
#  ('sad branch raini day write tear fli bird haiku 3line micropoetri', 2),
#  ('hbd dick suckin tequila lovin slut wouldnt want u way justalil butstillontim',
#   2),
#  ('happi 35th bihday shane robe watson bihday shane watson australia cricker',
#   2),
#  ('u think like god come god keep', 2),
#  ('ilovethesecret lawofattract quiz love happi motiv success joy life', 2),
#  ('thank enteain thank posit', 2),
#  ('eg smile smile egsmil torio', 2),
#  ('everi minut lose sixti second happi', 2),
#  ('happi pharrel william pharrellwilliam lyric', 2),
#  ('happi folk first freakshak launch freak yum dalston', 2),
#  ('huge crowd trump', 2),
#  ('die light villag green town antisemit hocoschool columbiamd hocomd', 2),
#  ('chill relax piano music keep pet quiet july4th firework', 2),
#  ('trump ny co chair make racist remark michel obama p2 p21 fyi tcot', 2),
#  ('fan make', 2),
#  ('back day job shane lowri', 2),
#  ('sister even know watch argu nigga wait say wrong shit', 2),
#  ('week sta kinda lame get better yay wednesdaywisdom', 2),
#  ('first bihday puppi elois sweetbabin dog growingup cute bihdaygirl', 2),
#  ('5 000 pig burn aliv saskatchewan barn fire video', 2),
#  ('never convinc american right bear prayfororlando guncontrol', 2),
#  ('wait go see warcraft ugh warcraft', 2),
#  ('happi happi minion', 2),
#  ('true nigga dont go look apament go look shoe jewelri', 2),
#  ('allahsoil familiar becom difficult stereotyp', 2),
#  ('yep grate everyday gratitud laurasworld', 2),
#  ('dental testimoni lichfield client', 2),
#  ('wish dad happi father day dad fathersday 2016 intellicr', 2),
#  ('happi father day dad except rogergoodel fathersday goodellsuck', 2),
#  ('nigger lifelesson white kid grew 60 blogpost whitepeopl respect', 2),
#  ('peopl use tragedi like fuel hate agenda toward entir group peopl opposit help',
#   2),
#  ('noth make dad happier tasti meal fathersday', 2),
#  ('monro amp nick best friend amp rosale amp addi kelli amp babymonrosal grimm famili nadalind',
#   2),
#  ('sirf ashiq log follow karen iqbal galib wasi faraz mohsin ki full poetri add follow',
#   2),
#  ('know go room one troubl soul draw blackandwhit', 2),
#  ('everytim wear soccer shi joie fri say look mexican fuck', 2),
#  ('even dear cuti', 2),
#  ('thank power social media aand', 2),
#  ('allahsoil vp got multi million dollar bonus averag american lost home', 2),
#  ('keep opposit endthen', 2),
#  ('latest positivementalattitud thank posit', 2),
#  ('simpl true becom capabl burnsurvivor dolbf motiv motiv', 2),
#  ('repeat put dog hot car leav heat keep home fuck sake dog', 2),
#  ('trumpusa call us homophob misogynist realli say jealou us w', 2),
#  ('congrat thoma new beauti home tehaleh welcom lennar famili homeown', 2),
#  ('msg hope newyear busi end endof2016 tedtalk tedatibm', 2),
#  ('gd morn gdragon gd kwonjiyong jiyong vip bigbang handsom cute love', 2),
#  ('current mood web develop meet amp hire 6 22', 2),
#  ('true home food consid cheap meal impress made restaur', 2),
#  ('live life', 2),
#  ('ngitingtagumpay', 2),
#  ('top crappi day w sign paper hous pop conc 4 block work amp know', 2),
#  ('omg bitch knew gone lil kim actual look like music video', 2),
#  ('forget research show sexist men psycholog problem tuckercarlson', 2),
#  ('view oregon poland usa unitedst holiday dj produc hous', 2),
#  ('fact keep watch make interest', 2),
#  ('snapchat barbiet 93 tranni ladyboy asianladyboy thailand usa lasvega', 2),
#  ('heal natur healthi idwp joytrain', 2),
#  ('make make smile laugh much breath love long', 2),
#  ('pizza tonight stream bout favorit pizza food gamer fun hungri', 2),
#  ('happi w ork confer right mindset lead cultur develop organ work mindset',
#   2),
#  ('defens deflect fact defens trump georg show true color neverump', 2),
#  ('alexmag like interest peopl new feel love ro porn young sexi shi nasti nu',
#   2),
#  ('pleas us notlongnow whatson familyfun', 2),
#  ('way cmtredcarpet tunein', 2),
#  ('disgrac poor kid alreadi tough life', 2),
#  ('stay tune saint issu 4 printer comic makecom', 2),
#  ('lot stuff confirm book open day detail finalis biggestev', 2),
#  ('repoer read lgbt card bbcnew orlando', 2),
#  ('costest burlesqu glinda made ski amp sleev love come cosplay handmad', 2),
#  ('tennesse look republican suppo', 2),
#  ('jaguar fpace come soon jaguarstb jaguarstellenbosch jaguarfpac', 2),
#  ('light power time test busi end build process digm', 2),
#  ('buffalo school district boot trump alli racist comment birdsofafeath resist',
#   2),
#  ('factsguid agre motiv', 2),
#  ('go negro far expens commut bc car', 2),
#  ('help littl peopl manag big emot feel disappoint', 2),
#  ('ultim joke earli 2016 wish tell also wish well', 2),
#  ('first perform went great imthestar', 2),
#  ('thank comput thank posit', 2),
#  ('thank independ thank posit', 2),
#  ('wish wonder friday friday citi nyc newyork interior design well health space',
#   2),
#  ('easili amus haha happi queen 20poundnot pound opticalillus iandrewmus', 2),
#  ('ootd wiwt metoday fwi fashion swag fring dayoff goodday love japan tokyo beauti',
#   2),
#  ('psa age inform true ethnic biblic peopl caus overlap', 2),
#  ('countdown 1 hour left till excit announc', 2),
#  ('allahsoil muslim hate america emirati 2016in4word', 2),
#  ('thank life challeng thank posit', 2),
#  ('anyon fli glasgow philadelphia poland 26th june campadam', 2),
#  ('take moonris next week second outing newbook', 2),
#  ('stumbl get back getbackup stumbl livefre loveoften befre behappi', 2),
#  ('love favourit item cloth comfi', 2),
#  ('paul beloy still issu vari level belgian footbal', 2),
#  ('super posit affirm', 2),
#  ('craziestpeopl motiv', 2),
#  ('easi like sunday morn zen abstract photographi ocean beach beliz peac', 2),
#  ('bullshit thrown muslim', 2),
#  ('spoiler good dinosaur thing fuck sad funni thegooddinosaur thefuck', 2),
#  ('way', 2),
#  ('follow hope well world', 2),
#  ('liber believ pay inclus believ equal anywher tra', 2),
#  ('spent bestfriendsday w bentley corgi move 2 n fl 2morro sad day', 2),
#  ('world extrem', 2),
#  ('relax katiequeu music life amaz guitar', 2),
#  ('excit line shop come soon vintagehour frenchvintag', 2),
#  ('thank pillow thank posit', 2),
#  ('helix bridg riclswtravelbook bearlovestravel trip travel singapor enjoy',
#   2),
#  ('that standard home minist', 2),
#  ('tom jerri icepol see someon feel better kid child awesom', 2),
#  ('malia shake ass fine pass blunt', 2),
#  ('lumin posit affirm', 2),
#  ('play naoyuki onda templ twilight music song', 2),
#  ('agre hrc popularvot w ca much way trump win w', 2),
#  ('hello inshot girl cute summer blur sun fun dog hair beach hot cool', 2),
#  ('morelov lesshat prayfororlando world come defint need', 2),
#  ('rationchalleng fundrais help educ syrianrefuge love face thankfulthursday',
#   2),
#  ('benidorm week sta new job hospit nh summer', 2),
#  ('first nodej expressj app live heroku', 2),
#  ('us lost wonder dad soon hard day almost fathersday', 2),
#  ('one favorit episod far spoke lt 3 determin heal share journey', 2),
#  ('serious lede come better', 2),
#  ('take chanc liber amp excit amp alway grow result livelovelif', 2),
#  ('allahsoil crusad west vs islam terror popular sequel capit vs commun', 2),
#  ('person got suspend impli women bring domest violenc dud', 2),
#  ('archiv relax spa day claric hous buri st edmund weekend ago sist calm', 2),
#  ('techjunkiejh daili show unpack blackwomen asianmen datingapp', 2),
#  ('feel proud determin gym gettingfitt gettingfit fit sprinttriatholon', 2),
#  ('travel canuck game sad disappoint oiler fan sad cheer team', 2),
#  ('board written alina readi tomorrow summer drink amp brand new menu', 2),
#  ('happi father day first equiti fund fathersday fathersday firstequ fund', 2),
#  ('detroit may stronger claim red wing tv revenu via cours kevyn orr comment',
#   2),
#  ('watermelon natur shot ibiza ibiza2016 lovelif beachday calatarida', 2),
#  ('thank hug thank posit', 2),
#  ('latest happi design daili thank staup', 2),
#  ('mep bear travel sandi hook 2013 hope anoth gun massacr would never occur',
#   2),
#  ('w ever ppl love rep pay need open ef newpap im republican waiting4trump',
#   2),
#  ('long england v wale match team fish get spirit thing euro2016', 2),
#  ('love flagday semperfi', 2),
#  ('emo americanfootbal minion kinsella', 2),
#  ('fun posit affirm', 2),
#  ('wait dark first film moviegeek edfilmfest', 2),
#  ('politician yell job actual grow proud today good day', 2),
#  ('good dad irreplac live children fathersday dad', 2),
#  ('bihday rajkuamar sir great success ahead', 2),
#  ('offici 1 month 1 day without see comehom', 2),
#  ('smile dog make dogfriend', 2),
#  ('happi bihday brother man need mixtap like need boo good one sach', 2),
#  ('drunk cb lion club yyt nfld', 2),
#  ('opi gorilla simul need adapt environ need tear citi materi da', 2),
#  ('lot strawberri appear garden morn homegrown strawberri', 2),
#  ('visit power happi websit thepowerofhappi behappi', 2),
#  ('sad wav suga kpop bt bangtanboy edit fmv minyoongi yoongi babe cute au', 2),
#  ('readi great day train mccormick today look chang manag', 2),
#  ('donkey zionazi proud murder real palestinian semit children that call antisemt',
#   2),
#  ('precis opendata book club', 2),
#  ('wealthi posit affirm', 2),
#  ('ludicr 2think happen especi come far taken 2leap backward', 2),
#  ('get prep deleg arriv smaccdub smaccforc foam', 2),
#  ('dystopian tale radicalis amp reveng preorder 99c 99p', 2),
#  ('halfway amaniknew love', 2),
#  ('happen far often', 2),
#  ('fashion true fact', 2),
#  ('control battl loud soft suppoiv via', 2),
#  ('today shoot attack us especi hu lgbt friend prayfororlando speechless', 2),
#  ('viamiano wish father day', 2),
#  ('think mayb got sweet gig joke caus sent empti gift card', 2),
#  ('bae togeth studi damn fine', 2),
#  ('ok goe accept speak confer usofa later year suffolkhour', 2),
#  ('36 week pictur 37 week monday long babygirl bumpi', 2),
#  ('4 whore ring fire misogyni', 2),
#  ('bet ugli outsid insid tweet shit prove', 2),
#  ('shout peopl head state', 2),
#  ('possibl futur year 2100 advanc far lazi issu hug futureofwork', 2),
#  ('feel smiley selfi smile photooftheday posit positivevib summer day', 2),
#  ('thank sunris thank posit', 2),
#  ('thank sunday thank posit', 2),
#  ('seen latest design vote favorit cactu hug cute green', 2),
#  ('job jobsearch drunk sudburi wave box cutter greater sudburi man threaten',
#   2),
#  ('check flyer trump yay titti question bring pussi grab pussi', 2),
#  ('readi 4 wed boy selfi weddingtim cute handsom cool blue smile', 2),
#  ('need chang profil economicapahi hatespeech get servic poor', 2),
#  ('stori life', 2),
#  ('milkyway24 na kinki slut porn xxx nasti young naughti shi wet sexi hot horni nude',
#   2),
#  ('grandpa life insur grandpa realli die', 2),
#  ('fridayfeel fridaythought realtalk shideism bless day teamshid', 2),
#  ('silent major amp frighten amp beyond pray orlando', 2),
#  ('sad much hatr toward jew eu amp xian rememb xian kenya nigeria', 2),
#  ('nobodi help sinc day complaint ref 3818 nothinglikenew mensfashion centralatdahisar',
#   2),
#  ('10 hour walk nyc woman newyork women men bigot', 2),
#  ('thank creativ thank posit', 2),
#  ('f h e r fathersday love famili enjoy tbt bw black white', 2),
#  ('hope everyon nake saturday', 2),
#  ('wish could fun guy love bitten', 2),
#  ('allahsoil market crash march 2000 greenspan cut interest rate even', 2),
#  ('new video show guy sta abus humili muslim guy', 2),
#  ('vibrant posit affirm', 2),
#  ('week assembl princip launch end year reward trip student', 2),
#  ('fridg magnet bastard get life', 2),
#  ('shower time didnt hit snooz took slow slow tweet time got cut sho', 2),
#  ('linstagram present linzi fiestar goodmorn', 2),
#  ('done flight delay nearli 5hr amp frustrat', 2),
#  ('sorri hear mum 95 year care home last eight month come', 2),
#  ('prison offic goad muslim inmat need restrain pa game', 2),
#  ('2 day perform trojan women andromach gotoyourfathercolin', 2),
#  ('first wwe event excit wwewaco wwe deanambros wrestl familyfunnight yay', 2),
#  ('read vote sho stori wattys2016 wattpad dark girl death friend love', 2),
#  ('bubbl posit affirm', 2),
#  ('school place find educationfest', 2),
#  ('europ prove divers amp multicultur bring violenc rape amp ruin white western countri',
#   2),
#  ('ask dr rene choos 365black thank ask dr rene', 2),
#  ('work freestyl hair hairstyl hairdress thankyou good cool', 2),
#  ('father day wonder dad', 2),
#  ('next bracelet desdelaraiz handmad color joy hechoamano', 2),
#  ('pjk 42k suicid number overdos hr2646 irrelev bill thathelpsnoon end dentalcrisi',
#   2),
#  ('new one either way men disgrac harass verbalassault', 2),
#  ('figgiti figgiti fuck emo yikez', 2),
#  ('fuck micronesian amp shit weak know micro athlet', 2),
#  ('stop chelski fan equal divers', 2),
#  ('jeff session omit decad record ag confirm hear hide', 2),
#  ('wed moment bride groom bridesmaid happi unforgett love forev', 2),
#  ('believ reason homeoffic disclos info yarlswood', 2),
#  ('tech 10 symptom paner obsess bitcoin infograph', 2),
#  ('greatest friend lucki sinc 2008 best friend', 2),
#  ('sta day dog give bounc noth', 2),
#  ('open public two hour bargain', 2),
#  ('excit posit affirm', 2),
#  ('thank enemi thank posit', 2),
#  ('get readi swing sixti tonight sewingbe', 2),
#  ('treasur wisconsin librari museum histor societi soon histori', 2),
#  ('stun colour along morn run rout today june', 2),
#  ('kind day saturday weekend downtown', 2),
#  ('pl norfolkhour eaaa norfolk polo festiv sta tomorrow', 2),
#  ('cook girl instagood idola idol followm selfi', 2),
#  ('go canievenpaintanymor newproject fabercastel winsorandnewton experi notpencil',
#   2),
#  ('thursdaythought thursdaytreat realtalk shideism teamshid stay amp stay bless got',
#   2),
#  ('mcconnel obstruct goe way back discov obama black', 2),
#  ('meet fab betv volunteersweek', 2),
#  ('offic jew offici eye libtard mass', 2),
#  ('first day school', 2),
#  ('gonna home soon', 2),
#  ('pray orlando famili involv', 2),
#  ('sneak peek content look great', 2),
#  ('arriv sky high', 2),
#  ('thank energi thank posit', 2),
#  ('feel children stori recogn express manag anger male', 2),
#  ('retweet myminecraftrobot season 1', 2),
#  ('nigga burn amp let know amp femal burn amp let know', 2),
#  ('introduct msqrd lol dev ador toocut funni loveit instafun instacut', 2),
#  ('pathet donaldtrump easili tri make orlandohorror ego tragedi', 2),
#  ('word factori race denial prevent heal southafrica leadership transform inequ 9',
#   2),
#  ('onthisday 1744 young child die newcastl tragic circumst noheast povey socialhistori',
#   2),
#  ('excel idea dig deep amp hang em high treason aidingenemi fraud coverup benghazi extoion17',
#   2),
#  ('happi bihday see red line sink faster titan weakdonald loser', 2),
#  ('look like damn fool 50 year usa openli oppos settlement bulid israel', 2),
#  ('find game littl pa bird game play', 2),
#  ('camiilabeck divulga oeparceria inshot girl cute summer blur sun fun dog',
#   2),
#  ('dream dream take action make happen saterd vine', 2),
#  ('bear rapaci hunger oil also seal doom allahsoil teambt', 2),
#  ('1 week trip question pleas speak member team', 2),
#  ('quotesilov polar bear climb race angri polar bear climb race polar bear live cold place',
#   2),
#  ('state sysadmin age contain devop datacent', 2),
#  ('knosso amp akrotiri includ unesco world heritag site', 2),
#  ('relev ever', 2),
#  ('air condit broke gym temp 89 last 6 4 eahathon mile uponeaglew hot', 2),
#  ('readi handsom', 2),
#  ('wanna watch weekli mlpseason6 episod rememb hiatu mlp mlpfim', 2),
#  ('celebr posit affirm', 2),
#  ('want fulfil life 2 thing life smile satisfi bless', 2),
#  ('man rori show ufcottawa', 2),
#  ('fun play afternoon drum educ wednesdaywisdom retweet fl palmbeach', 2),
#  ('readi go', 2),
#  ('bday one awasom dj rakesh mani happi return da day hva awasom n bless day',
#   2),
#  ('anoth exampl religiouspsychosi epidem brutal amp ignor', 2),
#  ('happi posit affirm', 2),
#  ('happi', 2),
#  ('joy school achiev educationfest', 2),
#  ('peopl need understand joke amp walk away kind comment', 2),
#  ('sad first possibl mani come extinct', 2),
#  ('thank warm welcom morn enjoy hear sip next year wait', 2),
#  ('readi athlet meet teamwyb', 2),
#  ('son look shi first day school tomorrow proudpar', 2),
#  ('thank mountain thank posit', 2),
#  ('begin', 2),
#  ('precis deplor arm', 2),
#  ('notic empti prime retail space chicago trump tower', 2),
#  ('simpl yet effect tip advic help journey singl mom aga', 2),
#  ('secret work identifi enjoy work focu get client', 2),
#  ('happi joyou free bad way live life freedom', 2),
#  ('becom happier new app check updat health app tech watch', 2),
#  ('amen wonder daili inspir', 2),
#  ('omg tear gent olivia loveisland', 2),
#  ('count day ss17 launch wholesal womenswear menswear accessori sustain', 2),
#  ('happi father day yosoytupadr felizdiadelpadr fathersday domingodeganarseguidor sundaymorn iqq',
#   2),
#  ('thank clean water thank posit', 2),
#  ('trump alli r unstopp obama via christmasev', 2),
#  ('react anger respond conflict relationship', 2),
#  ('great aicl truth trc need comment back need indignen via', 2),
#  ('xbox happi score big e3 term tech internet score search', 2),
#  ('wait flight airpo manchest spain flight', 2),
#  ('lot resist challeng favorit thoughtlead mentor', 2),
#  ('lot ppl get wrong impress jocoxmp surpris thing spin polit gain', 2),
#  ('thought prayer jo cox famili eah go countri', 2),
#  ('super hero dad father day dad kubang', 2),
#  ('cri smile eye like pay love like4lik likeforlik like4follow', 2),
#  ('like page badass motiv quot gt inspirationalquot', 2),
#  ('3 app help keep amp healthi bloggingg', 2),
#  ('holi shit trump 1 person cheer n e new jersey like lie', 2),
#  ('sure emerg schedul snafu keep use acquir 24 ticket muhammadali', 2),
#  ('know trump win pipe whatev ego boost everyon get', 2),
#  ('famili horribl attack thegreenpalmcottag plettenburgbay westerncap thyini thiza want',
#   2),
#  ('kid dozen way help motherood dad classroom', 2),
#  ('anniversari sun queensilvia amp kingcarlgustaf sweden marri 40 year congrat royal',
#   2),
#  ('comment reflect ignor', 2),
#  ('life hors much fun would life without hors horselov equestrian hors', 2),
#  ('queenaneliss like posit atitud like joke men snapshot shi nude slut na', 2),
#  ('boom toureiffel three day pari pretti dead sporad selfi', 2),
#  ('wow realli appear peopl tri sell free ticket muhammadali funer', 2),
#  ('she cute gotta wait forev see', 2),
#  ('allahsoil peopl origin meant white landhold male', 2),
#  ('thank star thank posit', 2),
#  ('luth nurs begin indefinit strike', 2),
#  ('look damoor afternoon', 2),
#  ('arriv readi adrenalin fuell day student curriculumday', 2),
#  ('iamposs today extraordinaryladyspeak staraward', 2),
#  ('true careerguid', 2),
#  ('govern handout entic though', 2),
#  ('thank photograph thank posit', 2),
#  ('let put tank front everi nightclub america everi school everi theater everi church bowl alley',
#   2),
#  ('fantast posit affirm', 2),
#  ('badger new kennel toy badger', 2),
#  ('know posit affirm', 2),
#  ('nice1girl na horni slut kinki nude hot nasti sexi porn naughti snapshot xxx young wet shi',
#   2),
#  ('2day pray victim amp famili orlandoshoot thank god church love like christ',
#   2),
#  ('recit dua u ramazan dua', 2),
#  ('unfoun current gop see reagan like', 2),
#  ('believ sick thing peopl devil sick prayfororlando', 2),
#  ('love fact book avail onlin lovepub ukpub newbook', 2),
#  ('day', 2),
#  ('thai gorilla simul need adapt environ need tear citi materi', 2),
#  ('sta live life way alway want atsocialmedia lovelif destress', 2),
#  ('trump campaign offici want michel obama let loos live african ape notmypresid',
#   2),
#  ('saturday night live yay high five cecili strong bobbi moynihan mc donald',
#   2),
#  ('chang someth simpl thrivetrib tuesdaymotiv entrepreneur', 2),
#  ('fuck hater', 2),
#  ('repost repostapp prayfororlando', 2),
#  ('troubl leav until leav troubl learninglif life experi imwithh', 2),
#  ('vehicl caus celebr haiti travel vine', 2),
#  ('via funnymem funni girl sassi sosassi cute', 2),
#  ('earli amp get readi travel day 1', 2),
#  ('11th year anniversari michael jackson vindic', 2),
#  ('check star made sister team', 2),
#  ('djhumil feel ojb vibe ripojb areacodemixshow cc', 2),
#  ('damn life pretti awesom right kid great bill paid get marri', 2),
#  ('order two spf15 bronz lip balm australiangold', 2),
#  ('got ticket today gig favourit band atm favourit venu nice one estron', 2),
#  ('saw kid drop stuff outsid', 2),
#  ('indianapoli colt black cheerlead hug boy use slur much class', 2),
#  ('today celebr lulybtip affirm', 2),
#  ('flower bloom hope flower flower tuesday vine', 2),
#  ('fave', 2),
#  ('award best team 10th maidsaf award thankyou maidston', 2),
#  ('super excit quiz tomorrow night aid quiz knowledgeispow', 2),
#  ('wake empti phone everi morn', 2),
#  ('sheer wast two hour watch much nois crap udthapunjab', 2),
#  ('prioriti tou choro koi 2nd option tk ni banata 49 other', 2),
#  ('found medford', 2),
#  ('thank dead white dude europ nigga da list blm rapechucktodd', 2),
#  ('learn feelgood hormon click link bio goodfeel', 2),
#  ('less need happier minim happi plant make us simbi osi', 2),
#  ('shopper riclswtravelbook bearlovestravel trip travel singapor enjoy', 2),
#  ('gentlepassion4u na naughti shi slut nude sexi hot porn horni kinki nasti snapshot wet',
#   2),
#  ('kyra get assssss somewher', 2),
#  ('prepar posit affirm', 2),
#  ('sea shepherd suppoer racist seashepherd antirac', 2),
#  ('like summer summer swim swim sun sunni sea seasid', 2),
#  ('bihday talent amp humbl tnx 4 friend even fa schoolofrock', 2),
#  ('got near front bonnaroo greatshow', 2),
#  ('mean peopl suck wrote book nice nice guy finish first smb', 2),
#  ('mustread educ amp stereotyp', 2),
#  ('herbalremedi ahriti realli stop pain altwaystoh healthi', 2),
#  ('fliibi ti think sweet lie soul fake smile ever', 2),
#  ('rout alli palli boxcup', 2),
#  ('thank palm tree thank posit', 2),
#  ('good morn amp friday make today amp everyday ridicul amaz tgif', 2),
#  ('tell jefferi beauregard quit foolin around come pick hood amp sheet saturda',
#   2),
#  ('divin posit affirm', 2),
#  ('pleas forget use word bind men never ignor excus', 2),
#  ('church best place sunday morn stayinlov', 2),
#  ('three face kay menner photographi qualiti print card', 2),
#  ('stun posit affirm', 2),
#  ('happi brithday hoshi oppa hoshi day', 2),
#  ('food', 2),
#  ('3 miami offic fire target practic joke policebrut newswith', 2),
#  ('renaiss music stylist period music histori ancient vitorr staup read share',
#   2),
#  ('moment roti exactli suppos flame smallth 17 min go', 2),
#  ('kkd citi highst day run ssr 192chandragupta hero bih day nandamuri balakrishna',
#   2),
#  ('vote anim trump america fat chick', 2),
#  ('madashel join', 2),
#  ('goodmorn saturday storm move east byeby', 2),
#  ('43 day estuaryfringefestiv 2016 kick southend music cultur', 2),
#  ('touch love everyon becom poet plato love life', 2),
#  ('stamp 100 000', 2),
#  ('first intern press thank greenglam de suppo', 2),
#  ('exactli', 2),
#  ('special discount today bihday gt bihday', 2),
#  ('death jocox way result brexit remain cancel whole bloodi thing right', 2),
#  ('introduc keynot speaker eclipsecon franc', 2),
#  ('wait see present today tminus5hour', 2),
#  ('join us amp 039 christma juli amp 039 happi hour flipsidepa', 2),
#  ('dog', 2),
#  ('throw back 2 sta mrssa2016 journey brave2bu throwbackthursday', 2),
#  ('flight delay ramp empti avgeek bois airpo', 2),
#  ('heal posit affirm', 2),
#  ('peopl still', 2),
#  ('way great work love work love', 2),
#  ('council staff instruct anc go slow make da look bad expos week ago', 2),
#  ('3 week holiday pougal villa famili', 2),
#  ('nah creat lie ignor request prove truth', 2),
#  ('got ticket 12th juli', 2),
#  ('pleas long enough', 2),
#  ('expand pic empti tide turn wth mexican judg believ', 2),
#  ('oh loi duncan die met time fascin nice love work', 2),
#  ('celebr piraci pool pirat love summer thingstodo pooleboattrip', 2),
#  ('thank film thank posit', 2),
#  ('hey see august somethingtolookforwardto', 2),
#  ('thank googl thank posit', 2),
#  ('thank movi thank posit', 2),
#  ('earli bird registr 2017 today liveallyourdream underestim', 2),
#  ('follow hea', 2),
#  ('finish write anoth mabel childrensbook consid illustr use', 2),
#  ('bihday 20th', 2),
#  ('upbeat posit affirm', 2),
#  ('sta morn right lemonwat cleans detox begoodtoyourself healthi tuesdaymotiv',
#   2),
#  ('white fragil hard talk white peopl', 2),
#  ('rockshotel babalargunu kutlu olsun fathersday rock hotel amp casino', 2),
#  ('sirf ashiq log follow karen iqbal galib wasi faraz mohsin ki full poetri add follow f',
#   2),
#  ('love happi blue homehous instagood livemus justm bluedress instamo smile',
#   2),
#  ('fw dude yo ole man go colleg hoe wild', 2),
#  ('marxist evil jew propoganda jew control media never never cite non white grou',
#   2),
#  ('look forward head today perform annual cricket day pleasedontrain', 2),
#  ('saturday shoot beretta', 2),
#  ('conserv america attack unjust amp prejudici display proof', 2),
#  ('make sure stop exhibit see best hech hr', 2),
#  ('thing work week see game come togeth', 2),
#  ('thank child thank posit', 2),
#  ('fun amp teas blog fun laugh enteain funni loveislov prayfoheworld', 2),
#  ('wow wow wow creat plan life workshop amaz clariti plan motiv', 2),
#  ('happi begin selfish end john wooden quot happi', 2),
#  ('first base coach davey lope toss zach game ball nation', 2),
#  ('funni posit affirm', 2),
#  ('racial profil cologn disgust', 2),
#  ('guitar life music life life note love like music guitar girl', 2),
#  ('look arriv thank john hunter glastonburyfestiv', 2),
#  ('complet forgot home year', 2),
#  ('death dream day stop believ work take get dream quoteoftheday', 2),
#  ('wish bihday hbd bihday aboutlastnight', 2),
#  ('note stori get sympathi hard grind get result grind', 2),
#  ('rest peac stephen keshi', 2),
#  ('friday everyon', 2),
#  ('gm thursday morn', 2),
#  ('prayfororlando orlando pray pray puls love compass lgbt peac never', 2),
#  ('mai boi gp follow great bless', 2),
#  ('make consciou decis control world control mood', 2),
#  ('get', 2),
#  ('angel nicol niec nicol familytim turkey kemer time beinlif', 2),
#  ('5 day due date babydaddi scare pregnanc', 2),
#  ('test day big shoot thursday 360 360video vr music videoclip', 2),
#  ('much mayhem go shoot bomb bare keep', 2),
#  ('sunni sunday maraton runner run travel zipaquira bogotadc colombia', 2),
#  ('work develop greencommun summer fun sustainableliv', 2),
#  ('gt gt sirf ashiq log follow karen iqbal galib wasi faraz sagar mohsin ki full poetri shairi follow send 4o4o4',
#   2),
#  ('root beer storm rootbeer storm rain thunder lightn car caffin ford', 2),
#  ('two littl owl', 2),
#  ('sorri pain anguish brought area orlandostrong orlando', 2),
#  ('love posit affirm', 2),
#  ('today morn want wear lens red bloodi eye want much xoxo', 2),
#  ('big thankyou 200 sub motovlog cake', 2),
#  ('thank good news thank posit', 2),
#  ('best luck', 2),
#  ('woke alarm morn adrenalin nerv', 2),
#  ('bestsel coach inspir never go bed without dream wakeup without hope', 2),
#  ('freeship worldwid make offer 29 iron planch antiqu vintag heavi cast iron',
#   2),
#  ('libtard regress effo logic point w insult slur especi refut wh', 2),
#  ('would give away firstborn see take blanch duboi omg', 2),
#  ('much look forward summer besti holiday mum', 2),
#  ('sad world turn polit zoolog disast govern truli ever learn', 2),
#  ('corrieeeeee time', 2),
#  ('love hea chang world say goe love make world go round', 2),
#  ('father day best forev loui babi beuti freddi', 2),
#  ('uk 2016 fell pop star job bbc euref brexit media', 2),
#  ('girl home sens someth wrong never met littl boy year later mystic supernatur psychic',
#   2),
#  ('thank follow friday', 2),
#  ('yup saw right stay tune juici updat amp chef line up monsoonpunemarket chefdemo',
#   2),
#  ('wait mammamia', 2),
#  ('today day work stmu grad stmugrad finallyher', 2),
#  ('np ladylouisewindsor attend thanksgiv queenelizabeth bihday london 10 06 16',
#   2),
#  ('new sweet homedecor design avail pet togeth', 2),
#  ('found brand new hardback copi darker shade magic 10 total made day bookworm',
#   2),
#  ('sometim aloha like lovesong alohafriday', 2),
#  ('adv bihday thalaivaaaaaa thalaivaa vijay bdayspl week', 2),
#  ('delet account shallow go away', 2),
#  ('caridg coupl woh root day', 2),
#  ('guy live rule love work rcs16 big thank amp awesom', 2),
#  ('someon gossip make mistak gossip boringl nodream', 2),
#  ('great meet best gin experi london worldginday tomorrow', 2),
#  ('love edm much wait get logic pro futur', 2),
#  ('bt day pay', 2),
#  ('wait line reignofkong right', 2),
#  ('kati hopkin left admit truth islam islam polit jealou hate', 2),
#  ('cece eve go drag bed get tonight otherwis stay holiday bye', 2),
#  ('sway hbd want meet bihdaysway', 2),
#  ('even usa gay still danger prayfororlando whatap', 2),
#  ('cell phone minut 4 ebook funni wacki true cellphon stori kindl smashword nook ibook',
#   2),
#  ('follow depress suicid suicid selfharm quot', 2),
#  ('get request communalis much anger', 2),
#  ('happi explain realli love thought mr money mustach life', 2),
#  ('gop dnc wing nut disagr stupid absolut r scari', 2),
#  ('prepar underway', 2),
#  ('thank teacher thank posit', 2),
#  ('sick babi tire momma watch elmo liam liamwesley sick poorbabi rest 20monthsold',
#   2),
#  ('happi 17 week 1 7 pregnant 17week bump', 2),
#  ('happi father day father dad dad daddi fatherday traditon', 2),
#  ('trump guilti treason theresist must resist hate nake raygun treason', 2),
#  ('funni', 2),
#  ('content w life atm', 2),
#  ('reject news latest amwrit aicl', 2),
#  ('im done gurl betta get face', 2),
#  ('uandhealth bless week ahead followm tagsforlik beauti instadaili fu', 2),
#  ('bill materi uncov take unleash dazzl oomf gmr creat toolkit', 2),
#  ('thank cloud thank posit', 2),
#  ('alreadi miss best friend even 24 hour yet lol', 2),
#  ('realli tell microaggress race whiteprivileg antiblack', 2),
#  ('went look old tweet realli miss fam', 2),
#  ('48 hour go go glamp wi twin girlpow friend', 2),
#  ('probabl year therapi hatr still run deep', 2),
#  ('smile', 2),
#  ('aw slap face american hey neighbor black bought 700 000 hous r', 2),
#  ('sentiment exactli war minor war control think', 2),
#  ('happi wed wed', 2),
#  ('look forward wwdc 2016 year appl tech', 2),
#  ('cant wait', 2),
#  ('black12iwhiteboy na porn nude xxx nasti young horni slut hot shi sexi naughti kinki',
#   2),
#  ('binocular cirquedusoleil ovo gucci sequinbow lucki bless love', 2),
#  ('nice meet summer losangel live hello photographi studio longhair', 2),
#  ('thank kiss thank posit', 2),
#  ('mrrat395 starfightersaturday phantomavi cptplanespott blackmaverick12 wbruchal ufeellucki spad5',
#   2),
#  ('welcom monday', 2),
#  ('music put accent feel happi time give answer wound soul', 2),
#  ('fathersdayquot best father day quot bihday buy thing abo', 2),
#  ('realli happi relationship final much better one first', 2),
#  ('donthecon read poorli teleprompt', 2),
#  ('islam gave purpos life left islam purpos life defam islam useless', 2),
#  ('well donald trump offici reach bottom clown pay hood chick promot', 2),
#  ('saira way new smile invisalignjourney', 2),
#  ('5 simpl rule life quot leadership inspir', 2),
#  ('ben liter one fake human be ever encount ttrusthim donttrusthim bewar', 2),
#  ('money stay know', 2),
#  ('mtv whitepeopl ccot via', 2),
#  ('well', 2),
#  ('ok', 2),
#  ('ye everyon know shame bjp', 2),
#  ...]

# %%
#For_Test_Data
from collections import Counter
occurrences_1= Counter(X_test['tweet'])
occurrences_1.most_common()
# Out:
# [('model love u take u time ur', 172),
#  ('final found way delet old tweet might find use well deletetweet', 43),
#  ('aww yeah good bing bong bing bong', 32),
#  ('grate affirm', 31),
#  ('might libtard libtard sjw liber polit', 28),
#  ('lighttherapi help depress altwaystoh healthi happi', 27),
#  ('', 26),
#  ('feminismiscanc feminismisterror feminismmuktbharat malevot ignor', 20),
#  ('love instagood photooftheday top tag tbt cute beauti followm follow', 19),
#  ('happi work confer right mindset lead cultur develop organ work mindset',
#   16),
#  ('black amp feel like stomp listen retweet tampa miami', 15),
#  ('save login x broker chang meme love educ univers', 14),
#  ('best essentialoil anxieti healthi peac altwaystoh', 13),
#  ('get get get enjoy music today free app free music', 13),
#  ('lighttherapi help sad depress altwaystoh healthi', 12),
#  ('peopl protest trump republican trump fuher amp', 12),
#  ('father day', 11),
#  ('lover stop angri visit us gt gt gt lover friend astrolog love', 11),
#  ('100 amaz health benefit cucumb healthi altwaystoh', 10),
#  ('look feel joy join 20 speaker free summit unleashyourjoy', 9),
#  ('food heal bodi doplant healthi', 8),
#  ('use power mind heal bodi altwaystoh healthi peac', 8),
#  ('atherapi musictherapi heal life altwaystoh healthi heal', 8),
#  ('bihday', 8),
#  ('love instagood photooftheday top tag tbt cute beauti followm', 8),
#  ('sea shepherd suppoer racist antirac seashepherd', 8),
#  ('safe way heal acn altwaystoh healthi heal', 7),
#  ('heal lawofattract loa altwaystoh healthi well', 7),
#  ('thank love thank posit', 7),
#  ('today perfect day happi lifecoach reinventimposs', 7),
#  ('lawofattract heal altwaystoh healthi', 7),
#  ('make', 7),
#  ('stuck rat race find freedom masterkeyexperi', 7),
#  ('best lawofattract resourc heal altwaystoh healthi idwp', 7),
#  ('fathersday gift proud dad avail 1 day', 7),
#  ('sta laugh cri make sad laugh cri distress anxiou chang mindset depress', 7),
#  ('snow white gt open gt sleepi sneezi bash dm us today', 6),
#  ('amp grate money come increas quantiti multipl sourc continu basi', 6),
#  ('use power mind heal bodi altwaystoh healthi', 6),
#  ('best homeopath remedi anxieti altwaystoh heal peac', 6),
#  ('love abrahamhick lawofattract healthi heal joytrain', 6),
#  ('detoxdiet altwaystoh healthi', 6),
#  ('photo accept amp sale photographi', 6),
#  ('music therapi tool heal altwaystoh healthi', 6),
#  ('herbal sleep remedi work altwaystoh healthi heal', 6),
#  ('best essentialoil weightloss altwaystoh healthi', 6),
#  ('cloudchas bull hill climb reach target complet task surviv strong ex', 6),
#  ('angri squeak frog video frog natur anim cute ador', 6),
#  ('spare leader kolianwali meet fate ravisidhu capt amarind', 6),
#  ('teen girl kill 3 other injur downtown oakland shoot gun mentalil gang orlando',
#   6),
#  ('save thousand free search x login x broker actor seeklearn stafresh', 6),
#  ('love', 5),
#  ('thrill posit affirm', 5),
#  ('intellig posit affirm', 5),
#  ('tgif ff gamedev indiedev indiegamedev squad', 5),
#  ('toptweet like one venusexchang', 5),
#  ('ase bull domin bull direct whatev want', 5),
#  ('damn realli made tear littl mustread', 5),
#  ('rss ruggedmaxxx love instagood tbt photooftheday cute beauti foll', 5),
#  ('power posit affirm', 5),
#  ('flowerlov bull domin bull direct whatev want', 5),
#  ('remov aap spokesperson alkalamba showcas dictatori mindset kejriw', 5),
#  ('broken buffalo simul buffalo take vicin home way', 5),
#  ('parent bull domin bull direct whatev want', 5),
#  ('saysometh bull domin bull direct whatev want', 5),
#  ('herbalremedi anxieti work altwaystoh healthi heal peac', 5),
#  ('comment reflect ignor', 5),
#  ('save date 1 4 2017 sourcen live wed 8 thependulum newshow policebrut', 5),
#  ('thank passion thank posit', 5),
#  ('flagday2016 flag day 2016 30 photo buy thing flag day 2016', 5),
#  ('taylorswift1989 bull domin bull direct whatev want w', 5),
#  ('lawofattract heal loa healthi well idwp', 5),
#  ('green bull hill climb reach target complet task surviv strong excitem', 5),
#  ('raw food diet benefit altwaystoh healthi heal peac joy love', 4),
#  ('grow old along best yet robe brown wed love', 4),
#  ('thank freedom speech thank posit', 4),
#  ('justinb gorilla simul need adapt environ need tear citi materia', 4),
#  ('sunday', 4),
#  ('thank laughter thank posit', 4),
#  ('genuin posit affirm', 4),
#  ('might go hell surpris versac', 4),
#  ('zaynmalik bull domin bull direct whatev want yo', 4),
#  ('3 key found comput enjoy life inspir advic', 4),
#  ('thank internet connect thank posit', 4),
#  ('best essenti oil heal altwaystoh healthi', 4),
#  ('blackheathstandard summerfair', 4),
#  ('man come last race declar winner putinschoic putinspuppet retweet', 4),
#  ('magnettherapi realli work altwaystoh heal healthi', 4),
#  ('choos thought choos bless grate themoodcard via', 4),
#  ('want creativ worker give enough time play success quot', 4),
#  ('safe posit affirm', 4),
#  ('refin posit affirm', 4),
#  ('springfield bull domin bull direct whatev want', 4),
#  ('founat posit affirm', 4),
#  ('lessismor polar bear climb race angri polar bear climb race polar bear live cold place l',
#   4),
#  ('cotd polar bear climb race angri polar bear climb race polar bear live cold place look',
#   4),
#  ('smaphon bull domin bull direct whatev want', 4),
#  ('glamor posit affirm', 4),
#  ('thank hope thank posit', 4),
#  ('thank home thank posit', 4),
#  ('60 power minut free podcast anxieti stress life success nowplay', 4),
#  ('allahsoil term jihad highli contest concept teambt teamsuperjunior', 4),
#  ('facebook attack bull chase leav lot despit fact strong sourc fo', 4),
#  ('watch weddingplan peopl', 4),
#  ('quotesilov polar bear climb race angri polar bear climb race polar bear live cold place',
#   4),
#  ('grace posit affirm', 4),
#  ('spiritualgrowth bull domin bull direct whatev want w', 4),
#  ('nuur posit affirm', 4),
#  ('sometim take smile smile via', 4),
#  ('medit gorilla simul need adapt environ need tear citi mate', 4),
#  ('thank fun thank posit', 3),
#  ('bubbl posit affirm', 3),
#  ('spend life peopl make quot inspir', 3),
#  ('thank abl see thank posit', 3),
#  ('introduct happi day day', 3),
#  ('haileysporn na sexi shi porn horni nasti naughti slut hot xxx nude wet kinki young',
#   3),
#  ('special train offic stop two angri dog without violenc video', 3),
#  ('trainhard polar bear climb race angri polar bear climb race polar bear live cold place lo',
#   3),
#  ('hispan amp feel like stomp listen retweet boricua', 3),
#  ('tyler perri claim revers racism critic tlc seri tyler perri claim revers critic',
#   3),
#  ('thank food thank posit', 3),
#  ('newstar bull domin bull direct whatev want', 3),
#  ('eleg posit affirm', 3),
#  ('thank', 3),
#  ('nation ice tea day love', 3),
#  ('studio attack bull game 3d realli think head empti around citi side sup',
#   3),
#  ('thank freedom vote thank posit', 3),
#  ('film bull domin bull direct whatev want sta', 3),
#  ('lightroom bull domin bull direct whatev want yo', 3),
#  ('book german coloni global age ht imperi blm', 3),
#  ('decor buffalo simul buffalo take vicin home way', 3),
#  ('thank eah thank posit', 3),
#  ('fathersday comfo zone father day buy thing father day', 3),
#  ('thank mistak thank posit', 3),
#  ('thank sunshin thank posit', 3),
#  ('blackcokwhiteass na kinki snapshot naughti nasti porn wet slut horni young shi xxx sexi',
#   3),
#  ('smile smile top tag toptag smile beautifulsmil smiley smile pretti', 3),
#  ('energet posit affirm', 3),
#  ('thank cloud thank posit', 3),
#  ('success order', 3),
#  ('happi day altwaystoh healthi', 3),
#  ('hispan feel like stomp listen retweet boricua', 3),
#  ('fabul posit affirm', 3),
#  ('thank countri thank posit', 3),
#  ('itw play impoant role 2017 poll list offic bearer', 3),
#  ('go germani gogermani em em2016 famili love germani selfi lovemyfamili smile',
#   3),
#  ('happi', 3),
#  ('thank apolog thank posit', 3),
#  ('rainbowrowel bull domin bull direct whatev want whe', 3),
#  ('gener posit affirm', 3),
#  ('winterfashion bull domin bull direct whatev want whe', 3),
#  ('hispan amp feel stomp listen retweet boricua miami', 3),
#  ('13 tip help flourish posit success growth balanc', 3),
#  ('prfectpitch miss episod play back', 3),
#  ('contactcent qualiti improv fun perk avi ootd result new best', 3),
#  ('hispan amp like stomp listen retweet boricua miami', 3),
#  ('ok posit affirm', 3),
#  ('thank summer thank posit', 3),
#  ('make make smile laugh much breath love long live', 3),
#  ('drakeandjosh buffalo simul buffalo take vicin home wa', 3),
#  ('thank abl learn thank posit', 3),
#  ('late ff gamedev indiedev indiegamedev squad', 3),
#  ('choos happi matter circumst free smile', 3),
#  ('smilepowerday show us best cheesi grin pearli white smile teeth', 3),
#  ('thank peac thank posit', 3),
#  ('lot resist challeng favorit thoughtlead mentor', 3),
#  ('thank forgiv thank posit', 3),
#  ('bestsel famili motiv never go bed without dream wakeup without hope', 3),
#  ('respect posit affirm', 3),
#  ('playinggam buffalo simul buffalo take vicin home wa', 3),
#  ('scribbl polar bear climb race angri polar bear climb race polar bear live cold place loo',
#   3),
#  ('thank paner thank posit', 3),
#  ('happi work co nferenc right mindset lead cultur develop organ work mindset',
#   3),
#  ('thrive posit affirm', 3),
#  ('cutemuscleboy na nasti wet hot young slut xxx kinki naughti porn sexi shi horni nude',
#   3),
#  ('allahsoil like religion islam strong unifi forc teambt', 3),
#  ('day', 3),
#  ('tattoosleev gorilla simul need adapt environ need tear citi', 3),
#  ('7 step healthi age', 3),
#  ('mountain rooster simul want climb vast expans mountain reach leakag cock',
#   3),
#  ('thank photograph thank posit', 3),
#  ('noth make dad happier tasti meal fathersday', 3),
#  ('garden wisdom wisdom saturdaymorn flower saterday vine vine', 3),
#  ('natur perfect bull hill climb reach target complet task surviv str', 3),
#  ('haford buffalo simul buffalo take vicin home way', 3),
#  ('thank rain thank posit', 3),
#  ('thank new place thank posit', 3),
#  ('quoteoftheday bull domin bull direct whatev want whe', 3),
#  ('never', 3),
#  ('revolut occur marx expect teambt teamsuperjunior', 3),
#  ('cute posit affirm', 3),
#  ('sirf ashiq log follow karen iqbal galib wasi faraz mohsin ki full poetri add follow send 4o4o4',
#   3),
#  ('never understand dad left young deep inthefeel', 2),
#  ('electron music bogota colombia puntohost cedm edm dj fashion music', 2),
#  ('741 retweet half day gun owner like hubbi amp respect fanatic', 2),
#  ('way oambo see soon sasocp16', 2),
#  ('begun someth new page amp super daili tarot guidanc', 2),
#  ('trump long histori explain 1970 thru 2016 nevermypresid theresist', 2),
#  ('burnt garlic bread devast', 2),
#  ('oh admit small staff flipflopp disgrac', 2),
#  ('macbook gorilla simul need adapt environ need tear citi materia', 2),
#  ('93 video 16 refer sen warren pocahonta stabl pattern ignor', 2),
#  ('end day gotta', 2),
#  ('thank health thank posit', 2),
#  ('know posit affirm', 2),
#  ('tyler ward amp cimorelli cover pharrel william music video', 2),
#  ('come soon amazon coloringbook oliviagraceowen', 2),
#  ('nakedbusti love much', 2),
#  ('7 step age healthi', 2),
#  ('badventcalendar day24 nov 8 trump election2016 donat f kin save 2016', 2),
#  ('marathon bull domin bull direct whatev want', 2),
#  ('weekend amp ramadan everyon tri find dream propey weekend us dubai uae', 2),
#  ('troubl updat blackberri passpo 10 os 10 3 2 2836 alway stop instal 2 2 44 need help',
#   2),
#  ('final found way delet old tweet might find use well deletetw', 2),
#  ('happi work confer rig ht mindset lead cultur develop organ work mindset',
#   2),
#  ('hope u guy readi request rage callofduti game youtub ragen', 2),
#  ('say exclus mix ditch label drop next week', 2),
#  ('dazzl posit affirm', 2),
#  ('burlap farm dog fun dog anim cute funni play hay', 2),
#  ('life make let make motiv', 2),
#  ('sad dukhi shairi urdu shairi love poetri gazal nice poetri daili free poetri dosti msg plz 1 tri follow snd 40404',
#   2),
#  ('time yesaward winner announc', 2),
#  ('holiday plan januari 3 week book work beachhut travel', 2),
#  ('miss small human noth good without u girli snug', 2),
#  ('go', 2),
#  ('ericfriday compar polit career humanlif depict vote democrat2016 saniti',
#   2),
#  ('lawsuit alleg versac store', 2),
#  ('visit gorilla simul need adapt environ need tear citi materi', 2),
#  ('love trust wrong none friend work', 2),
#  ('happi bihday babygirl lilli 7 year alreadi whoop whoop bihday girl', 2),
#  ('town whiteland fight nativ american school mascot notyourmascot whiteprivileg via',
#   2),
#  ('thank thank posit', 2),
#  ('thank kiss thank posit', 2),
#  ('ationalbedfriendsday jump', 2),
#  ('want', 2),
#  ('terribl tragedi r p christinagrimmi world scari place heabroken', 2),
#  ('sexless season love scene impoant see disappoint puzzl outland', 2),
#  ('donald unfavor rate 70', 2),
#  ('happi father day father fathersday fathersday', 2),
#  ('wed teaser amp c photographi wed photographi bride groom moment', 2),
#  ('zumba tonight wellow hall romsey 6 7pm new tune fit dancefit noneedtobook',
#   2),
#  ('2016 white man act like kid twitter call passion black man say would win ego',
#   2),
#  ('thank star thank posit', 2),
#  ('funni thing humankind watch news feel bad etc back open busi usual good futur',
#   2),
#  ('socialmedia niif qatar invest author ink mou boost infra', 2),
#  ('thank get encourag thank posit', 2),
#  ('docu topic incl divid labor iww syndic revolutionari union childlabor anarch l',
#   2),
#  ('12 thing peopl differ infograph inspir gratitud', 2),
#  ('seem like episod earlier woh watch aldubthesend', 2),
#  ('thank compliment thank posit', 2),
#  ('get', 2),
#  ('gt iron use imag dover ralli antifa retreat reddit lick wound', 2),
#  ('thank good health thank posit', 2),
#  ('11 racist u presid via america promis equal lie', 2),
#  ('hit right nail way n hell agre share', 2),
#  ('alabama counti refus lower flag honor orlando shoot victim lower enteain',
#   2),
#  ('fathersday father day columbu post buy thing happi fa', 2),
#  ('cedarrapid bull domin bull direct whatev want', 2),
#  ('leicest polic offic sack film use languag england', 2),
#  ('make float perfectli', 2),
#  ('muslim famili use decor home show r sta ramadan', 2),
#  ('tragedi happyday knowledg empow site love blind marriag open eye', 2),
#  ('new video manspread new year manspread mansplain happynewyear', 2),
#  ('childhood bull domin bull direct whatev want yo', 2),
#  ('angel archangel high help live spiritu anf live', 2),
#  ('florida miss see soon', 2),
#  ('thank school thank posit', 2),
#  ('bihday rg', 2),
#  ('sta day cute note set cuddl alarm much', 2),
#  ('thank parent thank posit', 2),
#  ('fitnessaddict attack bull chase leav lot despit fact strong sourc', 2),
#  ('83 yr old woman beaten amp set fire black gang cri', 2),
#  ('good morn guy love instagood photooftheday fashion cute summer fun smile',
#   2),
#  ('hell yeah great surpris present enjoy pictur bihday', 2),
#  ('alreemgroup ali alshahawi ad cute summer photographerdubai sun hair mydubai',
#   2),
#  ('there instruct len view histori len empir', 2),
#  ('ryderrideu see c2c cum togeth snapshot young shi kinki wet porn hot xxx horni',
#   2),
#  ('feel landfil worri guilti solut depress teamcarpitza empathi yyc', 2),
#  ('good morn hope happi mine extrem masochist come session', 2),
#  ('peopl origin meant white landhold male 2017in3word', 2),
#  ('dentalclin bangalor wish morn', 2),
#  ('allahsoil bear rapaci hunger oil also seal doom teambt', 2),
#  ('jesserushot compliment present make horni daddi slut shi sexi snapshot xxx',
#   2),
#  ('peopl must think good drug realli good actor happi joy flow love', 2),
#  ('tran 160609 bigbadboii 1219 dragon boat festiv', 2),
#  ('realiti tech industri made regular ass peopl tech discrimin', 2),
#  ('anyscott na young nasti nude naughti horni wet sexi porn slut xxx hot kinki snapshot shi',
#   2),
#  ('dog kind way say worri dogsarejoy', 2),
#  ('tranquil posit affirm', 2),
#  ('samsunggalaxys2 rooster simul want climb vast expans mountain reach leakag',
#   2),
#  ('happi father day father day', 2),
#  ('thank babi giggl thank posit', 2),
#  ('thank sens smell thank posit', 2),
#  ('select retail planet organ lemonad save 1 00 1 5 l size cashbackoff', 2),
#  ('back view blowoutsbringhappi yet anoth client book appoint', 2),
#  ('mf offici first aid child protect vet muchli', 2),
#  ('excit featur summer issu fashionista fashionblogg', 2),
#  ('acquaint punjabi cultur kejriw tri lure punjabi', 2),
#  ('honor posit affirm', 2),
#  ('get album tomorrow read review', 2),
#  ('sikh templ vandalis calgari wso condemn act', 2),
#  ('punish work children', 2),
#  ('excel custom real prod issu apachespark develop oper', 2),
#  ('thank life thank posit', 2),
#  ('arriv nwwa sat final prosecco', 2),
#  ('hi tweep old acc lost phone laptop n password', 2),
#  ('got told immigr rape longer get rape kind', 2),
#  ('pain pleasur music melancholi tragedi emot studi', 2),
#  ('ye decid happi', 2),
#  ('one said break easi tell time would woh singl life', 2),
#  ('take countri feed ego orang clown', 2),
#  ('let go bitter get ebook happi free today', 2),
#  ('whiteland high school indiana 97 white commun want keep nativ mascot notyourmascot',
#   2),
#  ('exit love everyth repres growth expand', 2),
#  ('fathersday father day say quot imag buy thing happi fath', 2),
#  ('thank fall leav thank posit', 2),
#  ('brand new h e w n e r', 2),
#  ('happi pictur video webcam pictur video', 2),
#  ('feel recogn express amp manag anger printabl activ color b amp w ver', 2),
#  ('yooo swaggi bihday kid right one og', 2),
#  ('aint tragic superag', 2),
#  ('light posit affirm', 2),
#  ('thought factori left right polaris trump uselections2016 leadership polit brexit blm 10',
#   2),
#  ('kejriw must accept role make udtapunjab conspiraci defam punjab', 2),
#  ('see', 2),
#  ('increas profit hit sale 1 24 tweet day 60 500 worldwid photooftheday beauti',
#   2),
#  ('life bore around happi bihday let make life bihday friend', 2),
#  ('bihday buddi', 2),
#  ('happi color happi summer summer fashion color handmad jewelri hamsa necklac pink shell fashion',
#   2),
#  ('happ work confer right mindset lead cultur develop organ work mindset', 2),
#  ('learn pursu want leadership success', 2),
#  ('graduat tonight year earli onwiththemus', 2),
#  ('thank hike trail thank posit', 2),
#  ('alway sing flashligth', 2),
#  ('selamatmalam coffe time thank visit beauti long weekend', 2),
#  ('got coupon mail expir 2 day ago whatdididotodeservethi iwantmypotato', 2),
#  ('4 day championship fixtur announc bee brentfordfc', 2),
#  ('thank warm run water thank posit', 2),
#  ('normal new via', 2),
#  ('stress lose greatbook amread relax life', 2),
#  ('ashleymorrisx na nude xxx slut nasti wet sexi naughti kinki young hot porn shi horni',
#   2),
#  ('fathersday look someth see trend commun', 2),
#  ('6 ottawa polic confirm offic post comment anniepootoogook death aptn2016',
#   2),
#  ('listen jake gulli hall autocorrect shook ferret way hard day', 2),
#  ('feelgood thing', 2),
#  ('thank abl walk thank posit', 2),
#  ('likescam bull hill climb reach target complet task surviv strong excit', 2),
#  ('alway', 2),
#  ('si share outright wa', 2),
#  ('effoless posit affirm', 2),
#  ('media liter invest million destroy islam imag', 2),
#  ('amaz man amaz man perfect love man sweeti dearest', 2),
#  ('petal polar bear climb race angri polar bear climb race polar bear live cold place lookin',
#   2),
#  ('give someth eat erni', 2),
#  ('king queen streetstyl sneakernew smile basketbal hypebeast highsnobieti picoftheday',
#   2),
#  ('inter terrestri scifi sciencefict kindleunlimit kindlebook prejudic', 2),
#  ('thank vaccin thank posit', 2),
#  ('thank friday thank posit', 2),
#  ('attract posit affirm', 2),
#  ('good read love weather someon need holiday ibiza escanar', 2),
#  ('much love dad today especi mr brian l italien father', 2),
#  ('happi marriag union two good forgiv robe quillen wed love', 2),
#  ('fathersday guy young old day today enjoy', 2),
#  ('brittany9 na slut nude sexi naughti horni xxx kinki wet porn snapshot shi nasti hot young',
#   2),
#  ('nice posit affirm', 2),
#  ('thank rainbow thank posit', 2),
#  ('franc 2 recent terrorist attack english fan find polic total unsympathet',
#   2),
#  ('normal amp e kkk docuseri cancel news photoop', 2),
#  ('thursday everyon wish sunni day amp lot blue sky vine', 2),
#  ('even know say', 2),
#  ('said person 395 tweet 5 follow', 2),
#  ('even gang fight franc', 2),
#  ('olath polar bear climb race angri polar bear climb race polar bear live cold place looki',
#   2),
#  ('trump less appeal juli gop deleg bound nomin ted cruz chanc maga nt', 2),
#  ('good morn', 2),
#  ('stripe bull domin bull direct whatev want', 2),
#  ('impress posit affirm', 2),
#  ('cool even sock sock maximu puppi dog sock lovesock', 2),
#  ('regrann prayfororlando regrann', 2),
#  ('play mix doubl friday', 2),
#  ('7 impoant thing allow child', 2),
#  ('june newslett commun event brokencalendar sendyoureventdetail', 2),
#  ('electrifi posit affirm', 2),
#  ('look homescreen', 2),
#  ('ripchristina ripgrimmi miss christina grimmi muchlov rip mourn', 2),
#  ('wew curri foul', 2),
#  ('make overweight dog dog health problem', 2),
#  ('feel stori recogn express manag anger printabl color b amp w', 2),
#  ('everi childrensbook end mustread kkst 4ftm author', 2),
#  ('happi w ork confer right mindset lead cultur develop organ work mindset',
#   2),
#  ('cat photogrid cute eye instas perfect', 2),
#  ('one favorit caoon 2016 trump race hate', 2),
#  ('thank eyesight thank posit', 2),
#  ('amaz posit affirm', 2),
#  ('care advic sold soul faust blacklivesmatt', 2),
#  ('yellen would make great politician say noth yet peopl believ drivel', 2),
#  ('fire provid director editor approv resolut white guy', 2),
#  ('still shock win best jewel categori counti bride award nwwa wed award', 2),
#  ('sound amp act like batter spous cower trump slam cnn debat disgrac', 2),
#  ('patriot mother russia sure treasonoustrump fascist puppet traitor', 2),
#  ('11 habit suprem peopl', 2),
#  ('one week plane summerholiday marb', 2),
#  ('thank challeng thank posit', 2),
#  ('saturday hope enjoy recent f 16 takeoff weekend aviat avgeek', 2),
#  ('amazingli talkshow thursday 9pm hifi studio', 2),
#  ('im lemm catch brock bitch street', 2),
#  ('treat like begin end bless', 2),
#  ('hell yeah updat simciti', 2),
#  ('pjk 42k suicid number overdos hr2646 irrelev bill thathelpsnoon end dentalcrisi',
#   2),
#  ('global wind day gogreen cleanenergi', 2),
#  ('dr franc cress wels racism defin whitesupremaci drfranciscresswels', 2),
#  ('orlando weep u famili 20 human be murder hatr bigotri pride2016', 2),
#  ('sensit fan right xmenapocalyps movi poster', 2),
#  ('back via', 2),
#  ('toler polic forc', 2),
#  ('life come around whatev make', 2),
#  ('wonder mani happi memori store mind one day rememb memori', 2),
#  ('dickhead eat ham prawn drink grang', 2),
#  ('trump employe instruct write c color hous applic person would deni', 2),
#  ('main street vibe lifeisgood mainstreet', 2),
#  ('love colin kaepernick deserv award thank stand hatr', 2),
#  ('alway rememb forgot thing made u bt never forgot thing made u glad', 2),
#  ('let get pay sta spnphx spnfamili waywardaf', 2),
#  ('love summer time summer', 2),
#  ('wish bihday may god bless happi joy strength long great year ahead', 2),
#  ('love quot lt 3 lt 3 retweet love disney alic movi quot love disneyland mickey',
#   2),
#  ('goodmorn world rainingday', 2),
#  ('bullshit go r colleg univers racist view poison ur kid speak b4 2late', 2),
#  ('tyru wong bambi aist thwa racial bia die 106 via anim', 2),
#  ('women fare 2016 misogyni genderequ', 2),
#  ('wait treat kid knew bowl alley', 2),
#  ('happi christma tol see u later', 2),
#  ('count day make day count flower friday vine vine', 2),
#  ('disgust blacklivesmatt best loser motiv fool', 2),
#  ('danish imam tri antijewish incit denmark jail', 2),
#  ('becom ugli mt patriarchi feminist femin', 2),
#  ('ye mean often hear fl full gator never thought disney world though issu',
#   2),
#  ('eat veget r dram broccoli lilyachti music musicvideo danc loved music', 2),
#  ('bigot', 2),
#  ('sale today cross bloke cheatingwif', 2),
#  ('host fist ever productjam 1 see tech digit via', 2),
#  ('ink polar bear climb race angri polar bear climb race polar bear live cold place lookin',
#   2),
#  ('sunday bless famo', 2),
#  ('everyth alway want across funk selfi smile moment life', 2),
#  ('electron music bogota colombia puntohost edm dj ibiza fashion envivo music live',
#   2),
#  ('ador posit affirm', 2),
#  ('trumpsamerica suck bigli ny gov cuomo condemn carl paladino ugli remark abt obama',
#   2),
#  ('terribl news austin yelchin pass away age 27 gameofthron starek news news23 rip',
#   2),
#  ('11 june2016 goodmemori goodtim friendship got7 flyinbangkok mark', 2),
#  ('proud say repres ireland at2016world univers row champ women senior singl scull',
#   2),
#  ('damn', 2),
#  ('orchid earli morn make smile excit orchidsofinstagram', 2),
#  ('worri', 2),
#  ('imagin posit affirm', 2),
#  ('peppa pig bird lollipop finger famili nurseri rhyme lyric qua', 2),
#  ('nation best friend day', 2),
#  ('archiv thought happi happi content want blog grate wonder', 2),
#  ('good morn goodmorn hello fanci withnewhaircut letsgo oslo norway', 2),
#  ('johnson publish sell eboni jet magazin texa firm chicago tribun', 2),
#  ('jewish group whitewash isra racism ensur fester gaza palestin israel bd',
#   2),
#  ('thursday love alway shine star beauti day', 2),
#  ('first grimmi die orlando shoot world home confus', 2),
#  ('puppi make', 2),
#  ('thank app thank posit', 2),
#  ('inde wisdomoverflowsmcgi million thank god bless forevergr feel', 2),
#  ('bob holman man truli walk walk life well live loss gt gt', 2),
#  ('pretti posit affirm', 2),
#  ('spirit posit affirm', 2),
#  ('like4lik likeforlikealway hour tagsforlik instap instagood instafashion',
#   2),
#  ('morn fight fashionblogg fashionillustr fashionillustr', 2),
#  ('mondaymotiv everyon danc upbeat cardio hip hop routin', 2),
#  ('thank sens touch thank posit', 2),
#  ('antidepress ruin ur nat serotonin u never b wo ur pill', 2),
#  ('coz vid dont mean woh wotch hilari must watc', 2),
#  ('rest peac friend', 2),
#  ('gonna interest upcom epi kuchrangpyarkeaisebhi', 2),
#  ('hate bad dream dream cri', 2),
#  ('harmoni posit affirm', 2),
#  ('popular posit affirm', 2),
#  ('nationalbestfriendsday', 2),
#  ('yal alway wanna b like', 2),
#  ('highest happi eah happi marriag william lyon phelp wed love', 2),
#  ('realli like life live math sad teen', 2),
#  ('success posit affirm', 2),
#  ('thank comfo thank posit', 2),
#  ('life new selfhelp ecours design livinghappi insid', 2),
#  ('glass john lennon wore shot kill new york decemb 8 1980', 2),
#  ('100 follow thank much everyon done without grate muchlov', 2),
#  ('thank internet thank posit', 2),
#  ('motiv video youtub cannot inspir wake earli health fit', 2),
#  ('relax piano music keep pet quiet july4th firework', 2),
#  ('healthi bodi healthi mind product hr', 2),
#  ('cold war fought oil teambt teamsuperjunior allahsoil', 2),
#  ('singl kurd suspens', 2),
#  ('regrann thursday famili', 2),
#  ('osu launch divid commun project', 2),
#  ('oh get lie around hous spout broad work must nice', 2),
#  ('exercis smile today weekend smile exercis fit', 2),
#  ('new plymouth road locat traverwood replac green road store', 2),
#  ('hey tweep check dude', 2),
#  ('jewish talmud bodi work ever written', 2),
#  ('would play', 2),
#  ('thank freedom thank posit', 2),
#  ('seek probe udtapunjab leak point finger amarind aap', 2),
#  ('day guitar chillen write coffe bed music', 2),
#  ('way end end race one race human race', 2),
#  ('repo eng euros2016 notallhooligan', 2),
#  ('excit girl sunday labyrinth girlsnight popupcinema', 2),
#  ('peopl tweet without grammat error copi tweet aicl', 2),
#  ('long stroll harbour reward big gin sunseaandlario', 2),
#  ('work hard pay harder weeknd', 2),
#  ('book readi construct 2016 austin csi construct', 2),
#  ('hispan amp feel like stomp listen retweet boricua miami newyork losangel',
#   2),
#  ('massiv censorship', 2),
#  ('enjoy life', 2),
#  ('onlin sourc system open talk us live websit time broker', 2),
#  ('thank abl rememb thank posit', 2),
#  ('bunch kid twitter new work forc life think rule planet eah lmfao', 2),
#  ('posit', 2),
#  ('kid get parent toddler', 2),
#  ('bestsel inspir golf never go bed without dream wakeup without hope', 2),
#  ('delah made playlist everyon ovehink tn ovehink delahnoch music af blah vibe',
#   2),
#  ('today happi sad lowfat myth bust sad mani suffer year inc angri listen criticis',
#   2),
#  ('happi bihday', 2),
#  ('good night goodmorn rio carioca brasil love day sun fall autumn sky beach',
#   2),
#  ('victori posit affirm', 2),
#  ('friday new histori new outfit post fashion look friendsfluenc', 2),
#  ('team new mc amp show phillysuppophilli amp combat', 2),
#  ('jaymohrspo sometim forget racism amp stereotyp exist peopl like emili austin pop amp oh',
#   2),
#  ('famili babi son boyfriend famili love make memori', 2),
#  ('bihday friend n music director', 2),
#  ('friend', 2),
#  ('bill materi uncov take unleash dazzl oomf gmr creat toolkit', 2),
#  ('happi wor k confer right mindset lead cultur develop organ work mindset',
#   2),
#  ('mark calendar', 2),
#  ('dang', 2),
#  ('long belli ass got shit better make fake page', 2),
#  ('head stratford upon avon suppo xx p', 2),
#  ('happi posit affirm', 2),
#  ('book endur convict fred korematsu amp quest justic humanright ht', 2),
#  ('thank clean sheet thank posit', 2),
#  ('wow awesom', 2),
#  ('tl full ppl vega edc broke', 2),
#  ('lui enjoy medal almost much 1 57 41 soggyfeet thisgirlcan', 2),
#  ('ransom landlord cat look like join us amp exet', 2),
#  ('join essenc life www face care inspir love quot quoteoftheday suppo', 2),
#  ('brave posit affirm', 2),
#  ('gameshow bull hill climb reach target complet task surviv strong excit', 2),
#  ('photo cwp diet essex london weightloss healthi', 2),
#  ('thank sunday thank posit', 2),
#  ('congratul qualifi us jr girl championship proud', 2),
#  ('feel book insid ty pharrellwilliam amp kid love', 2),
#  ('eight way guarante miser happi', 2),
#  ('optimist posit affirm', 2),
#  ('read danc make', 2),
#  ('friday', 2),
#  ('love instagood photooftheday tbt cute beauti followm follow fashion', 2),
#  ('healthi posit affirm', 2),
#  ('tail travel today bu furev home favourit time targovist adoptdontshop', 2),
#  ('hola entrega happi flower lamp acril design likesforlik', 2),
#  ('whatev decid make sure make', 2),
#  ('nashvil tour monday nashvilleontour', 2),
#  ('monopoli will ignor govt barbar deepli shame refuge', 2),
#  ('ha ppi work confer right mindset lead cultur develop organ work mindset',
#   2),
#  ('rip lvl 93 almost 94 shield charger 20 ex 20 second delay mob around lag sta',
#   2),
#  ('rock logo audiojungl soundclip royaltyfreemus', 2),
#  ('origin illustr miss sword truth inspir kahlan si jankala', 2),
#  ('tgif ff gamer squad', 2),
#  ('hungri long time make irrit scienc', 2),
#  ('believ', 2),
#  ('thought factori left right polaris trump uselections2016 leadership polit brexit blm 13',
#   2),
#  ('us know dont care destruct wrong inform bring', 2),
#  ('photoshop bull domin bull direct whatev want yo', 2),
#  ('4day left releas new music suit get readi anoth bang', 2),
#  ('vehicl gorilla simul need adapt environ need tear citi materia', 2),
#  ('time call neonazi minim hate antisemit need', 2),
#  ('nigger lifelesson white kid grew 60 blogpost whitepeopl respect', 2),
#  ('year 4 way', 2),
#  ('true', 2),
#  ('korea gorilla simul need adapt environ need tear citi materi', 2),
#  ('happi weekend weekend friday success natur flower life good kuwait', 2),
#  ('feel children stori recogn express manag sad par', 2),
#  ('bypo echocid waterislif poetri poem solidar nodapl climatejustic climatechag epa classwar',
#   2),
#  ('facebook 22nd rm day 2015 day btsrmday2015', 2),
#  ('eah motiv anyon walk night club slaughter innoc peopl world gone mad', 2),
#  ('happi worldginday line alreadi gin rhubarb', 2),
#  ('thank celebr thank posit', 2),
#  ('delay tactic sit bjp 1984 riot', 2),
#  ('magic tidi brenda palmer goodread amazon read declutt', 2),
#  ('100 amaz health benefit cucumb healthi doplant', 2),
#  ('thank puppi thank posit', 2),
#  ('allahsoil riyadh renown deadliest traffic world', 2),
#  ('littl need make life within way think', 2),
#  ('thank farmer farmer market thank posit', 2),
#  ('calm posit affirm', 2),
#  ('born life purpos god children', 2),
#  ('unproduct today', 2),
#  ('join snapchat music smule like4lik likeforlik', 2),
#  ('reliabl posit affirm', 2),
#  ('father day father', 2),
#  ('state affair', 2),
#  ('surpris adam saleh david wood', 2),
#  ('fathersday father day craft beer amp kitchencraft beer amp kitchen buy', 2),
#  ('western academ taught wrong thing', 2),
#  ('emma leav fri oz want go free food friday easesthepain lovinreward', 2),
#  ('simpl thankyou take custom market socialmedia wahm', 2),
#  ('miss acapitolfouh 8 7 central 4thofjuli uscapitol july4thpb', 2),
#  ('look good birmingham', 2),
#  ('truth posit affirm', 2),
#  ('sunset islamorada beachtim swim boatday beautifullsunset love', 2),
#  ('thank tear thank posit', 2),
#  ('omg priyankachopra admit face hollywood read insid know detail bollywood gossip',
#   2),
#  ('smoker bill leak sticker help avoid think abt smoke', 2),
#  ('let us pray orlando', 2),
#  ('love four book togeth catalogu author', 2),
#  ('craig famili silenceiscompl theresist fascism', 2),
#  ('happi monday everyon let make good week mondaymotiv freshsta healthi', 2),
#  ('wait ryan go main hous bbuk', 2),
#  ('retweet love healthi brain healthi', 2),
#  ('walker run', 2),
#  ('insid home orlando terrorist omar mateen loser belief fanat islam cultur anger',
#   2),
#  ('sad', 2),
#  ('want via joy life time', 2),
#  ('never understand peopl colleg come back hang ppl high school', 2),
#  ('need address dehumanis amp stereotyp tackl employ gap peopl disabl', 2),
#  ('want happier ask simpl question everi morn', 2),
#  ('count day make day count spring memori flower vine', 2),
#  ('jacksonvil rooster simul want climb vast expans mountain reach leakag co',
#   2),
#  ('angel death pleas stop ripkeshi earlier ripamodushuaibu repoedli die chest pain',
#   2),
#  ('nation ice tea day celebr offer delici blend tea', 2),
#  ('activ posit affirm', 2),
#  ('swnyc sta swepari', 2),
#  ('st coz vid dont mean woh wotch differ hilari', 2),
#  ('bride woman fine prospect happi behind ambros bierc wed love', 2),
#  ('10 step sell structuredsettl read share home write vitorr staup live usa england hous',
#   2),
#  ('live world rape enabl guy coach footbal', 2),
#  ('sinist aspect amp goal endem bjp govt punjab', 2),
#  ('damn believ shot kill conc thevoic', 2),
#  ('beauti frame 2 michaelfassbend jamesmcavoy cherik mcfassi mcavoy shipper au flim',
#   2),
#  ('eur gbp deflat high back 0 7920 blog silver gold forex', 2),
#  ('2play maison johnni w', 2),
#  ('fuck anoth one faggot asscunt big strapon', 2),
#  ('racist pay ever', 2),
#  ('indic far fallen', 2),
#  ('kidsbook 12 stori 0 99 anim friendship adventur iag bookboost', 2),
#  ('help rumi peac love life happi', 2),
#  ('happi father day 2016 dad dad father day 2016', 2),
#  ('abund posit affirm', 2),
#  ('plenti prep go launch night launch final thehelenblak', 2),
#  ('lucki posit affirm', 2),
#  ('makeup much money make race bait', 2),
#  ('might well get use kind respons abt especi continu cater yo', 2),
#  ('devast journalist misogyni amp rode journalist integr press despis', 2),
#  ('studiolif aislif requir passion dedic willpow find newmateri', 1),
#  ('white supremacist want everyon see new bird movi', 1),
#  ('hp curs child book reserv alreadi ye harrypott pottermor favorit', 1),
#  ('3rd bihday amaz hilari nephew eli ahmir uncl dave love miss', 1),
#  ('choos momtip', 1),
#  ('someth insid die eye ness smokeyey tire lone sof grung', 1),
#  ('finish tattoo ink ink loveit thank aleee', 1),
#  ('delici food lovelif capetown mannaepicur restur', 1),
#  ('1000dayswast narcosi infinit ep make awar grind neuro bass lifestyl', 1),
#  ('one world greatest spo event lemans24 teamaudi', 1),
#  ('half way websit allgoingwel', 1),
#  ('good food good life enjoy call garlic bread iloveit', 1),
#  ('stand behind guncontrolpleas senselessshoot takethegun comicrelief stillsad',
#   1),
#  ('ate ate ate jamaisasthi fish curri prawn hilsa foodfestiv foodi', 1),
#  ('got limit edit rain shine set today', 1),
#  ('amp love amp hug amp kiss keep babi parent healthcar', 1),
#  ('girl sun fave london unit kingdom', 1),
#  ('thought factori bbc neutral right wing fascism polit media blm brexit trump leadership gt 3',
#   1),
#  ('hey guy tommorow last day exam happi yay', 1),
#  ('levyrroni recuerdo memori recuerdo friend life triunfodelamor', 1),
#  ('mind like bodi like sleepi stillallin', 1),
#  ('never entir life', 1),
#  ('check twitterww trend trend worldwid 11 14 bst 1 oscarpistorius2 diplom liselilerayakta3',
#   1),
#  ('thought saw mermaid ceege smcr inshot girl cute summer blur sun', 1),
#  ('chick get fuck hottest nake ladi', 1),
#  ('happi bday luci xoxo love beauti pizza instagood mileycyru demilovato', 1),
#  ('haroldfriday weekend fill sunbeam everyon healthi weekend', 1),
#  ('tri noth tri know love 2 3rd light fave amp deep river', 1),
#  ('never 120 thick women blacktina', 1),
#  ('new episod tk realli cool 2 year anniversari ep work august', 1),
#  ('orangechicken attack bull game 3d realli think head empti around citi side',
#   1),
#  ('suppo taiji fisherman bulli racism tweet4taiji thecov seashepherd', 1),
#  ('say speak collect alway known 2016 show lot', 1),
#  ('wish could talk', 1),
#  ('food time hayli hot chocol mummi thank god friday', 1),
#  ('bihday shilpashetti wish success yearretail manufactur ladi cloth', 1),
#  ('lotteri', 1),
#  ('tomorrow fun see old friend shoot someth super fun', 1),
#  ('trump invest billion saudi empow peopl fund isi trumpsahypocrit', 1),
#  ('granddaught 1st bihday tomorrow go pick play hous littl car amp pool today',
#   1),
#  ('happiest place eah disneyworld orlando castl mickeymous likechildren', 1),
#  ('babi dave due born octob 26 fav band time tool play weekend lol', 1),
#  ('love everi day', 1),
#  ('morn sunshin smile sexi bigboob', 1),
#  ('world make jesu make happi john 16 33 word truth faith peac', 1),
#  ('enjoy sunshin god good orlando sunshinest goodlif bossladi joy', 1),
#  ('father idol prg', 1),
#  ('reason maintain android provid clear basic code exampl doc', 1),
#  ('nice luxuryweek monday neweek luxuryweek bestday stayposit fun goodmoment lifestyl',
#   1),
#  ('caus get live togeth whole week cantwaittocook', 1),
#  ('throw back thursday bih day 2 bro chege', 1),
#  ('saw cray coz babi hard breath strong yeah babi god kaika medic center', 1),
#  ('happen babi duedec2016', 1),
#  ('let thing euro2016', 1),
#  ('time euro2016 onemonth 24team onewinn footbal intern 10thjune 10thjuli', 1),
#  ('good sunday everyon sunday morn smile picoftheday', 1),
#  ('cousin ask alway shawl di ko lang masabi coz po get fat braso get bigger baboy',
#   1),
#  ('believ r willing 2 tri 2 understand 2 encourag amp 2 inspir other 2 b amp grow greater spiritu purpos grok',
#   1),
#  ('time pint see coldplay wembleyyyi coldplay wembleystadium', 1),
#  ('current mood goodnight happilyeveraft disney quot bless thank grate', 1),
#  ('chioma nobl igw special day chobs16 chobs2016 landmark centr', 1),
#  ('cant believ left school 5 year ago 8 week time ill teach class drama teacher gettingold',
#   1),
#  ('lipo light help shape help shape learn loseinch burnfat result', 1),
#  ('ahhh leav tomorrow eforest2016 electricforest plur', 1),
#  ('bless hear morn choru good morn peopl friday', 1),
#  ('aunti mi find hilari post nigeria enough troubl', 1),
#  ('6 chapter left book amp nearli complet kruella adaughterstal hard read emot funni',
#   1),
#  ('thrill work come month announc soon 2faceddancecompani', 1),
#  ('tri anoth way make sourdough bread one may underproof fail bake', 1),
#  ('cool old door window 50 00 vendor 509 shoploc shopalyssa fathersday', 1),
#  ('fathersday fatherday team', 1),
#  ('greatbritain eye sky rafredarrow fli past mall say', 1),
#  ('8000 follow bless love everyon suppo us thx much fish f', 1),
#  ('lt feed public trough piggi michelleobama', 1),
#  ('websit live avon makeup fresh look', 1),
#  ('forecast look good weather across bolton', 1),
#  ('happi shoot love monica sweet magazin thanku love', 1),
#  ('happi father day father day fathersday dad ilovemydad ilovemyfath love', 1),
#  ('stardivariu friday new histori new outfit post fashion look friendsfl', 1),
#  ('final countdown offici us public june 1st whyfontsmatt usa typographi font book',
#   1),
#  ('happi trust first know lovelovelovebabi', 1),
#  ('interview feat grandmast flash ze love messag nurap nudisco music pari via',
#   1),
#  ('get hour work train', 1),
#  ('life right amaz success posit', 1),
#  ('social media realiti realli get viual accept seem realli thing ocialmedia',
#   1),
#  ('seven tomorrow southwestseason final next week plu scrim wearebusi', 1),
#  ('ignor amp ill inform tweet r silli childish amp one dimension', 1),
#  ('great see look forward welcom digm', 1),
#  ('jackblair na horni hot naughti nasti slut young shi wet nude xxx sexi porn kinki snapshot',
#   1),
#  ('u take pour one big cup drink deliv', 1),
#  ('happi father day dad hope u great day love u fathersday lovey', 1),
#  ('work anatomi studyguid sinc 5 pm still done isuck plspassm', 1),
#  ('worri daydream sunlight thunder miss dream distanc silenc pain sweet', 1),
#  ('get readi kubamba father day kambua noel gg moh bless', 1),
#  ('ya know guy feel stress donut thing feel happi know 96 follow stick', 1),
#  ('pa 2 jk fun memori bff love', 1),
#  ('back peopl missingperson havingfunalon lone hothl', 1),
#  ('l v e sky photoofday moment cool instaphoto paradis good mexico', 1),
#  ('happi saturday tune music saturday edm', 1),
#  ('mani alum friend wake shock hear death scsu presid shock', 1),
#  ('disappoint yesterday argument even baselessli accus live mother basement weak bad',
#   1),
#  ('hey 14000 ivanka bracelet feel good profit xenophobia misogyni hatr grabyourwallet',
#   1),
#  ('love saw temporari setup', 1),
#  ('happi euro 2016 eve euro2016', 1),
#  ('colourpop', 1),
#  ('palladino say feel like say gopathet lookwhatyoudid polit madcow', 1),
#  ('fursuit fuck hardcor 2008', 1),
#  ('someth obvious realli funni laugh girl smile', 1),
#  ('fbf sta far come amp anxiou', 1),
#  ('thank film thank posit', 1),
#  ('alway alway alway somebodi els fault bigot', 1),
#  ('turn today whitegirlwast dramafre armedsecur', 1),
#  ('qatil poetri poetri eid poetri 2 line sm eid ghazal urdu poetri dard poetri beuti poetri follow send 4o4o4',
#   1),
#  ('rip victim usa prayfororlando terror victim lgbt suppo altogeth pride stand',
#   1),
#  ('read aicl 4 yr even dhaba side nation highway grow 1 2 acr ganja', 1),
#  ('drive see greas amp footloos', 1),
#  ('thank steve think quit sunk though', 1),
#  ('today good day happiestplaceoneah disneyland fun walk sundayfunday', 1),
#  ('ltpst need vitamin sea beach blue smile', 1),
#  ('today code white summer love', 1),
#  ('rainbow wall street good way end train officialrainbowspott', 1),
#  ('water', 1),
#  ('go great day day choic matter feelinggood proud feelingaccomplish motiv',
#   1),
#  ('oh ton stuff like eah garbag dump', 1),
#  ('found vault never post selfi throwback boy guy love', 1),
#  ('happi friday wegotwheel car vw polo firstcar ontheroad whitepolo newcar',
#   1),
#  ('togeth christma pl amp follow nation day action 20 feb amp', 1),
#  ('withasumi yesterday shot disney disneyland enjoy', 1),
#  ('game throne s5 longer sky box set mad help', 1),
#  ('straight chaser music video', 1),
#  ('4u nonhockey peopl hockey babe ruth die gordi howe beyond myth legend hockey lost mr hockey',
#   1),
#  ('linkedin anyth work give free membership canadian australian british veteran justusvetsatm',
#   1),
#  ('michelleobama look bit dishevel think spend retir visit obama', 1),
#  ('dinner lukey boy lovehim holiday orlando clear creek circl', 1),
#  ('wait watch everyon even', 1),
#  ('hahaha good point total skip 14 celebr dad ask', 1),
#  ('cat bag fruit ninja steam htcvive', 1),
#  ('nation german bestfriend day mayb', 1),
#  ('realli good cook credit mash potato mac n chees', 1),
#  ('local mp downgrad hospit savethealex', 1),
#  ('pretti much best advic ever hydrat zerofucksgiven friday sorrynotsorri live',
#   1),
#  ('model altern tattoo pierc old town bellevu', 1),
#  ('sent msg aunt peru told wish grandpa uncl happi father day includ dad', 1),
#  ('day best', 1),
#  ('work attorney white offic shot philandocastil remov black judg presid trial',
#   1),
#  ('phil spencer critic soni cours els would got slap face soni huge 40 million dick',
#   1),
#  ('think sa pretti great wait show twodaystogo countdown shhh bringiton', 1),
#  ('w cafeexpress stanupcomedi crazi', 1),
#  ('happi mother day ppl', 1),
#  ('bff liverpool first stop flatwhit coffeelov bestfriend', 1),
#  ('tom hiddleston aka loki excus spell new jamesbond scaryinthor bestchoicefornewjb',
#   1),
#  ('watch movi alon', 1),
#  ('one think could bit punch gameofthron', 1),
#  ('princess one princess sadli', 1),
#  ('cant wait icon weekend wait final get one tatoo icon16', 1),
#  ('laugh fact mfz use app talk u feel insid peopl see haha', 1),
#  ('sterl attack bull chase leav lot despit fact strong sourc fo', 1),
#  ('never doubt pa mani vote sad america', 1),
#  ('cut anyon english dna half well find written insid', 1),
#  ('vip ciniworld caz', 1),
#  ('see war craft imax 3d warcraftmovi imax woohoo', 1),
#  ('look right cameraman grab kati arm amp said talk wow everyth tv', 1),
#  ('held one march great cpd everyon', 1),
#  ('look african news boredem stumbl upon oh god site racist fuck everyth', 1),
#  ('dana devest troubl', 1),
#  ('gorgeou posit affirm', 1),
#  ('happi instagram instagood instagram instapasspo instadaili', 1),
#  ('splash around dog bestdogev swim healthi goodvib yoga fit', 1),
#  ('peopl old bore resolv bulli other twitter', 1),
#  ('much violenc last euro wonder happen brutal side come back euro2016 footba',
#   1),
#  ('mess nail', 1),
#  ('selfi srelfi smile selfi followm f4f polishgirl polskadziewczyna', 1),
#  ('vera rubin overcam invent whole field scientif studi diversityinsci scienc steam',
#   1),
#  ('sorri read much pain', 1),
#  ('draft 1 b4 pick uni liverpool recognit', 1),
#  ('gbp usd upsid limit around 1 4255 1 4350 commerzbank blog silver gold forex',
#   1),
#  ('childrenoftheworld bull domin bull direct whatev want', 1),
#  ('kaya class', 1),
#  ('london selfi smile love photooftheday picoftheday london londonlif', 1),
#  ('need prayer right take grandma death well shock whyher', 1),
#  ('seen gay gorilla mindset nonsens tout dershowitz clean', 1),
#  ('think go best match ever watch wed oldgirl auwfc', 1),
#  ('unfoun current gop see reagan like', 1),
#  ('monday instagram instagramm motorspo photograph formula1', 1),
#  ('great day littl man tkd grade amp crack swim lesson top wale win wal', 1),
#  ('sorri bear time', 1),
#  ('wait pubcon bestconfer oct16 digitalmarket comingsoon', 1),
#  ('monday u model boob tit urbex televis sexi retweet tight pantyhos desir touch',
#   1),
#  ('glad live place', 1),
#  ('fam ili fast famili likeforlik like4lik lfl togeth happi love', 1),
#  ('starship nickiminaj 6secondcov singitfohevin singersofvin sing musician music',
#   1),
#  ('make someon happi today mind damn busi life live inv busi love', 1),
#  ('paradis rooster simul want climb vast expans mountain reach leakag cock w',
#   1),
#  ('pats2020 student want snapchat adrianmcqueen snapchat ucumberland colleg',
#   1),
#  ('client need brainstorm socialmedia altrincham', 1),
#  ('disney gator attack 2 year old boy found dead disney', 1),
#  ('price stolen payment card record drop 25 2011 6 2016 ransomwar rise', 1),
#  ('got free slice cake fav cafe tgif', 1),
#  ('box pictur contain singl inflat prep school boy sex doll', 1),
#  ('relax peac', 1),
#  ('first new custom paner drupa2016 hall 10 stand c13 3', 1),
#  ('sinc last time drank hard liquor officem', 1),
#  ('older peopl see pic nose rememb smell close impoant site like', 1),
#  ('socialmedia may 2016 hottest may record nasa', 1),
#  ('say abl attend year due hotel cost hope attend next year tho', 1),
#  ('hea spazz ship hahaha doctor', 1),
#  ('nearli readi nohamptoncarniv', 1),
#  ('mani innoc peopl die ceain politician choos ignor hate refus even discuss gun control',
#   1),
#  ('almost week sinc saw stroke', 1),
#  ('sta newbook visit jfk museum inspir', 1),
#  ('fatal truck crash kigali highway leav 30 peopl die instantli around kicukiro centr rwanda',
#   1),
#  ('marshmallow time fire son love', 1),
#  ('believ much use care peopl thought like lol fuck u fuck wtf fuck', 1),
#  ('jealou best mother mamatii je aim cute nice', 1),
#  ('alway amaz come unexpect place like local cafe today irish got first muslim gut',
#   1),
#  ('icedcoffe coffeeblogg coffe thecappuccinotravel', 1),
#  ('ever get lyme war yeah help', 1),
#  ('p5 pupil readi ymi music extravaganza', 1),
#  ('made laugh hard angri bieber dontknowwhi fridayfun', 1),
#  ('usd jpi bull sit tight 107 handl fxstreet blog silver gold forex', 1),
#  ('fail terribl control drug must punish elector let initi blue fb', 1),
#  ('never see store anymor ask autograph said hi time', 1),
#  ('rest peac christina rip ripchristina christinagrimmi love miss', 1),
#  ('alway watch one race inspir train still got solid month yet 1st race', 1),
#  ('see pictur dog today smile face tweet good', 1),
#  ('woke af realiz world around chang sigh', 1),
#  ('love return coollim starbuck cool lime feel fresh nice great drink', 1),
#  ('could wors embarrass unfoun traumat bitch black live matter black peopl',
#   1),
#  ('tech buy bitcoin debit card', 1),
#  ('happi father day father fathersday sunday famili', 1),
#  ('still fuck bullshit give bigot platform spread vile hate boy', 1),
#  ('girl boy p sissi', 1),
#  ('bihday flower saturday flower love je b jewelri studio', 1),
#  ('even think wear dad jean', 1),
#  ('anoth nerd friend ban person believ snotopenmind ohwel', 1),
#  ('alway race religion wrong w america', 1),
#  ('sometim take realiz person realli fit life friend soon boss', 1),
#  ('back day job shane lowri gt gt', 1),
#  ('fathersday strongest patient kind understand person know', 1),
#  ('third wheel cold stone right use buy one get one free coupon', 1),
#  ('simpli assault equal spit someon author got charg wrong guy walk', 1),
#  ('get tweet marriag wale', 1),
#  ('make meer inspirati kijk op life', 1),
#  ('hous taken footbal time get read alway love book', 1),
#  ('cleveland fan look', 1),
#  ('get readi deliv featur address bright eye group youngster nervou', 1),
#  ('smoothi glass half full comeon', 1),
#  ('wednesdaywisdom make sure ignor true happi life', 1),
#  ('trust broken right', 1),
#  ('iftar happyhous besti friend chillin iftar goodtim tgi friday street', 1),
#  ('realiz look littl cross eye licens lol', 1),
#  ('go fun week 10 day csikraken construct', 1),
#  ('bihday sweet littl mermaid time flown quickli believ', 1),
#  ('30 000 arrest daili us 160 000 polic civilian encount daili shoot abus extrem rare tho',
#   1),
#  ('thank inspir thank posit', 1),
#  ('wish kpop aist never come countri abl see perform broke ppl kpop', 1),
#  ('want go anywher sunday sinc ghosthuntersintern destinationtruth chillernetwork',
#   1),
#  ('peopl judg colour english accent', 1),
#  ('9975 lostnfound got togeth want seriou long term monogam relationship', 1),
#  ('cc without aciiii eki liani fetti cc emerg team friend famili like love',
#   1),
#  ('black live matter today day', 1),
#  ('usd jpi remain weak 106 00 blog silver gold forex', 1),
#  ('charact custom confirm pokemonsunmoon e32016', 1),
#  ('emma great meet yesterday email oppoun alreadi', 1),
#  ('poor babe miss water play morn school figur water play afternoon poorbabi',
#   1),
#  ('let light hmmm prefer l spotlight vibrant aliv joy sparkl', 1),
#  ('today good day love goodday smile goodangl instasmil instagram', 1),
#  ('realli terribl mass terrorist attack usa night club black day', 1),
#  ('hear bigotri homophobia sexual assault woman treason lie hear', 1),
#  ('right one suppo women nutrit romanc love date soulmat sexi', 1),
#  ('hate crisi among mani other presid elect amp co capabl', 1),
#  ('wonder saturday flower day vine', 1),
#  ('guess chip hill teach kid spell mp might littl hard u', 1),
#  ('got wine v happi', 1),
#  ('deserv much better understand endors stand much', 1),
#  ('thank reach issu resolv turn site fulli compat safari io maco', 1),
#  ('happi bday jb yesterdaycelebr fambam feel happi', 1),
#  ('bihday libat feat gay boy cute friend love', 1),
#  ('bihday majesti', 1),
#  ('sleep cri', 1),
#  ('live color check new tote bag color life totebag inspir ht', 1),
#  ('thank much realli feel amaz', 1),
#  ('pimp hoe hooker point documentari brent owen cathous seri kid lol', 1),
#  ('goomespa divulga oeparceria inshot girl cute summer blur sun fun dog hair',
#   1),
#  ('sad true true', 1),
#  ('anim cat cat grumpi cat happi camper treat play', 1),
#  ('aww poor ednahhthepug missingmommi sit wait time', 1),
#  ('nice deliveri today manfrotto peakdesign photo photographi tripod strap bag',
#   1),
#  ('smile filter instamood picoftheday behealthi summer bliss bitchpleas', 1),
#  ('pre order 3d browton beautyblogg icantwait', 1),
#  ('luther vandross danc father father day', 1),
#  ('enslav anim okay', 1),
#  ('dark', 1),
#  ('ah man sunday come round quick enough thestoneros', 1),
#  ('got first liquid lipstick love girl', 1),
#  ('first bubbl 40yr old self champagn celebr thank pete gemini bihday inde',
#   1),
#  ('patriotwatch 4 11 sherm new year gap auspol rwnj drunk refuge asylum', 1),
#  ('accept fact appl lost innov sta rip android', 1),
#  ('shock amp hear christinagrimmi past away thought amp prayer rwith famili time ripchristina',
#   1),
#  ('hey love music realli perform murder azerbaijan dictatorship', 1),
#  ('new ted baker ski top surpris hubbi lucki loa lawofattract', 1),
#  ('love hello kitti model pink girl girli yolo smile pop', 1),
#  ('ur gunna miss', 1),
#  ('meet today volunt run local librari went kid givingback pocintech', 1),
#  ('whenev sad close eye rememb happiest moment life life lifequot thought', 1),
#  ('wait see iron maiden first time next sunday', 1),
#  ('never previou secretscreen starmoviessecretscreen shh come', 1),
#  ('mikoto suoh kproject mikoto vine cassidytheduck', 1),
#  ('thought factori left right polaris trump uselections2016 leadership polit brexit blm gt 17',
#   1),
#  ('biographi step cousin denis got ear mite use payphon', 1),
#  ('4 merri behappyandsmil behappyandsmilealway behappywithm likesm', 1),
#  ('go eat shit dog anti american piec shit bet dad fuck mouth trump nazi', 1),
#  ('realli happi graduat childish shit graduat done', 1),
#  ('would live life grate compass love one anoth without', 1),
#  ('mani hash tag', 1),
#  ('huaweiceifiedspecialist pre sale accessnetwork deliv ye stress sno', 1),
#  ('look forward bean caramel macchiato definit burnt memburi servic', 1),
#  ('oh word think awar ghastli there someth broken soul need', 1),
#  ('tap gratitudejourn benefit without journal entri pressur gratit', 1),
#  ('suppos confirm even read teleprompt', 1),
#  ('great screw job 2016 cannot catch break impactonpop impactwrestl', 1),
#  ('tomoz nite hit stoke go fab night glad im go besti 3rdr', 1),
#  ('last formteach lesson byebye8year', 1),
#  ('care care alon', 1),
#  ('way door counti wisconsin weekend vacat car foreverdr indi travel vacati',
#   1),
#  ('poor world', 1),
#  ('realiz laker fan make u hate everi western confer team cant root 4 dub impetti lakers2017 kobe',
#   1),
#  ('mind boggl dontunderstandtheconswqu', 1),
#  ('like true fals stephen keshi die na waoh life eh one thing dey rememba abt say dey alwaz chew gum',
#   1),
#  ('trigger impuls decis strike haha netherworldforess tier 1', 1),
#  ('alway ministradesanidad', 1),
#  ('singl word requir wast everyth wha actual', 1),
#  ('mercuri engin amp mercuri cloudcov truli attend prestigi event data datacentr',
#   1),
#  ('cant alway alway posit inspir gepaforum', 1),
#  ('tbt capetown tablemountain dad ghel bakh bihday lafamilia', 1),
#  ('new tenant collect key 9am propeyh move apament', 1),
#  ('see u soon stratton u attend come find us wanderlust fashion', 1),
#  ('think happi stay happi', 1),
#  ('wait join us garden walk', 1),
#  ('ye today day get giddi orangeisthenewblack season4 obsess', 1),
#  ('slfl conc week away x', 1),
#  ('saturday peopl hope hungov listen newsong band unsign', 1),
#  ('recogn amp acknowledg relationship god give need succeed', 1),
#  ('book tick see cha amp dave wait', 1),
#  ('wonder wifi work anymor wifi wifiproblem wifioverload wifisuck suck network',
#   1),
#  ('idea stupid comment make invit respons death sideshow', 1),
#  ('check daddydub super father day u 1 best father 4 gr8t', 1),
#  ...]

# %% [markdown]
# Through This We can find most_common tweets

# %%
X_train = X_train.drop_duplicates(subset='tweet', keep='first', inplace=False, ignore_index=False)
X_train
# Out:
#           id  label                                              tweet
# 0          1      0      father dysfunct selfish drag kid dysfunct run
# 1          2      0  thank lyft credit use caus offer wheelchair va...
# 2          3      0                                     bihday majesti
# 3          4      0                        model love u take u time ur
# 4          5      0                            factsguid societi motiv
# ...      ...    ...                                                ...
# 31956  31957      0         fish tomorrow carnt wait first time 2 year
# 31957  31958      0                                      ate isz youuu
# 31958  31959      0  see nina turner airwav tri wrap mantl genuin h...
# 31959  31960      0           listen sad song monday morn otw work sad
# 31961  31962      0                                       thank follow
#
# [28262 rows x 3 columns]

# %%
#For_Removed_Duplicate_Train_Data
from collections import Counter
occurrences= Counter(X_train['tweet'])
occurrences.most_common()
# Out:
# [('father dysfunct selfish drag kid dysfunct run', 1),
#  ('thank lyft credit use caus offer wheelchair van pdx disapoint getthank', 1),
#  ('bihday majesti', 1),
#  ('model love u take u time ur', 1),
#  ('factsguid societi motiv', 1),
#  ('2 2 huge fan fare big talk leav chao pay disput get allshowandnogo', 1),
#  ('camp tomorrow danni', 1),
#  ('next school year year exam think school exam hate imagin actorslif revolutionschool girl',
#   1),
#  ('love land allin cav champion cleveland clevelandcavali', 1),
#  ('welcom gr8', 1),
#  ('ireland consum price index mom climb previou 0 2 0 5 may blog silver gold forex',
#   1),
#  ('selfish orlando standwithorlando pulseshoot orlandoshoot biggerproblem selfish heabreak valu love',
#   1),
#  ('get see daddi today 80day gettingf', 1),
#  ('cnn call michigan middl school build wall chant tcot', 1),
#  ('comment australia opkillingbay seashepherd helpcovedolphin thecov helpcovedolphin',
#   1),
#  ('ouch junior angri got7 junior yugyoem omg', 1),
#  ('thank paner thank posit', 1),
#  ('retweet agre', 1),
#  ('friday smile around via ig user cooki make peopl', 1),
#  ('know essenti oil made chemic', 1),
#  ('euro2016 peopl blame ha conced goal fat rooney gave away free kick know bale hit',
#   1),
#  ('sad littl dude badday coneofsham cat piss funni laugh', 1),
#  ('product day happi man wine tool weekend time open amp drink', 1),
#  ('lumpi say prove lumpi', 1),
#  ('tgif ff gamedev indiedev indiegamedev squad', 1),
#  ('beauti sign vendor 80 45 00 upsideofflorida shopalyssa love', 1),
#  ('smile media pressconfer antalya turkey sunday throwback love', 1),
#  ('great panel mediat public servic ica16', 1),
#  ('happi father day', 1),
#  ('50 peopl went nightclub good night 1 man action mean peopl lost famili forev rip orlando',
#   1),
#  ('never chanc vote presidenti candid excit cycl look differ', 1),
#  ('alohafriday time exist positivevib hawaiian', 1),
#  ('rip fellow nohern ireland fan sadley pass away tonight gawa forev sing cheer fire',
#   1),
#  ('hard monday due cloudi weather disabl oxygen product today goodnight badmonday',
#   1),
#  ('unbeliev 21st centuri need someth like neverump xenophobia', 1),
#  ('taylorswift1989 bull domin bull direct whatev want w', 1),
#  ('morn travelingram dalat ripinkylif', 1),
#  ('one word tell photoshop enoughisenough dontphotoshopeveryth wheresallthenaturalphoto',
#   1),
#  ('oh cedarpoint wait 2 hour valravn line stop work close', 1),
#  ('thank sunshin thank posit', 1),
#  ('final finish book work awhil bookworm ontothenextnovel', 1),
#  ('yup knick fan hard easier nba fan playoff roll around', 1),
#  ('life social network embrac day', 1),
#  ('mom share bihday bihday snake see weekend', 1),
#  ('love echeveria bloom flower grow garden iphonesia bliss bloom basilicabotanica',
#   1),
#  ('amaz posit affirm', 1),
#  ('whenev im someth goe wrong', 1),
#  ('feel blue illustr', 1),
#  ('best pa life know', 1),
#  ('abc2020 get readi 2 remov victum frm pulseclub prayfororlando', 1),
#  ('bihday got nose job bihday petunia love', 1),
#  ('concelebr albanpilgrimag first time', 1),
#  ('let scum baggeri begin', 1),
#  ('thank super love zpamdelacruz wed dolor capa tarlac', 1),
#  ('scourg play baroqu piec piano beyond belief', 1),
#  ('let fight love peac', 1),
#  ('happi father day mr rayo video father day rayo world hotvideo video', 1),
#  ('ascot time babe ascot fashion monochrom style instahappyday', 1),
#  ('weekend selfi yolo xoxo like4lik', 1),
#  ('happi work confer right mindset lead cultur develop organ work mindset', 1),
#  ('christina grimmi last perform shot via christinarip voic christinagrimmi',
#   1),
#  ('readi danc roar preschool student proud', 1),
#  ('realli hu feel', 1),
#  ('wife ador miss poland show surgeri name bridget amp everyth', 1),
#  ('jealou right chatiado', 1),
#  ('celebr everi man play fatherli role father day', 1),
#  ('sure happi hour', 1),
#  ('white establish blk folx run around love promot great', 1),
#  ('good morn journey begin travel yeah thejourneybegin hello', 1),
#  ('luv hottweet like venusexchang', 1),
#  ('new brochur arriv excit awork solut', 1),
#  ('much stuff happen florida first orlando shoot disneygatorattack two year old kid',
#   1),
#  ('ferrari sake championship gp clearli turn point rb ferrari merc', 1),
#  ('ace first test proud', 1),
#  ('seek probe udtapunjab leak point finger amarind aap', 1),
#  ('wrap senseaboutmath 6th', 1),
#  ('hey white peopl call peopl white race ident med', 1),
#  ('might shown today regurgit talk point name call', 1),
#  ('sometim rais brow rais bar golfstrengthandcondit strong felixfoisgolf', 1),
#  ('greathonour careerconvo', 1),
#  ('design innov learn space includ wateringhol cave mountaintop campfir h', 1),
#  ('altright use amp insecur lure men whitesupremaci', 1),
#  ('carri gun help take gun control stop black market terror get wors', 1),
#  ('use power mind heal bodi altwaystoh healthi peac', 1),
#  ('woohoo 5 week go', 1),
#  ('far away place famili member hu', 1),
#  ('readi rehears tonight new music new video look announc midweek newmus watchthisspac guitar',
#   1),
#  ('monday night 8pm channel final get see fuss', 1),
#  ('watch new episod', 1),
#  ('offlin nice long night snapchat redhead vermillionr', 1),
#  ('15 thing incred peopl', 1),
#  ('ye receiv accept letter master back octob goodtim histori', 1),
#  ('daughter ride bike around driveway son play guitar us enjoy campfir summeim memori',
#   1),
#  ('omg love station way jam work get work done cours memori', 1),
#  ('alway hope one day get hug think gonna happen anytim soon', 1),
#  ('coupl sex fat nake japanes girl', 1),
#  ('hump hump day humper edwardsvil pennsylvania', 1),
#  ('personalis gbp 7 99 get shop cool home fun', 1),
#  ('truli sick ppl', 1),
#  ('trump call obama resign orlando shoot boy point 8 year talk chang', 1),
#  ('long nashvilletour2016 nashvilleforev', 1),
#  ('eur usd clear 1 1400 barrier jump fresh 4 week high blog silver gold forex',
#   1),
#  ('go la tomorrow', 1),
#  ('thank good friend thank posit', 1),
#  ('still wrap head around fact christinagrimmi gone fact man destroy prayfororlando',
#   1),
#  ('receiv di wait sta bake eyelid', 1),
#  ('play vigilfororlando harp clonakilti rip via', 1),
#  ('ye ye ye ihavenofriend someonecomewithm', 1),
#  ('sunday weekend relax icon woman sundaymorn sunday marilynmonro', 1),
#  ('interest linguist address race amp racism power raciolinguist bring', 1),
#  ('one belov long lost cd recov thank appl music', 1),
#  ('marvel song musica weed ripchristina adel danc vine', 1),
#  ('mock obama black brexit', 1),
#  ('spell brexit referendum commerzbank blog silver gold forex', 1),
#  ('100 amaz health benefit cucumb healthi altwaystoh', 1),
#  ('work ofw pinoy followm iger instagood smile love', 1),
#  ('toradora anim animeedit made breakup alon lone', 1),
#  ('50 lap pool 10k ride done pick gym membership form', 1),
#  ('cotd polar bear climb race angri polar bear climb race polar bear live cold place look',
#   1),
#  ('get angri muslim assassin 50 much', 1),
#  ('happi snappi wait footbal footbal snapchat', 1),
#  ('friday miss fring qcbag summer', 1),
#  ('nochebuena lasvega usa la vega strip', 1),
#  ('fleurett instaboy instaman sefi septum friend smile blackandwhit', 1),
#  ('sad branch raini day write tear fli bird haiku 3line micropoetri', 1),
#  ('yeah new button mail pretti jewelrymak button', 1),
#  ('driver hit femal moos river rd weston moos kill driver ok crew remov anim',
#   1),
#  ('afterpa made japan madeinjapan eo cute fun cawaii love strawberri tomato',
#   1),
#  ('peopl protest trump republican trump fuher amp', 1),
#  ('need find way spend time alway mind boy guy', 1),
#  ('1466047260 15 updat social analyt photooftheday iger like', 1),
#  ('anyon know date doj fbi becam corrupt emailg hillary2016 shame disgrac ridicul',
#   1),
#  ('stupid make even neglig put sachintendulkar instal u go take', 1),
#  ('bihday 21thbihday bestfriend love', 1),
#  ('impoant thing enjoy life matter life sho pooh4u', 1),
#  ('happi bihday chri evan great actor human chrisevan bihday', 1),
#  ('hea thought prayer go 50 peopl murder gay nightclub florida', 1),
#  ('demo guitar new album newalbum indi guitar echobelli', 1),
#  ('retweet lion pro tgif webmaret seo commun manag weekend', 1),
#  ('nzd usd target 100 week sma 0 7190 blog silver gold forex', 1),
#  ('pretti bad bihday week far worst ever bihdayweeksuck bithday27', 1),
#  ('bless work sa best lead ladi', 1),
#  ('happiest place eah disneysmagickingdom disney magickingdom disneyland orlando',
#   1),
#  ('kinda among human', 1),
#  ('found exclaim gr8 blain hair nite', 1),
#  ('lt 3 listen beauti best friend sing amaz voic lt 3 lt 3 lt 3 lt 3 17', 1),
#  ('n healthi freedom effo present mere mean effo store past theodor roosevelt',
#   1),
#  ('know yall 2 aint go know love commit trust faith', 1),
#  ('ye call michelleobama gorilla racist long thought black peopl bet', 1),
#  ('newarkfestiv us year wait show sta 3rd year run', 1),
#  ('internet broken watch netflix mochithepug puglif', 1),
#  ('busi usual', 1),
#  ('hbd dick suckin tequila lovin slut wouldnt want u way justalil butstillontim',
#   1),
#  ('smaller hand show barri probabl lie knick game suck golf', 1),
#  ('good morn friday everyon weekend goodmorn friday girl love florida', 1),
#  ('challeng aap claim 70 punjabi drugaddict dare prove', 1),
#  ('tracerequest send deepest condol orlando gay famili zimbabw gay commun hea touch',
#   1),
#  ('new selfi guy mato chapon', 1),
#  ('saturday afternoon chi meet friend', 1),
#  ('so nut amp bolt bloke', 1),
#  ('aww yeah good bing bong bing bong', 1),
#  ('dawn 2 month see live excit vfest summer', 1),
#  ('happi 35th bihday shane robe watson bihday shane watson australia cricker',
#   1),
#  ('point one finger million point right back jewishsupremacist', 1),
#  ('sad hear announc say may move player one two lead whoknow', 1),
#  ('radio1 go coldplay tonight oh ye', 1),
#  ('u think like god come god keep', 1),
#  ('terrorist constitut right anoth excus republican appeas nra gun control measur',
#   1),
#  ('gloucesterrugbi', 1),
#  ('sad happen', 1),
#  ('everyon everyth sad togeth alon fine dandi lone exuber depress halfful halfempti',
#   1),
#  ('mikeashley sposdirectsham perhaps good exampl need protect workersright within europ euref remain',
#   1),
#  ('angri bird stella bad princess bird stella bad princess birdsstellabadprincess time post wed',
#   1),
#  ('check incred made great memori great peopl', 1),
#  ('saw shi last night said rip care realli', 1),
#  ('hilari alreadi block ask one paicularli difficult question', 1),
#  ('devast news hea goe victim famili orlando heabreak', 1),
#  ('happi state arriv manner travel margaret lee runbeck happi quot inspir', 1),
#  ('safe way heal acn altwaystoh healthi heal', 1),
#  ('creat right beat makingbeat thursday work istandard akaipro', 1),
#  ('wed number 10 wed weddingpay love forev weddingdress', 1),
#  ('look forward attend cipd ireland confer amp workshop cpd onemoreday', 1),
#  ('final reach 200 follow twitch follow hypu stream tomorrow', 1),
#  ('word r free u use em cost verbal abus hu love adult teen', 1),
#  ('countri went last year see peopl bring bomb stadium amp come everyth footbal',
#   1),
#  ('thank cat thank posit', 1),
#  ('time eat bae swalscha dejeun lunch happi love amoureux', 1),
#  ('ilovethesecret lawofattract quiz love happi motiv success joy life', 1),
#  ('might libtard libtard sjw liber polit', 1),
#  ('go pole bgp rozthediva blackgirlspol bodyandpol live love', 1),
#  ('argentina2015 attack bull game 3d realli think head empti around citi side',
#   1),
#  ('self serv hypocrit alway keep eye bounc ball nimrod presid', 1),
#  ('nohcarolina bull domin bull direct whatev want whe', 1),
#  ('build polar bear climb race angri polar bear climb race polar bear live cold place loo',
#   1),
#  ('want reelect money ksleg', 1),
#  ('hea orlando right truli cannot imagin could easili happen anywher', 1),
#  ('alreemgroup ali alshahawi ad cute summer photographerdubai sun hair mydubai',
#   1),
#  ('seem like place action montreal', 1),
#  ('old wash', 1),
#  ('spirit posit affirm', 1),
#  ('thank enteain thank posit', 1),
#  ('show truli bad brisban', 1),
#  ('wait wimbledon2016', 1),
#  ('happi man success model entrepreneur speaker ff fresh confid fashion', 1),
#  ('gala moment day kid bipolar frikiegirl2016 lucki chinatown mall binondo',
#   1),
#  ('realli take piss angri goe show valu complet utter moron', 1),
#  ('take trash america vote hate vote vote vot', 1),
#  ('father day amaz dad give much famili enjoy', 1),
#  ('magnettherapi realli work altwaystoh heal healthi', 1),
#  ('sebbo said', 1),
#  ('eg smile smile egsmil torio', 1),
#  ('brilliant servic ketter branch today custom', 1),
#  ('screen miss sing song potp shock treatment', 1),
#  ('way toraya bu alamindah white music carrieunderwood', 1),
#  ('good day 6 new beer bridpo food amp beer fest back campsit drunk starstruck amp move 5',
#   1),
#  ('g l repost propey ocean summer life famili sydney', 1),
#  ('want teach love like never felt quot quot love pakistan allin216 girl boy fashion feel',
#   1),
#  ('thank thank posit', 1),
#  ('omg 100 day left countdown nolefam wait come milan 22092016', 1),
#  ('stone rose done time club day', 1),
#  ('reason two peopl stay togeth give someth nobodi els hopelli great day', 1),
#  ('never know might crush wakow buzz moment ride love crush date hookup app',
#   1),
#  ('friend got engag', 1),
#  ('298 day lef b4 end classez yay risay18 risaypl', 1),
#  ('thursday may watch say need said', 1),
#  ('legendari posit affirm', 1),
#  ('unit state america rest world think proven right firearm', 1),
#  ('hold open door woman woman nice thing even tri deni', 1),
#  ('good weekend show thank bless jeffreycwilliam', 1),
#  ('good hea help everyon alway seem one get hu buttru', 1),
#  ('happiest babi ive ever known cute smile babygirl beauti niec bless xo', 1),
#  ('readi b c oneteamlincoln', 1),
#  ('wait carowind readi see time rockthepark timetogetmyjesuson', 1),
#  ('alreadi bought find dori ticket', 1),
#  ('everi minut lose sixti second happi', 1),
#  ('sanjapan animeconvent see guy septemb', 1),
#  ('question day excit moto tech announc moto question', 1),
#  ('make today count mondaymotiv livelifetothefullest healthi everydaycount',
#   1),
#  ('happi morn 8degre anna classmat friend 92', 1),
#  ('would u abl suppo event brentwood homesta lost fund may close', 1),
#  ('happi littl peopl happyhappi peopl kitten cat blackkitten', 1),
#  ('thank much oppoun cherish forev', 1),
#  ('themeowood puppi', 1),
#  ('day till', 1),
#  ('happi pharrel william pharrellwilliam lyric', 1),
#  ('happi w ork confer right mindset lead cultur develop organ work', 1),
#  ('lost anoth member famili yesterday gut rosi', 1),
#  ('yayyy trailer 2morrow fever super', 1),
#  ('watch fanci tail vine mad mad teeth bite piss dog bite dogbit dogtreat', 1),
#  ('dreamcatch bull domin bull direct whatev want', 1),
#  ('readi tomorrow englishteach teacher ecuador', 1),
#  ('memori wonder dad alway miss etern love strong greatquot', 1),
#  ('dalla shoot video see disturb viewer discret play loop ove', 1),
#  ('itako alon fine littl', 1),
#  ('sunshin amp sticker kind saturday letthembelittl childhoodunplug', 1),
#  ('wonder day today calm sunni chubbygirl glass finnishgirl finn', 1),
#  ('buka bersama tma famili yuhuuuuu tma w risha meylucki amp 3 other mayfair townhous pic',
#   1),
#  ('love know nationalbestfriendsday true', 1),
#  ('man ran governor ny state biggest african american popul', 1),
#  ('stereotyp prejudic offer hope solut creat old repetit hate conflict', 1),
#  ('get pussi quicker day', 1),
#  ('probabl 30 time come back home ugh', 1),
#  ('anyon play voez kinda love game game game girlgam voez', 1),
#  ('mani pol pass mani time said noth bluelivesmatt draintheswamp ferguson', 1),
#  ('sequoia weekend', 1),
#  ('bitch care eyebrow much makin end week', 1),
#  ('bham pride paradereadi beyou ofbham', 1),
#  ('fathersday guy play dad love', 1),
#  ('0616 bihday bogummi love forev hope happi everyday good night', 1),
#  ('wish client babi goat cuddl', 1),
#  ('positivevib fresh love guy get concord mill mall', 1),
#  ('conjuring2 get readi scare tonight readyornot truestori', 1),
#  ('today day make chang elimin neg choos live posit lifestyl instead', 1),
#  ('aaahh nabilah look arigat jkt48 happi daaay iwearbanana', 1),
#  ('last day work tomorrow self employ monday scare redditchbizhour', 1),
#  ('im half boy half man im dumb', 1),
#  ('happi littl boy smile corbinrayp', 1),
#  ('never appropri zero idea feel right scare missyou whatwasthat', 1),
#  ('magnific monday mondaymorn mondaymotiv monday indraloka', 1),
#  ('dont understand design print anim fabric bought muzlin 5b sanasafinaz noexchangepolici',
#   1),
#  ('mayb 4 happi hour get end', 1),
#  ('littlebear friend joy toddlerfriend puresweet latergram toddlerfun', 1),
#  ('never lost love one senseless violenc get fuck opinion 2nd amend', 1),
#  ('world head could lose life leav home orlando', 1),
#  ('heard say tri lock shooter kept patron get', 1),
#  ('good mood flight munich interview pharrel', 1),
#  ('first present netherland', 1),
#  ('u made us proud hv read ur word amp assur b assoment petit emot wish u best',
#   1),
#  ('happi vs joy happi temporari leav u hu joy last forev never leav real tru',
#   1),
#  ('twinklatinboy na slut snapshot hot nasti naughti sexi horni shi porn nude kinki xxx',
#   1),
#  ('peopl thank thank peopl happi thankfulthursday', 1),
#  ('creativ posit affirm', 1),
#  ('held back tear cri happi tear amp final leav week tomorrow canadianrav', 1),
#  ('bihday pressi mummi granni michaelkor luckygirl bihday liverpool', 1),
#  ('stuck athen instead santorini said windi land shock servic everi level sinc',
#   1),
#  ('happi folk first freakshak launch freak yum dalston', 1),
#  ('huge crowd trump', 1),
#  ('thank saturday thank posit', 1),
#  ('good god', 1),
#  ('enjoy delici melon vegan organ fresh fruit organ healthi healthyliv life',
#   1),
#  ('first month week day till begin end sad time', 1),
#  ('firework weeheeee', 1),
#  ('blackpool attack bull game 3d realli think head empti around citi side', 1),
#  ('fathersday amaz father today', 1),
#  ('want much ask', 1),
#  ('readi wait newblood16', 1),
#  ('sad aunt pass away 96 funer', 1),
#  ('7 horribl ad 2016 made us cring', 1),
#  ('mind robson kanu s6 decent player avail free transfer', 1),
#  ('come better pleas put shoe unnecessari stress h', 1),
#  ('stalk watch peon poor disabl kill usa usa use 2b proud amp univers care',
#   1),
#  ('stephcurri outburst beg question christian get nbafin', 1),
#  ('grate affirm', 1),
#  ('8 week go im san antonio bound see cant wait see littl brother missyou mybrotherskeep',
#   1),
#  ('listen gt gt gt gt gt gt gt', 1),
#  ('die light villag green town antisemit hocoschool columbiamd hocomd', 1),
#  ('hahaha last friday amp weird', 1),
#  ('hey notic u train lover ask u check free app known train appl', 1),
#  ('sexi fuck direction niall nialhoranfact niallerwin hot justindrewbieb justindb believet',
#   1),
#  ('father sday say love dad right sanya whererefreshingbegin', 1),
#  ('guess back back lifeaftersurgeri dog dogslif labrador labradorretriev lifeofsam',
#   1),
#  ('hey superspoilt may want check latest updat glastofest', 1),
#  ('bihday sid god bless hav success career', 1),
#  ('nba final ambival love steph thompson kyri stink green class doosh lebron talk guillermo',
#   1),
#  ('check product team web seri episod edit truli mep webseri', 1),
#  ('never answer statement nazi hatr amp bigotri found w', 1),
#  ('juneteenth independenceday food4thought rich ancestr heritag independ hall',
#   1),
#  ('river gorilla simul need adapt environ need tear citi materi', 1),
#  ('watch leadership embrac amp kiss donald ass pathet amp pay pay racism amp hate ripgop',
#   1),
#  ('love matur age', 1),
#  ('good feel happen smile instalik instamood instap', 1),
#  ('check graffiti dublin ireland music vimeo movi video europ peopl flow fun rafalwojcicki',
#   1),
#  ('oitnbseason4 2 day aaahhhhh', 1),
#  ('iamposs today extraordinaryladyspeak staraward ht', 1),
#  ('sun happi thursday breakfast sun day sunnyday sun blue', 1),
#  ('pack sneak peek work yellowjacket neshl 2016 bhl hockey', 1),
#  ('toni sunday tonyaward', 1),
#  ('happi father day 2016 dad dad father day 2016', 1),
#  ('theverdict idiot countri rock bluegrass beatl love pop romanc', 1),
#  ('project week june 13 2016 blog silver gold forex', 1),
#  ('300dayshappi dayseventyseven day77 happi love lifequot life', 1),
#  ('littl brother higher toler alcohol lol', 1),
#  ('wish guy bihday blaze say spit imag', 1),
#  ('thank hike trail thank posit', 1),
#  ('pay meet tackl movi uncov problem want world know', 1),
#  ('chill relax piano music keep pet quiet july4th firework', 1),
#  ('noth say merica like tweet', 1),
#  ('alway paratyphoid', 1),
#  ('today lost thevoic sister senselessli sing love death peopl stoptheh ripchristina',
#   1),
#  ('guy concern twitter brand honest follow', 1),
#  ('hate like 90 famili realli born big ass toxic bomb mother fucker give fuck cuz got money',
#   1),
#  ('get get get enjoy music today free app free music', 1),
#  ('best lawofattract resourc heal altwaystoh healthi idwp', 1),
#  ('trump ny co chair make racist remark michel obama p2 p21 fyi tcot', 1),
#  ('fan make', 1),
#  ('music therapi tool heal altwaystoh healthi', 1),
#  ('food make famili fight mxm', 1),
#  ('delici sangria salud cheer smile pub pembrok', 1),
#  ('fabul weekend beauti soul nofilt', 1),
#  ('feel overwhelm look see million reason happi love craig', 1),
#  ('back day job shane lowri', 1),
#  ('hour right 2 4 1 bottl amp drink 4 7pm 42 w chippewa st buffalo', 1),
#  ('ana nimra farishta mawia khushal 960 952 503 484 435 3334 number mark obtain damn high p',
#   1),
#  ('monday empti without bachelorett thebachelorett empti nowin', 1),
#  ('suppo famili god chivalri tradit pride one heritag controversi', 1),
#  ('pic say otherwis young girl confin kitchen void mean beyond cheap public topoli',
#   1),
#  ('good night faith ever vaitacacommafiasdv', 1),
#  ('love simpli love love success work busi', 1),
#  ('lunchtim mom torrington lunch afterschool instadaili yummi withmom', 1),
#  ('sister even know watch argu nigga wait say wrong shit', 1),
#  ('ride ride back done cycl sunset ride bike fit cardio dese', 1),
#  ('well gonna go see adtr bae', 1),
#  ('tagsforlik food friend summer swag quot love god girl weekend polaroid followm teen win job',
#   1),
#  ('payintheusa polar bear climb race angri polar bear climb race polar bear live cold place',
#   1),
#  ('11 11 healthi fam', 1),
#  ('dream palac move alreadi stellar girl dreami goodmorn day', 1),
#  ('im wait follow sinc x factor', 1),
#  ('fault use pointscor', 1),
#  ('week sta kinda lame get better yay wednesdaywisdom', 1),
#  ('forev young man luk hot wen temper b alwi ur fan till lst breath h', 1),
#  ('worri bee', 1),
#  ('doubl tap follow beauti smooth lifestyl skin instas f4f fashion', 1),
#  ('lawofattract heal loa healthi well idwp', 1),
#  ('oil turn flat 50 40 eye eia inventori data fuher direct blog silver gold forex',
#   1),
#  ('train new employe fun newblood', 1),
#  ('first bihday puppi elois sweetbabin dog growingup cute bihdaygirl', 1),
#  ('5 000 pig burn aliv saskatchewan barn fire video', 1),
#  ('never convinc american right bear prayfororlando guncontrol', 1),
#  ('beauti ladi bless know smile lovethem', 1),
#  ('today baba siddiqu ifftar pay mumbai amp dono ayeng see', 1),
#  ('hand ombr blue', 1),
#  ('wait go see warcraft ugh warcraft', 1),
#  ('cousin reunit famili fun well', 1),
#  ('audienc duan henri insight', 1),
#  ('train move bing tweet', 1),
#  ('lover stop angri visit us gt gt gt lover friend astrolog love', 1),
#  ('block troll promis blacklivesmatt amp let nonsens rant boo', 1),
#  ('father day dad one heaven', 1),
#  ('sdl326am june 16', 1),
#  ('creepi awesom baboon climb fire escap like human summev zoo', 1),
#  ('use power mind heal bodi altwaystoh healthi', 1),
#  ('dude tiger roar tiger annaswelshzoo bihdaycelebr', 1),
#  ('laugh happi laugh william jame xtra', 1),
#  ('happi sunday everyon think today go good day positivevib sunshin sunday',
#   1),
#  ('talk way organ dehuman us never held account', 1),
#  ('stuck rat race find freedom masterkeyexperi', 1),
#  ('studi face pizza stole roommat idea take pic', 1),
#  ('dinner sister sisteradventur sister ilovemysist', 1),
#  ('els plan watch tomorrow', 1),
#  ('usn rifl day snow ar 15 closest 16 ever got navi', 1),
#  ('euro 2016 bbc pundit make predict franc euro sta today', 1),
#  ('happi happi minion', 1),
#  ('elder scroll mani year wah wah bethesda e3 e32016', 1),
#  ('poor tiggi littl bit cheeki jax amp soa throwbackthursday', 1),
#  ('cannot wait eurogam year pump eurogamer2016', 1),
#  ('work russel beckwith soon staytun friend lyle tapfoag', 1),
#  ('nazi studi american race law inspir ushistori eugen', 1),
#  ('share ice cream sun love outdoor picnic summer famili daughter father dess icecream',
#   1),
#  ('noth like river island sale shop spree cheer retailtherapi riverisland shoppingqueen alwayscheersyouup',
#   1),
#  ('clean ze hous zo ziy laundri final free fever cold happi clean laundryday',
#   1),
#  ('2 new list ebay woohoo sell sell buy shop shop', 1),
#  ('thank challeng thank posit', 1),
#  ('chill night ice cream amp grown up2 chill', 1),
#  ('biher absolut origin hate bigotri altright hatr african american potu theresist',
#   1),
#  ('sweet instagood idola idol followm selfi', 1),
#  ('tragedi america first kill christinagrimmi orlando america safe place today',
#   1),
#  ('brexit angst factor help drive interest rate germani japan bbh blog silver gold',
#   1),
#  ('fab amp interest day eacbpm dash quiet place dial iiba emea region meet busi',
#   1),
#  ('kayak sup snorkel swim whatev pleasur put togeth alohabeachbu hawaii explor',
#   1),
#  ('u hold man year watch chang u hear say loyalti', 1),
#  ('back go tacloban see ya later great travel tacloban citi catbalogan', 1),
#  ('feel olymp medal', 1),
#  ('angri bird il film download ita 720p hdtc 2016 bird download film il ita',
#   1),
#  ('sunday photo model urbex topless tit mono retweet sexi heel ace', 1),
#  ('fo woh offic viral arrest video rude racist chief crime offic', 1),
#  ('saturday friend', 1),
#  ('yayyyi friend got marri today congratul guy shegotmarri', 1),
#  ('lewi remain perfect ranger announc gonna stroke', 1),
#  ('chri back soccer miss spring season broken', 1),
#  ('train ticket book opera week wale', 1),
#  ('beauti day sun fun beachpark beach park', 1),
#  ('big screen fit right euros2016', 1),
#  ('love stori happi end anim love stori end like4lik', 1),
#  ('poet bull domin bull direct whatev want sta', 1),
#  ('tranquil posit affirm', 1),
#  ('name upcom new track 2pm kpop', 1),
#  ('best essentialoil anxieti healthi peac altwaystoh', 1),
#  ('wow peopl children noth better insult peopl twitter', 1),
#  ('think mayb bought instead gettingold becomingbor notborderland goblizzard',
#   1),
#  ('fact album hour away drip lose mind fatkidinacandystor', 1),
#  ('ryderrideu see c2c cum togeth snapshot young shi kinki wet porn hot xxx horni',
#   1),
#  ('snapchat gabi china20 love girl snapchat flower instasmil instalov', 1),
#  ('brilliant posit affirm', 1),
#  ('true nigga dont go look apament go look shoe jewelri', 1),
#  ('msgapparelstoday u r special 4 us father day', 1),
#  ('camp next weekend lovecamp brownwood', 1),
#  ('forev besti karaok friend friendship love nofilt instacool instagood', 1),
#  ('absolut love place fantast welcom carlo receptionist 5th time room request grant usual 318',
#   1),
#  ('head thealter peculiar famili', 1),
#  ('us retail sale control group like rose 0 2 may dansk bank blog silver gold forex',
#   1),
#  ('happi father day love life amp best father world fathersday love', 1),
#  ('coolestlifehack world smallest snake motiv', 1),
#  ('shockingli increasingli violent world live uk gun control law feel mp famili amp friend',
#   1),
#  ('funni simpli truestori', 1),
#  ('happi bihday brithday day holiday monday menmodel', 1),
#  ('sadden one thought groom posit ask opinion issu', 1),
#  ('ukrainian athlet grosseto watch livestream without see', 1),
#  ('new season oitnb sta tonight oitnbseason4', 1),
#  ('excit side cuain tonight look forward see broadway', 1),
#  ('quay collab say sold noooo whyyyy loveyoudesi', 1),
#  ('final get jordan get paid wear lowtop', 1),
#  ('impress posit affirm', 1),
#  ('father day father make happen salut', 1),
#  ('view 27th floor nyc newyorkc myview girl wine fridaynight', 1),
#  ('discuss republican thing critiqu ignor consequ', 1),
#  ('got school tomorrow last integr', 1),
#  ('amen truth alway lt 3 lt 3 love bless', 1),
#  ('stamford kid got 6 month rape boredom 20 minut action', 1),
#  ('let color life w rainbow danian love colour rainbow depok', 1),
#  ('aiel aielmaharashtra rude custom care execut make want switch loyalti anoth provid irrit',
#   1),
#  ('hi teddi corpuz rocksteddi band enjoy idol omg', 1),
#  ('wow great daughter send father right father day cheapshot lowblow shame',
#   1),
#  ('6 reason happi kid mid tantrum parent tantrum toddler calm mind strong', 1),
#  ('truth posit affirm', 1),
#  ('yup siri maco wwdc2016 woot next work listen skill', 1),
#  ('diy done dresser nicknack newelectricscrewdriv brock london', 1),
#  ('black amp feel like stomp retweet tampa miami', 1),
#  ('that problem one polic offic need bigger gun perhap one tank soldier', 1),
#  ('father day friend', 1),
#  ('choic fall alway write candid', 1),
#  ('end', 1),
#  ('get know team behind app keep tummi june issu bazaarmag', 1),
#  ('actual go fish today somewher nice', 1),
#  ('cute look like doll', 1),
#  ('im', 1),
#  ('love vacat enjoy greec crete sabinedrift chillinn blondegirl bluedress', 1),
#  ('unreal 3 advisor refus take payment say wait pcn custom servic ur site wasnt work',
#   1),
#  ('gamereadi forza horizon pc time live', 1),
#  ('life better tahiti summer life school tahiti like', 1),
#  ('know male thought vagina like video game xd stupidthought quot lmao', 1),
#  ('pa pack taken brainwash cheetah downasquadmemb treeout', 1),
#  ('japan domest corpor good price index yoy line expect 4 2 may blog silver',
#   1),
#  ('rememb day peopl bbuk went becom realiti tv star seem realiti tv star becom big brother contest',
#   1),
#  ('allahsoil familiar becom difficult stereotyp', 1),
#  ('good morn want live life tie goal peopl thing', 1),
#  ('friday lt 3 fridayfeel relax bristol', 1),
#  ('day porn movi pussi pay pic', 1),
#  ('look easi till turn rap hiphop rock funni comedi pop kanyewest', 1),
#  ('banner merri christma new year freepik ad decor newyear', 1),
#  ('yay thank let know pa happi man', 1),
#  ('exam room test tire annoy', 1),
#  ('best homeopath remedi anxieti altwaystoh heal peac', 1),
#  ('rest peac christina', 1),
#  ('bama fool around might rais child ppl dont think far advanc see fun whatev',
#   1),
#  ('anti racist codeword antiwhit asia asian africa african white countri everyon',
#   1),
#  ('periscop first god babi graduat high school collegebound', 1),
#  ('nearli folk nervou curiou finalis stuff pointer grainn bringiton', 1),
#  ('fellowship lifegroup', 1),
#  ('caught eat chocol slice bread besid ref realiz still eat dinner', 1),
#  ('prais cleveland polic rnc polic consent decre 75 white tamirric rip', 1),
#  ('everyth need surfday fathersday dad novyspo novytowel surfgear', 1),
#  ('100 agre', 1),
#  ('next show monday fiddler elbow camden look like go huge night ht', 1),
#  ('swim sign everywher parent watch 2 year old', 1),
#  ('mitchellrattl mitchel goodson', 1),
#  ('get readi saturday jeep run nbjc 3 day showyourjeepday jeepmafia jeeplif jeep htt',
#   1),
#  ('attempt czech furi croatia score second', 1),
#  ('latest dairi k thank', 1),
#  ('yep grate everyday gratitud laurasworld', 1),
#  ('ebook awhil nice hard copi', 1),
#  ('nba final game 7 could basketbal fan ask nbafin', 1),
#  ('prevent bigot', 1),
#  ('dear uot despit attempt savechar regret announc lost tragic rip angel friend miss u',
#   1),
#  ('space place color blue fabricsourc finish pillow cushion use us', 1),
#  ('perfect moment day', 1),
#  ('wait hour come autograph final walk away come cours disappoint', 1),
#  ('fathersday gift dad secur financi futur save insur invest', 1),
#  ('girl world sexi matur housewif', 1),
#  ('time get happi saturday saturday weekend', 1),
#  ('3 awesom dad almighti father lord darl dad rip sweethea husband babi daddi 1st son fathersday',
#   1),
#  ('owen footbal tornament footbal', 1),
#  ('come ee piss poor recept today 20 month struggl get signal buxton put mast switch grumpi',
#   1),
#  ('excit na', 1),
#  ('let troopingthecolour begin bihdayyourmajesti thequeenat90 ht', 1),
#  ('work fusiona wolv last stage develop chase', 1),
#  ('like blacklivesmatt slogan talk', 1),
#  ('r p littl bear bear hamster rip imissy', 1),
#  ('give hug love cat moment', 1),
#  ('lip like fire blood like gasolin love boyfriend smile', 1),
#  ('go let peopl icrs2016', 1),
#  ('life race allow present fun', 1),
#  ('dental testimoni lichfield client', 1),
#  ('thank soo much pretti feel soo bless amp lucki plz keep shower ur lyk surpris 2like unexpect',
#   1),
#  ('nice 2c susanna smile 2day need fals promis fli dragon got ben', 1),
#  ('1d back yet', 1),
#  ('got call yesterday mom diagnos stage 3 ovarian cancer terrifi terrifi know',
#   1),
#  ('feminismiscanc feminismisterror feminismmuktbharat malevot ignor', 1),
#  ('side histori alli issu embarrass', 1),
#  ('fox new come say bluntli one thing read', 1),
#  ('good morn internationaldayofyoga2016 yogalov yoga relax healthi posit', 1),
#  ('monkey also declar vermin protest bajrang dal', 1),
#  ('new plant readi garden garden know', 1),
#  ('coldplay last night fave coldplay conc hampden fave coupl cute', 1),
#  ('flagday mine gorgeou texa sky householdnam takingov', 1),
#  ('ye let suppo openli prowar anti islam homophob rapist advoc hypocrit', 1),
#  ('cat furri persiancat 4798 pixion wallpap imag', 1),
#  ('good moooooorn tgif kiss kiss friday fridayfun', 1),
#  ('enjoy everyth alreadi given rather alway need bless thank', 1),
#  ('euro2016 match schedul design franc vs romania feedback appreci', 1),
#  ('father day take dad 2 20 love', 1),
#  ('berlin thank much incred theriveourberlin theboss', 1),
#  ('listen incubu never hu nowplay sick littl world nissan live set de', 1),
#  ('anderson cooper amp lemon like gay thrown build sharia 2ndamend', 1),
#  ('bei field dog walk dog', 1),
#  ('would steal awork boohiss', 1),
#  ('compet list today whenrealtorscompeteyouwin callm gotheextramil', 1),
#  ('great park total disorganis one poaventura whatajok', 1),
#  ('got news berni win dc even vote held last month dcvote', 1),
#  ('eur usd print new monthli top 1 1400 draghi eye blog silver gold forex', 1),
#  ('two presidenti candid everybodi devolv elections2016 america smh usa', 1),
#  ('poor pup anim puppi vine magic subscrib youtub vine', 1),
#  ('rare pic superstar bihday sivakoratala', 1),
#  ('2016 move outsid downtown gr mi neither offer better 6 mbp', 1),
#  ('wish dad happi father day dad fathersday 2016 intellicr', 1),
#  ('met girl 5 yr ago onlin b ng gay friend look like b4', 1),
#  ('face say pwcproud', 1),
#  ('b u love instagood tbt cute beauti followm', 1),
#  ('enjoy weekend famili home happi weekend dear friend weekend famili home',
#   1),
#  ('anoth senseless tragedi tragic puls orlandostaystrong thoughtsandpray', 1),
#  ('love yrkkh frm bottom hea frm day stare amp v get return uglyspat', 1),
#  ('captain felix rutland water littl boat behind go grand adventur', 1),
#  ('bing watch seri 1 thekil complet avoid footbal', 1),
#  ('quot jeremi corbyn fuck go', 1),
#  ('happi travel time instamood moment love mylif russian girl model 4like', 1),
#  ('porn vid wwwsmallgirlsexcom', 1),
#  ('tuesday jacki quot taketim make soul enjoylif smile believ dream havefun',
#   1),
#  ('home sweet home call edinburgh sinc move year ago scotland homesweethom famili',
#   1),
#  ('play england vs russia marseil 21 00 expect high risk game plenti time drink',
#   1),
#  ('thank sweater weather thank posit', 1),
#  ('haunt atmospher studiotim', 1),
#  ('becom fan give right critic person life idol', 1),
#  ('latest obsidian radio daili thank latesnew', 1),
#  ('mind blown learn much googl form workshop cfisdrrr', 1),
#  ('sexi prettypussi sexybbw realmvp', 1),
#  ('back v traumat month damag bad thought proof plan work onward amp upward excit',
#   1),
#  ('overwhelm evid compani trump keep echo sentiment amp ideal dumptrump', 1),
#  ('femal beef commun dick ass nigga', 1),
#  ('peopl like alreadi forgot nah new name made hashtag weekli basi', 1),
#  ('answer', 1),
#  ('cherri color symbol warm posit energi necklac price 200 a stone gift amaz beauti',
#   1),
#  ('wait 2016 17 season begin lfc ynwa englishpremierleagu', 1),
#  ('happi father day dad except rogergoodel fathersday goodellsuck', 1),
#  ('orb independ brexit poll show leav vote ahead gbp usd slump blog silver gold forex',
#   1),
#  ('25mm 16mm washout flood good take set anoth day golf', 1),
#  ('ya ever sinc zayn left never', 1),
#  ('happi father day lovey fathersday sunday father daddi day', 1),
#  ('big shock monday need find new home yeah found dream cottag tuesday', 1),
#  ('save thousand free search x login x broker actor seeklearn stafresh', 1),
#  ('actual order kyli lip kit', 1),
#  ('hope famili made arrang make sure bastard get access', 1),
#  ('socialmedia us firm build 6 nuclear reactor india', 1),
#  ('smaphon bull domin bull direct whatev want', 1),
#  ('lifeisbeauti loveit workhard trainhard matter go bless fitlif', 1),
#  ('oscar tabarez talk lui suarez angri reaction spo lui oscar', 1),
#  ('play njoyhit40 1hitmusicst us uk eur join us nice nyc', 1),
#  ('2 week go personaltrain full time new slot avail 30 june pl spread', 1),
#  ('mother take care ten children sometim ten children cant take care mother',
#   1),
#  ('thank good night sleep thank posit', 1),
#  ('play bride nocturn melancholi melancholymus', 1),
#  ('tvk3fathersday father day tatay daddi enjoy wath tha voic kid', 1),
#  ('thank friend thank posit', 1),
#  ('thank mason jar thank posit', 1),
#  ('nigger lifelesson white kid grew 60 blogpost whitepeopl respect', 1),
#  ('congrat', 1),
#  ('via jts88 love sinkthepink music instagay celebspot', 1),
#  ('readi ccmf2016 mychurch frontrow upshow', 1),
#  ('utterli peopl incur stupid africa albino kill malawi spark educ campaign',
#   1),
#  ('gold high back around 1 260 blog silver gold forex', 1),
#  ('shock event orlando usa review gun law innoc die first horrif unforgiv', 1),
#  ('knowledg posit affirm', 1),
#  ('le sister instatravel instamo igdaili instagramhub instagood instalik', 1),
#  ('feel lone', 1),
#  ('girliguessimwithh tag saddest represent peopl feel forc vote', 1),
#  ('h factor mobil app make user want factor click download aric whitepap', 1),
#  ('meanwhil googl violat free speech', 1),
#  ('rochest attack bull chase leav lot despit fact strong sourc f', 1),
#  ('competit', 1),
#  ('tattoosleev gorilla simul need adapt environ need tear citi', 1),
#  ('ima go cri hour brb', 1),
#  ('tell sorrow river river taught flow without complain sepatu dahlan philosophi proverb',
#   1),
#  ('thank memori thank posit', 1),
#  ('sure nasti piec work lmao', 1),
#  ('today perfect day happi lifecoach reinventimposs', 1),
#  ('sex 40 sex nake women', 1),
#  ('thank cocktail thank posit', 1),
#  ('dont wait outsid thepeel 4 work homophob taxi driver guy kiss gay melbourn 13cab',
#   1),
#  ('guess one want let resid spring street know abl leav hour today', 1),
#  ('great morn deborah smile kind day', 1),
#  ('windows10 split screen browser customcasetab noedit 712', 1),
#  ('peopl use tragedi like fuel hate agenda toward entir group peopl opposit help',
#   1),
#  ('taeyeon unni fire btw realli hope album cover yellow lol', 1),
#  ('john mica hell peopl like elect totalpolitician outoftouch disgrac', 1),
#  ('noth make dad happier tasti meal fathersday', 1),
#  ('truth suicid rate young blackboy', 1),
#  ('happi sunday homesweethom amaz love istanbul girl beauti instalik', 1),
#  ('oh block least love island look forward sunday', 1),
#  ('play suzann ciani 4 clock morn music song', 1),
#  ('swing swing mybabygirl babi littlegirl park love cute', 1),
#  ('help bubbl attack winter bathtim cozi', 1),
#  ('move posit affirm', 1),
#  ('thing matter mani law regul gun peopl still find way get hand', 1),
#  ('sunflow natur garden photograpi qualiti print amp card', 1),
#  ('didnt stay long emerg home daughter well soo rush home miss ur set', 1),
#  ('great insight trust profess emea growth hack confer growthwithhubspot', 1),
#  ('carolyn cooper ugli poor ignor black', 1),
#  ('franklin dog sunshin dogsoftwitt', 1),
#  ('perfect day buy real furnitur hike dinner dess sleepnumb bonustolongrest dnd',
#   1),
#  ('happi face love smile satisfi hair workit smile face', 1),
#  ('love sunday weekend selfi longhair girl selfporait love', 1),
#  ('natur perfect bull hill climb reach target complet task surviv str', 1),
#  ('orlando gay men angri amp 039 donat blood massacr', 1),
#  ('golinglob golinuntern fresh air trail run soul keep golinuntern life balanc',
#   1),
#  ('monro amp nick best friend amp rosale amp addi kelli amp babymonrosal grimm famili nadalind',
#   1),
#  ('lie hillari would call secur inquiri liber like mind one eat shit eat shit',
#   1),
#  ('know find incred disrespect take person call meet frustrat', 1),
#  ('date night friday pub ilovehim instagay beer billi burnet', 1),
#  ('wish would make phone damn screen shatter cost arm leg still gotta pay fix em',
#   1),
#  ('hea wrench would state mother know son die', 1),
#  ('time fli less week go brilliant lead summer confer', 1),
#  ('fruit time fruit dess instamo photooftheday yvr sweet vancitybuzz', 1),
#  ('sad one gt gt gt', 1),
#  ('sirf ashiq log follow karen iqbal galib wasi faraz mohsin ki full poetri add follow',
#   1),
#  ('28 minut go armaanamaalontkss', 1),
#  ('thank god royal 2015 without kansa citi right cleveland disgrac', 1),
#  ('get see favorit person tmrrw', 1),
#  ('latina buffalo simul buffalo take vicin home way', 1),
#  ('world live orlando', 1),
#  ('vacat begun triathlet triathlon coach vacat fearless rul htt', 1),
#  ('bit heabreak reflect', 1),
#  ('peac way sta morn daili chao begin gratitud', 1),
#  ('hardcor girl video birday sex xxx', 1),
#  ('takalot book order arriv time long weekend away bush bengreenfield', 1),
#  ('saysometh bull domin bull direct whatev want', 1),
#  ('steph san kana 3 badli need pleas', 1),
#  ('anoth hand amp feet complet berachah best amp tire', 1),
#  ('way ctf book talk inmat paicip book club program slugg', 1),
#  ('readi awesom beat cool dj danc edm hous goodmus mad', 1),
#  ('jpi neg extern environ remain suppoiv mufg blog silver gold forex', 1),
#  ('24 99 mkf collect jasmin moira crossbodi bag wednesday', 1),
#  ('current eat steakandshak 20 minut gotten shake order', 1),
#  ('gray sad color make feel grayneedstogo', 1),
#  ('difficult road often lead beauti destin anon leadership inspir quot inspir',
#   1),
#  ('usd long posit ad eur sho increas anz blog silver gold forex', 1),
#  ('r1rockallday day nois', 1),
#  ('definit mexican fakenewsal', 1),
#  ('new album releas break loveherbreakup hotgoss', 1),
#  ('stand racism hate americad curs congress hater deplor hate', 1),
#  ('sunshin sunshin make sky gray', 1),
#  ('someth want say someth make happi game gamer xboxon playstat e32016', 1),
#  ('footbal actual thing mo watchabl bringbackgladi', 1),
#  ('happi hump day humpday life lifestyl wednesday midweek snapchat walru funni',
#   1),
#  ('let say love', 1),
#  ('worri happi via archiveday weekendblogshar happi quot tshi', 1),
#  ('great thing never came comfo zone goodtogreat inspirem love', 1),
#  ('happi puppi london puppi thursdaymotiv', 1),
#  ('know go room one troubl soul draw blackandwhit', 1),
#  ('recommend dark amp romanc horror moviegenr ambianc', 1),
#  ('trump use hate putin win white hous trump press attack khan famili g p leader',
#   1),
#  ('one bucket list item tick tonight final saw ice cube live tonight wildlifefestiv today good day',
#   1),
#  ('friend magic potion ewabeach magicalhappydrink ewa beach hous', 1),
#  ('everytim wear soccer shi joie fri say look mexican fuck', 1),
#  ('weird month final feel posit life late pleasedontchang', 1),
#  ('check holiday croatia 13daystogo', 1),
#  ('night sweet dream', 1),
#  ('nyc seven day newyork newyorkc travel bigappl', 1),
#  ('life make let make motiv', 1),
#  ('fashionblog rooster simul want climb vast expans mountain reach leakag coc',
#   1),
#  ('best mood ever becauseofhim inlov', 1),
#  ('happi worri smile love iminlov iam im nice day', 1),
#  ('monaco resto chezedgard grandprixf1 essai sun lewissuppo amour love', 1),
#  ('bought launch use design think amp via toread letsmak', 1),
#  ('sukhbir badal announc offic bearer eastcoast zone canada', 1),
#  ('mad chose dj snake zedd edc', 1),
#  ('mango wood lett gbp 19 99 get shop cool home fun', 1),
#  ('danger white liber oveurn appli liber men femin', 1),
#  ('truli truli pathet mani way noth learn coverin', 1),
#  ('monday morn work lake scottieandrussel work love picoftheday', 1),
#  ('love rain hope hang around rain water tbt weather bribieisland', 1),
#  ('chosen wrong hors unless chang mind soon end polit career', 1),
#  ('wed impoant celebr life possibl ann hathaway wed love', 1),
#  ('icymi shoot orlando nightclub kill 20 polic say debelop gun', 1),
#  ('snatch past week schoolsuppli', 1),
#  ('great aicl right money starspangledbann slaveri apaheid usa', 1),
#  ('babi born welcom new world cat babiescat cat newborn congratul', 1),
#  ('pretend pain exampl strong person nighti', 1),
#  ('even dear cuti', 1),
#  ('mental cultur mentalhealth', 1),
#  ('wish us weekend', 1),
#  ('thank freezer thank posit', 1),
#  ('readi lt gt full day lt html gt cssday', 1),
#  ('bihday cake made mom bihday mom fondant pumpkin chocol delici beauti amaz',
#   1),
#  ('thank power social media aand', 1),
#  ('made smile bigbang babi cto', 1),
#  ('send good vibe way happi friday tgifriday goodvibesonli becauseimhappi smilemor',
#   1),
#  ('letsgo agent tooeasi 10 day till dlc know gamingforeveryon', 1),
#  ('holi citi tissu', 1),
#  ('old mom bihday', 1),
#  ('decid fowoh goldenretriev lcck9comfodog workingdog', 1),
#  ('hereeee ericprydz edc music musiclif edm danc girl', 1),
#  ('funni thing humankind watch news feel bad etc back open busi usual good futur',
#   1),
#  ('keep tell aryan allow rape women troll eod', 1),
#  ('speechless come shoot recent guess peopl noth lose respect', 1),
#  ('forecast beauti wave raalhugandu disappear due construct bridg amp there hope com',
#   1),
#  ('minut trump condemn vile bigot comment surrog carlpaladino endhat', 1),
#  ('wish wonder dad father day let rock today red rascal', 1),
#  ('allahsoil vp got multi million dollar bonus averag american lost home', 1),
#  ('love abrahamhick lawofattract healthi heal joytrain', 1),
#  ('sign first bikram yoga class', 1),
#  ('think thought shine face like sun beam quot smile', 1),
#  ('want creativ worker give enough time play success quot', 1),
#  ('hea prayer orlando victim famili lgbt commun', 1),
#  ('25 jan interest discrimin affect crimin justic system', 1),
#  ('friend forev friend sweden reunion grate love egna hem', 1),
#  ('keep opposit endthen', 1),
#  ('love pizza pizzaslic pizzaslice2 aoyama pizza yummi delicia goodtimeswithgo',
#   1),
#  ('two love beer craftbee dog malinoislov malinoi passion friend', 1),
#  ('abund posit affirm', 1),
#  ('fathersday father day dad skinni singl buy thing h', 1),
#  ('rickiti rick rickiti rick ole broken wagon look find next mateen jump board',
#   1),
#  ('love citi great day cleveland home calm', 1),
#  ('guess talk progress advanc misogyni homophobia bigotri', 1),
#  ('teen girl kill 3 other injur downtown oakland shoot gun mentalil gang orlando',
#   1),
#  ('everyon go struggl pain right keep head keep smile get hope', 1),
#  ('good even darl instagram babi bless lipstick makeup fun grate share', 1),
#  ('jake right 2 mani ppl lack power take stand amp drown small mind amp oft evil tendenc past',
#   1),
#  ('realli hate hipocrit politician side deserv better citizen', 1),
#  ('environment wellb plan site nothng todo w', 1),
#  ('bihday sway bihday sway bihday bihday', 1),
#  ('saturday morn go back sleep thetrust comus indi fade away johnmaun listen',
#   1),
#  ('founat man life everi singl day father day', 1),
#  ('gut know tonight would good luck', 1),
#  ('begin think tom bradi hater way goe man', 1),
#  ('attack orlando caus lot pain mani peopl vengeanc option let comfo', 1),
#  ('cute overload let life fill love sweet live long marri life', 1),
#  ('head graduat mechtechplumb futureplumb proudmama', 1),
#  ('possibl speak topic without bring race bigot', 1),
#  ('much terribl news weekend orlando christinagrimmi prayer', 1),
#  ('make innov nou', 1),
#  ('1465876849 66 updat social analyt instalik tbt yoga summer fun', 1),
#  ('rushlimbaugh incred obama impress via', 1),
#  ('peopl fail fellow citizen', 1),
#  ('sta pack move newflat', 1),
#  ('first love may make feel like love chees shotermlongdist', 1),
#  ('youtu bed two get friendship', 1),
#  ('want kind poor sin despis anyon jesu faith believ wisdom', 1),
#  ('nice life done tri lovequot', 1),
#  ('latest positivementalattitud thank posit', 1),
#  ('want spark seriou debat gun violenc releas photo bodi insid club orlandoshoot gunviol',
#   1),
#  ('arriv blagoevgrad fo zaz conc feel umbrela', 1),
#  ('number leader come', 1),
#  ('see tcashowroom yesterday', 1),
#  ('mean mean like', 1),
#  ('great way spend saturday relax positivevib california cakesbytheocean', 1),
#  ('eur usd could test 1 16 near term westpac blog silver gold forex', 1),
#  ('money campaign ask 100k donat midnight fight hrc ad buy brokedonald lyindon',
#   1),
#  ('today call champagn friday fridayfeel friyay goodweek client hair', 1),
#  ('rightli gop hate trump obama', 1),
#  ('sunday hug', 1),
#  ('2 us selfi myfriend loveh giannena smile thecomeback', 1),
#  ('moment decid need switch control life respons default', 1),
#  ('play yiruma kiss rain music song', 1),
#  ('simpl true becom capabl burnsurvivor dolbf motiv motiv', 1),
#  ('back miss greatfultogod beendoinggreat selfi', 1),
#  ('repeat put dog hot car leav heat keep home fuck sake dog', 1),
#  ('splendid nosi probabl year wrc rallypoland', 1),
#  ('2 hour go music video releas music edinburgh scotland band musicvideo', 1),
#  ('confirm dead accord farrah gray pulseshoot', 1),
#  ('look journey left right foot stage', 1),
#  ('black professor make assumpt entir race whilst speak entir race next week jew',
#   1),
#  ('back music play michael jackson lost children unificationsday may god children amp famili 33 smile',
#   1),
#  ('drakeandjosh buffalo simul buffalo take vicin home wa', 1),
#  ('trumpusa call us homophob misogynist realli say jealou us w', 1),
#  ('think suspend indefininetli racist staff', 1),
#  ('sat alon let sad sigh openrp bore', 1),
#  ('good morn manchest quick preview new gin launch soon one', 1),
#  ('tri new trailn2v3 today although feel similar v2 v3 smoother feel great',
#   1),
#  ('kiki felt ignor today make kiki danc kikid miabbook', 1),
#  ('sourc inspir ideal lyf baba father day', 1),
#  ('congrat thoma new beauti home tehaleh welcom lennar famili homeown', 1),
#  ('miss day friend play xbox', 1),
#  ('new case scraggli hair', 1),
#  ('love dincwear mum da word straight 16 saturday brickingit', 1),
#  ('bihday sexi girl girl top boy nake', 1),
#  ('one major fan like salti gsw fan need someon', 1),
#  ('chang daili basi 14week handov network team soon av', 1),
#  ('come singapor', 1),
#  ('sma babi sock gbp 19 00 get shop cool home fun', 1),
#  ('like video sjw retard want', 1),
#  ('woh wait doubledown wife veganbeerfest vegan', 1),
#  ('lmfao deadass', 1),
#  ('amaz interview bjmckenzi born2win bjmuzic', 1),
#  ('boasti tuesday last night boom boom harri hype say get', 1),
#  ('bihday balayya even age mass look craze fan screen romanc legend jaibalayya',
#   1),
#  ('woohoo kingsland highlandreserv hous famili build ourhom', 1),
#  ('outlin theme would poem haha', 1),
#  ('decor buffalo simul buffalo take vicin home way', 1),
#  ('sold one two paint go get beauti new home week sold', 1),
#  ('msg hope newyear busi end endof2016 tedtalk tedatibm', 1),
#  ('slag children love show realli', 1),
#  ('safe say miss marb sit home watch euro2016 listen rain depress bringbackhappi',
#   1),
#  ('brainwash left allow terrorist come america kill', 1),
#  ('gd morn gdragon gd kwonjiyong jiyong vip bigbang handsom cute love', 1),
#  ('friendszxc', 1),
#  ('4 day till vacat', 1),
#  ('secret happi marriag find peopl less attract repo', 1),
#  ('python27 concurr best friend code 2 restructur get concurr celeri develop python',
#   1),
#  ('womenareamaz think induoev superwomen follow dowhatyoulov', 1),
#  ('hairi pussi redtub hardcor track', 1),
#  ('let season 4 bing begin oitnb myfavorit season4 weekendplan', 1),
#  ('rest peac christinagrimmi loss rip miss fan foreverinourhea', 1),
#  ('pictur woh thousand word sundayrewind hongkong travel ladi lawyer', 1),
#  ('relax inger followm follow follow4follow beach pool relax enjoy coupl', 1),
#  ('countdown begun famili freeevent festiv enteain food stall', 1),
#  ('awesom beginn gopro mount super use', 1),
#  ('dear istor pleas crash due heavi overload 17 19 booktim muchlov', 1),
#  ('never underestim power good book good wine good food great patio summereven patioweath',
#   1),
#  ('istg best chees ta dayum expens', 1),
#  ('morn offic routin never without bff imi', 1),
#  ('theshallow weak attempt cash jaw anniversari', 1),
#  ('non stop elect blame cspan hide 8 year 2016 pittsburgh california', 1),
#  ('extrem reveal first offici poster poalorigin pa 2 come summer mo', 1),
#  ('16 minut count wwdc wwdc2016', 1),
#  ('play ball state polit facad lost princip', 1),
#  ('great day noth happi bless thank', 1),
#  ('happi sunday everyon sundaymorn sunday peac love', 1),
#  ('alway help other never peopl matter clearli quot latenight', 1),
#  ('bihday weekend even better xx', 1),
#  ('stay strong selflov love ilovem quot quot quoteoftheday happi life wisdom wordsofwisdom',
#   1),
#  ('happi father day boy father sweet love memori', 1),
#  ('life impoant human spirit truth love give b spiritu thinkbigsundaywithmarsha',
#   1),
#  ('father babi love u happiest father day father via', 1),
#  ('current mood web develop meet amp hire 6 22', 1),
#  ('know get old sta get turn look poweool b amp q', 1),
#  ('50 project 2016 busi hand happi hand', 1),
#  ('bride woman fine prospect happi behind ambros bierc wed love', 1),
#  ('friday xoxosamantha via', 1),
#  ('stop rob innoc custom hard earn aiim guy idea dey manag recharg', 1),
#  ('grab besti amp swing hour miss fun eat', 1),
#  ('opinion racism degrad peopl base race justifi discrimin open violenc stoprac',
#   1),
#  ('final move today', 1),
#  ('way say blogger vlogger', 1),
#  ('yay fantast edinburgh', 1),
#  ('lemm find put boiler month june', 1),
#  ('hea goe famili 50 peopl kill massacr orlando', 1),
#  ('pre gig drink passthecourvoisi', 1),
#  ('rescu pup meet rexi rescuepup rexi pupsofsg suicidegirl beauti puppylov',
#   1),
#  ('video get excit futur tech augment futur mobil', 1),
#  ('congrat ur wish come true work superxcit song', 1),
#  ('wish', 1),
#  ('hellosunday hope beauti sunday sundayfunday sunnday', 1),
#  ('gif listen song sinc age', 1),
#  ('nzd usd rise 0 7040 eye gdt price index fomc statement blog silver gold forex',
#   1),
#  ('true home food consid cheap meal impress made restaur', 1),
#  ('happi bihday one west greatest tupac shakur bihday rip tupac', 1),
#  ('live life', 1),
#  ('29hr go fl motionpost reveal mupparimanam feel nervou stay tune', 1),
#  ('littl tast sure', 1),
#  ('appletstag compleanno toa cake famili bday selfi smile girl summer', 1),
#  ('anim anim tree friend tag anim fana pixiv happi tree', 1),
#  ('happi 2nd wed anniversari amaz husband memori 2year lotstocom love', 1),
#  ('slow sta product day get back routin bout fatigu flareup hard spoonieproblem',
#   1),
#  ('love ramdan fast love iftar feel love way feel ramadan pray read quran bless',
#   1),
#  ('eur gbp subdu trade action around 0 7930 blog silver gold forex', 1),
#  ('ngitingtagumpay', 1),
#  ('unusu cloudi day elect day picnic friend sunday everyon welcomeludovica',
#   1),
#  ('cloudchas gorilla simul need adapt environ need tear citi mat', 1),
#  ('christ aliv vlicob xoxo love grace amen share passion church life', 1),
#  ('want leak udta punjab probe suspect polit job jobsearch chandigarh maker udt',
#   1),
#  ('yesterday ozen restaur eatallyoucan', 1),
#  ('alreadi tell next week episod gonna give intens anxieti nervou gameofthron',
#   1),
#  ('got noth say assum ahahahahahah', 1),
#  ('ordinari girl intruduceyourself', 1),
#  ('may light triumph dark may ramadan bring peac harmoni joy ramadan ramadankareem',
#   1),
#  ('any1 els notic suppoer r pageant girl w year intern femal oppress system',
#   1),
#  ('4 reason optimist rule world success growth balanc optim', 1),
#  ('hate onlin applic even get foot door tell need', 1),
#  ('thank flower thank posit', 1),
#  ('top crappi day w sign paper hous pop conc 4 block work amp know', 1),
#  ('beauti love live beach beach loveit', 1),
#  ('omg bitch knew gone lil kim actual look like music video', 1),
#  ('man even bunch coupon', 1),
#  ('way sta day goodmorn', 1),
#  ('lking forward 2 water hole watchtow foress', 1),
#  ('allahsoil next best seller book isi islam 2016in4world 2016in4word terrorist gwot',
#   1),
#  ('fantast rub steak yum thespicesndteaexchang dc healthi', 1),
#  ('followm touch tit', 1),
#  ('feel like summer love like live life enjoy healthi sun tan bikini summer',
#   1),
#  ('teenageson reckon gone beyond call duti fathersday prezzi', 1),
#  ('forget research show sexist men psycholog problem tuckercarlson', 1),
#  ('nice specif pedagog chang', 1),
#  ('typic citi fan', 1),
#  ('im attract asian ppl bc im asian tell im attract u bc im ins race hoe', 1),
#  ('awlrit mol jealou better cricket pitch life getalif', 1),
#  ('prayer go eddi famili', 1),
#  ('nothappi carer finish one week', 1),
#  ('closeencount fatkind fatkid dese sick tire maybemono', 1),
#  ('gymmorgon gym morn strength energi train wingym', 1),
#  ('glad arriv safe', 1),
#  ('defin histor oppress histor oppressor privileg', 1),
#  ('realli pretend truthseek empower selfimprov heal ihearadio', 1),
#  ('final found way delet old tweet might find use well deletetweet', 1),
#  ('view oregon poland usa unitedst holiday dj produc hous', 1),
#  ('put vote yet havent share see make smile poll', 1),
#  ('next chapter life sta soon look hous today fianc', 1),
#  ('book trip europ travelwis europe2016 london pari', 1),
#  ('thank oxygen thank posit', 1),
#  ('latest volatil daili thank space', 1),
#  ('someon explain moodi', 1),
#  ('worri', 1),
#  ('today nation smile power day show pearli white someon deserv make day one',
#   1),
#  ('radic counter terrorist see us inhuman free judg color', 1),
#  ('great appreci frm everyon u perform soo happi sir 11 hr go watch film gentleman',
#   1),
#  ('cuddl babi fun love', 1),
#  ('end era amazon final took final fantasi versu xiii entri databas', 1),
#  ('lot pakistani twitter folk make like total liber amp open mind deen imaa',
#   1),
#  ('littl anya fun wait 28 miler arriv ride 2016neotour', 1),
#  ('daddi day', 1),
#  ('sad leav first hous today look forward make memori new hous movingh', 1),
#  ('tend expos mood aist name song titl music', 1),
#  ('friday bbq surf rider hostel fueeventura barbequ hostel summer surf kitesurf wave fun holiday',
#   1),
#  ('cnnelect nice parrot racist talk point repo last night onpoint', 1),
#  ('stuff crazi fashion fun color gown fashiondesign design illustr', 1),
#  ('give depress get busi posit movement put good mood fit fresh', 1),
#  ('half want indulg lot yunho esp danc keep head today', 1),
#  ('tri later move institut 2 year row fail lol 2 3 year experi requir 9', 1),
#  ('fact keep watch make interest', 1),
#  ('like si regrann fffwithjanel liber', 1),
#  ('last day normalci star summer camp', 1),
#  ('turn year younger newyear newbless bihday thank grate', 1),
#  ('wait wale vs nz tonight eden park cymruambyth come', 1),
#  ...]

# %%
X_test = X_test.drop_duplicates(subset='tweet', keep='first', inplace=False, ignore_index=False)
X_test
# Out:
#           id                                              tweet
# 0      31963  studiolif aislif requir passion dedic willpow ...
# 1      31964   white supremacist want everyon see new bird movi
# 2      31965          safe way heal acn altwaystoh healthi heal
# 3      31966  hp curs child book reserv alreadi ye harrypott...
# 4      31967  3rd bihday amaz hilari nephew eli ahmir uncl d...
# ...      ...                                                ...
# 17191  49154  2 damn tuff ruff muff techno citi ng005 web 19...
# 17192  49155  thought factori left right polaris trump usele...
# 17193  49156  feel like mermaid hairflip neverreadi formal w...
# 17194  49157  hillari campaign today ohio omg amp use word l...
# 17196  49159     song glad free download shoegaz newmus newsong
#
# [15682 rows x 2 columns]

# %%
#For_Removed_Duplicate_Test_Data
from collections import Counter
occurrences_1= Counter(X_test['tweet'])
occurrences_1.most_common()
# Out:
# [('studiolif aislif requir passion dedic willpow find newmateri', 1),
#  ('white supremacist want everyon see new bird movi', 1),
#  ('safe way heal acn altwaystoh healthi heal', 1),
#  ('hp curs child book reserv alreadi ye harrypott pottermor favorit', 1),
#  ('3rd bihday amaz hilari nephew eli ahmir uncl dave love miss', 1),
#  ('choos momtip', 1),
#  ('someth insid die eye ness smokeyey tire lone sof grung', 1),
#  ('finish tattoo ink ink loveit thank aleee', 1),
#  ('never understand dad left young deep inthefeel', 1),
#  ('delici food lovelif capetown mannaepicur restur', 1),
#  ('1000dayswast narcosi infinit ep make awar grind neuro bass lifestyl', 1),
#  ('one world greatest spo event lemans24 teamaudi', 1),
#  ('half way websit allgoingwel', 1),
#  ('good food good life enjoy call garlic bread iloveit', 1),
#  ('stand behind guncontrolpleas senselessshoot takethegun comicrelief stillsad',
#   1),
#  ('ate ate ate jamaisasthi fish curri prawn hilsa foodfestiv foodi', 1),
#  ('got limit edit rain shine set today', 1),
#  ('amp love amp hug amp kiss keep babi parent healthcar', 1),
#  ('girl sun fave london unit kingdom', 1),
#  ('thought factori bbc neutral right wing fascism polit media blm brexit trump leadership gt 3',
#   1),
#  ('hey guy tommorow last day exam happi yay', 1),
#  ('levyrroni recuerdo memori recuerdo friend life triunfodelamor', 1),
#  ('mind like bodi like sleepi stillallin', 1),
#  ('never entir life', 1),
#  ('check twitterww trend trend worldwid 11 14 bst 1 oscarpistorius2 diplom liselilerayakta3',
#   1),
#  ('thought saw mermaid ceege smcr inshot girl cute summer blur sun', 1),
#  ('chick get fuck hottest nake ladi', 1),
#  ('happi bday luci xoxo love beauti pizza instagood mileycyru demilovato', 1),
#  ('haroldfriday weekend fill sunbeam everyon healthi weekend', 1),
#  ('tri noth tri know love 2 3rd light fave amp deep river', 1),
#  ('never 120 thick women blacktina', 1),
#  ('new episod tk realli cool 2 year anniversari ep work august', 1),
#  ('orangechicken attack bull game 3d realli think head empti around citi side',
#   1),
#  ('suppo taiji fisherman bulli racism tweet4taiji thecov seashepherd', 1),
#  ('say speak collect alway known 2016 show lot', 1),
#  ('wish could talk', 1),
#  ('food time hayli hot chocol mummi thank god friday', 1),
#  ('snow white gt open gt sleepi sneezi bash dm us today', 1),
#  ('bihday shilpashetti wish success yearretail manufactur ladi cloth', 1),
#  ('lotteri', 1),
#  ('tomorrow fun see old friend shoot someth super fun', 1),
#  ('raw food diet benefit altwaystoh healthi heal peac joy love', 1),
#  ('trump invest billion saudi empow peopl fund isi trumpsahypocrit', 1),
#  ('granddaught 1st bihday tomorrow go pick play hous littl car amp pool today',
#   1),
#  ('happiest place eah disneyworld orlando castl mickeymous likechildren', 1),
#  ('babi dave due born octob 26 fav band time tool play weekend lol', 1),
#  ('love everi day', 1),
#  ('morn sunshin smile sexi bigboob', 1),
#  ('world make jesu make happi john 16 33 word truth faith peac', 1),
#  ('food heal bodi doplant healthi', 1),
#  ('enjoy sunshin god good orlando sunshinest goodlif bossladi joy', 1),
#  ('father idol prg', 1),
#  ('reason maintain android provid clear basic code exampl doc', 1),
#  ('nice luxuryweek monday neweek luxuryweek bestday stayposit fun goodmoment lifestyl',
#   1),
#  ('caus get live togeth whole week cantwaittocook', 1),
#  ('throw back thursday bih day 2 bro chege', 1),
#  ('thank fun thank posit', 1),
#  ('saw cray coz babi hard breath strong yeah babi god kaika medic center', 1),
#  ('happen babi duedec2016', 1),
#  ('let thing euro2016', 1),
#  ('time euro2016 onemonth 24team onewinn footbal intern 10thjune 10thjuli', 1),
#  ('model love u take u time ur', 1),
#  ('lighttherapi help sad depress altwaystoh healthi', 1),
#  ('good sunday everyon sunday morn smile picoftheday', 1),
#  ('cousin ask alway shawl di ko lang masabi coz po get fat braso get bigger baboy',
#   1),
#  ('believ r willing 2 tri 2 understand 2 encourag amp 2 inspir other 2 b amp grow greater spiritu purpos grok',
#   1),
#  ('time pint see coldplay wembleyyyi coldplay wembleystadium', 1),
#  ('current mood goodnight happilyeveraft disney quot bless thank grate', 1),
#  ('chioma nobl igw special day chobs16 chobs2016 landmark centr', 1),
#  ('cant believ left school 5 year ago 8 week time ill teach class drama teacher gettingold',
#   1),
#  ('lipo light help shape help shape learn loseinch burnfat result', 1),
#  ('ahhh leav tomorrow eforest2016 electricforest plur', 1),
#  ('bless hear morn choru good morn peopl friday', 1),
#  ('aunti mi find hilari post nigeria enough troubl', 1),
#  ('6 chapter left book amp nearli complet kruella adaughterstal hard read emot funni',
#   1),
#  ('thrill work come month announc soon 2faceddancecompani', 1),
#  ('tri anoth way make sourdough bread one may underproof fail bake', 1),
#  ('cool old door window 50 00 vendor 509 shoploc shopalyssa fathersday', 1),
#  ('fathersday fatherday team', 1),
#  ('greatbritain eye sky rafredarrow fli past mall say', 1),
#  ('8000 follow bless love everyon suppo us thx much fish f', 1),
#  ('lt feed public trough piggi michelleobama', 1),
#  ('websit live avon makeup fresh look', 1),
#  ('forecast look good weather across bolton', 1),
#  ('happi shoot love monica sweet magazin thanku love', 1),
#  ('happi father day father day fathersday dad ilovemydad ilovemyfath love', 1),
#  ('stardivariu friday new histori new outfit post fashion look friendsfl', 1),
#  ('final countdown offici us public june 1st whyfontsmatt usa typographi font book',
#   1),
#  ('happi trust first know lovelovelovebabi', 1),
#  ('interview feat grandmast flash ze love messag nurap nudisco music pari via',
#   1),
#  ('get hour work train', 1),
#  ('life right amaz success posit', 1),
#  ('social media realiti realli get viual accept seem realli thing ocialmedia',
#   1),
#  ('seven tomorrow southwestseason final next week plu scrim wearebusi', 1),
#  ('ignor amp ill inform tweet r silli childish amp one dimension', 1),
#  ('great see look forward welcom digm', 1),
#  ('jackblair na horni hot naughti nasti slut young shi wet nude xxx sexi porn kinki snapshot',
#   1),
#  ('u take pour one big cup drink deliv', 1),
#  ('happi father day dad hope u great day love u fathersday lovey', 1),
#  ('work anatomi studyguid sinc 5 pm still done isuck plspassm', 1),
#  ('worri daydream sunlight thunder miss dream distanc silenc pain sweet', 1),
#  ('get readi kubamba father day kambua noel gg moh bless', 1),
#  ('ya know guy feel stress donut thing feel happi know 96 follow stick', 1),
#  ('pa 2 jk fun memori bff love', 1),
#  ('electron music bogota colombia puntohost cedm edm dj fashion music', 1),
#  ('back peopl missingperson havingfunalon lone hothl', 1),
#  ('l v e sky photoofday moment cool instaphoto paradis good mexico', 1),
#  ('happi saturday tune music saturday edm', 1),
#  ('mani alum friend wake shock hear death scsu presid shock', 1),
#  ('disappoint yesterday argument even baselessli accus live mother basement weak bad',
#   1),
#  ('hey 14000 ivanka bracelet feel good profit xenophobia misogyni hatr grabyourwallet',
#   1),
#  ('love saw temporari setup', 1),
#  ('happi euro 2016 eve euro2016', 1),
#  ('741 retweet half day gun owner like hubbi amp respect fanatic', 1),
#  ('colourpop', 1),
#  ('palladino say feel like say gopathet lookwhatyoudid polit madcow', 1),
#  ('save login x broker chang meme love educ univers', 1),
#  ('fursuit fuck hardcor 2008', 1),
#  ('someth obvious realli funni laugh girl smile', 1),
#  ('fbf sta far come amp anxiou', 1),
#  ('thank film thank posit', 1),
#  ('way oambo see soon sasocp16', 1),
#  ('alway alway alway somebodi els fault bigot', 1),
#  ('begun someth new page amp super daili tarot guidanc', 1),
#  ('turn today whitegirlwast dramafre armedsecur', 1),
#  ('qatil poetri poetri eid poetri 2 line sm eid ghazal urdu poetri dard poetri beuti poetri follow send 4o4o4',
#   1),
#  ('rip victim usa prayfororlando terror victim lgbt suppo altogeth pride stand',
#   1),
#  ('grate affirm', 1),
#  ('read aicl 4 yr even dhaba side nation highway grow 1 2 acr ganja', 1),
#  ('drive see greas amp footloos', 1),
#  ('thank steve think quit sunk though', 1),
#  ('today good day happiestplaceoneah disneyland fun walk sundayfunday', 1),
#  ('ltpst need vitamin sea beach blue smile', 1),
#  ('today code white summer love', 1),
#  ('rainbow wall street good way end train officialrainbowspott', 1),
#  ('water', 1),
#  ('go great day day choic matter feelinggood proud feelingaccomplish motiv',
#   1),
#  ('oh ton stuff like eah garbag dump', 1),
#  ('found vault never post selfi throwback boy guy love', 1),
#  ('happi friday wegotwheel car vw polo firstcar ontheroad whitepolo newcar',
#   1),
#  ('togeth christma pl amp follow nation day action 20 feb amp', 1),
#  ('might libtard libtard sjw liber polit', 1),
#  ('withasumi yesterday shot disney disneyland enjoy', 1),
#  ('game throne s5 longer sky box set mad help', 1),
#  ('straight chaser music video', 1),
#  ('4u nonhockey peopl hockey babe ruth die gordi howe beyond myth legend hockey lost mr hockey',
#   1),
#  ('linkedin anyth work give free membership canadian australian british veteran justusvetsatm',
#   1),
#  ('michelleobama look bit dishevel think spend retir visit obama', 1),
#  ('dinner lukey boy lovehim holiday orlando clear creek circl', 1),
#  ('wait watch everyon even', 1),
#  ('hahaha good point total skip 14 celebr dad ask', 1),
#  ('cat bag fruit ninja steam htcvive', 1),
#  ('nation german bestfriend day mayb', 1),
#  ('realli good cook credit mash potato mac n chees', 1),
#  ('local mp downgrad hospit savethealex', 1),
#  ('pretti much best advic ever hydrat zerofucksgiven friday sorrynotsorri live',
#   1),
#  ('model altern tattoo pierc old town bellevu', 1),
#  ('sent msg aunt peru told wish grandpa uncl happi father day includ dad', 1),
#  ('day best', 1),
#  ('peopl protest trump republican trump fuher amp', 1),
#  ('work attorney white offic shot philandocastil remov black judg presid trial',
#   1),
#  ('phil spencer critic soni cours els would got slap face soni huge 40 million dick',
#   1),
#  ('think sa pretti great wait show twodaystogo countdown shhh bringiton', 1),
#  ('w cafeexpress stanupcomedi crazi', 1),
#  ('trump long histori explain 1970 thru 2016 nevermypresid theresist', 1),
#  ('happi mother day ppl', 1),
#  ('bff liverpool first stop flatwhit coffeelov bestfriend', 1),
#  ('love', 1),
#  ('tom hiddleston aka loki excus spell new jamesbond scaryinthor bestchoicefornewjb',
#   1),
#  ('watch movi alon', 1),
#  ('one think could bit punch gameofthron', 1),
#  ('princess one princess sadli', 1),
#  ('cant wait icon weekend wait final get one tatoo icon16', 1),
#  ('laugh fact mfz use app talk u feel insid peopl see haha', 1),
#  ('sterl attack bull chase leav lot despit fact strong sourc fo', 1),
#  ('final found way delet old tweet might find use well deletetweet', 1),
#  ('never doubt pa mani vote sad america', 1),
#  ('cut anyon english dna half well find written insid', 1),
#  ('vip ciniworld caz', 1),
#  ('see war craft imax 3d warcraftmovi imax woohoo', 1),
#  ('burnt garlic bread devast', 1),
#  ('look right cameraman grab kati arm amp said talk wow everyth tv', 1),
#  ('held one march great cpd everyon', 1),
#  ('look african news boredem stumbl upon oh god site racist fuck everyth', 1),
#  ('dana devest troubl', 1),
#  ('gorgeou posit affirm', 1),
#  ('oh admit small staff flipflopp disgrac', 1),
#  ('happi instagram instagood instagram instapasspo instadaili', 1),
#  ('splash around dog bestdogev swim healthi goodvib yoga fit', 1),
#  ('peopl old bore resolv bulli other twitter', 1),
#  ('much violenc last euro wonder happen brutal side come back euro2016 footba',
#   1),
#  ('mess nail', 1),
#  ('lighttherapi help depress altwaystoh healthi happi', 1),
#  ('aww yeah good bing bong bing bong', 1),
#  ('selfi srelfi smile selfi followm f4f polishgirl polskadziewczyna', 1),
#  ('vera rubin overcam invent whole field scientif studi diversityinsci scienc steam',
#   1),
#  ('sorri read much pain', 1),
#  ('draft 1 b4 pick uni liverpool recognit', 1),
#  ('gbp usd upsid limit around 1 4255 1 4350 commerzbank blog silver gold forex',
#   1),
#  ('childrenoftheworld bull domin bull direct whatev want', 1),
#  ('kaya class', 1),
#  ('london selfi smile love photooftheday picoftheday london londonlif', 1),
#  ('need prayer right take grandma death well shock whyher', 1),
#  ('seen gay gorilla mindset nonsens tout dershowitz clean', 1),
#  ('think go best match ever watch wed oldgirl auwfc', 1),
#  ('unfoun current gop see reagan like', 1),
#  ('monday instagram instagramm motorspo photograph formula1', 1),
#  ('great day littl man tkd grade amp crack swim lesson top wale win wal', 1),
#  ('sorri bear time', 1),
#  ('wait pubcon bestconfer oct16 digitalmarket comingsoon', 1),
#  ('monday u model boob tit urbex televis sexi retweet tight pantyhos desir touch',
#   1),
#  ('glad live place', 1),
#  ('fam ili fast famili likeforlik like4lik lfl togeth happi love', 1),
#  ('starship nickiminaj 6secondcov singitfohevin singersofvin sing musician music',
#   1),
#  ('thrill posit affirm', 1),
#  ('make someon happi today mind damn busi life live inv busi love', 1),
#  ('paradis rooster simul want climb vast expans mountain reach leakag cock w',
#   1),
#  ('pats2020 student want snapchat adrianmcqueen snapchat ucumberland colleg',
#   1),
#  ('client need brainstorm socialmedia altrincham', 1),
#  ('disney gator attack 2 year old boy found dead disney', 1),
#  ('price stolen payment card record drop 25 2011 6 2016 ransomwar rise', 1),
#  ('got free slice cake fav cafe tgif', 1),
#  ('box pictur contain singl inflat prep school boy sex doll', 1),
#  ('relax peac', 1),
#  ('first new custom paner drupa2016 hall 10 stand c13 3', 1),
#  ('love instagood photooftheday top tag tbt cute beauti followm follow', 1),
#  ('sinc last time drank hard liquor officem', 1),
#  ('older peopl see pic nose rememb smell close impoant site like', 1),
#  ('socialmedia may 2016 hottest may record nasa', 1),
#  ('say abl attend year due hotel cost hope attend next year tho', 1),
#  ('hea spazz ship hahaha doctor', 1),
#  ('nearli readi nohamptoncarniv', 1),
#  ('mani innoc peopl die ceain politician choos ignor hate refus even discuss gun control',
#   1),
#  ('almost week sinc saw stroke', 1),
#  ('sta newbook visit jfk museum inspir', 1),
#  ('intellig posit affirm', 1),
#  ('heal lawofattract loa altwaystoh healthi well', 1),
#  ('fatal truck crash kigali highway leav 30 peopl die instantli around kicukiro centr rwanda',
#   1),
#  ('macbook gorilla simul need adapt environ need tear citi materia', 1),
#  ('marshmallow time fire son love', 1),
#  ('believ much use care peopl thought like lol fuck u fuck wtf fuck', 1),
#  ('jealou best mother mamatii je aim cute nice', 1),
#  ('alway amaz come unexpect place like local cafe today irish got first muslim gut',
#   1),
#  ('icedcoffe coffeeblogg coffe thecappuccinotravel', 1),
#  ('ever get lyme war yeah help', 1),
#  ('p5 pupil readi ymi music extravaganza', 1),
#  ('made laugh hard angri bieber dontknowwhi fridayfun', 1),
#  ('grow old along best yet robe brown wed love', 1),
#  ('usd jpi bull sit tight 107 handl fxstreet blog silver gold forex', 1),
#  ('fail terribl control drug must punish elector let initi blue fb', 1),
#  ('never see store anymor ask autograph said hi time', 1),
#  ('rest peac christina rip ripchristina christinagrimmi love miss', 1),
#  ('alway watch one race inspir train still got solid month yet 1st race', 1),
#  ('see pictur dog today smile face tweet good', 1),
#  ('woke af realiz world around chang sigh', 1),
#  ('love return coollim starbuck cool lime feel fresh nice great drink', 1),
#  ('could wors embarrass unfoun traumat bitch black live matter black peopl',
#   1),
#  ('tech buy bitcoin debit card', 1),
#  ('happi father day father fathersday sunday famili', 1),
#  ('thank freedom speech thank posit', 1),
#  ('justinb gorilla simul need adapt environ need tear citi materia', 1),
#  ('still fuck bullshit give bigot platform spread vile hate boy', 1),
#  ('girl boy p sissi', 1),
#  ('bihday flower saturday flower love je b jewelri studio', 1),
#  ('even think wear dad jean', 1),
#  ('anoth nerd friend ban person believ snotopenmind ohwel', 1),
#  ('alway race religion wrong w america', 1),
#  ('sometim take realiz person realli fit life friend soon boss', 1),
#  ('back day job shane lowri gt gt', 1),
#  ('fathersday strongest patient kind understand person know', 1),
#  ('third wheel cold stone right use buy one get one free coupon', 1),
#  ('simpli assault equal spit someon author got charg wrong guy walk', 1),
#  ('get tweet marriag wale', 1),
#  ('93 video 16 refer sen warren pocahonta stabl pattern ignor', 1),
#  ('make meer inspirati kijk op life', 1),
#  ('hous taken footbal time get read alway love book', 1),
#  ('end day gotta', 1),
#  ('cleveland fan look', 1),
#  ('bubbl posit affirm', 1),
#  ('get readi deliv featur address bright eye group youngster nervou', 1),
#  ('smoothi glass half full comeon', 1),
#  ('wednesdaywisdom make sure ignor true happi life', 1),
#  ('trust broken right', 1),
#  ('iftar happyhous besti friend chillin iftar goodtim tgi friday street', 1),
#  ('realiz look littl cross eye licens lol', 1),
#  ('go fun week 10 day csikraken construct', 1),
#  ('bihday sweet littl mermaid time flown quickli believ', 1),
#  ('30 000 arrest daili us 160 000 polic civilian encount daili shoot abus extrem rare tho',
#   1),
#  ('thank inspir thank posit', 1),
#  ('wish kpop aist never come countri abl see perform broke ppl kpop', 1),
#  ('want go anywher sunday sinc ghosthuntersintern destinationtruth chillernetwork',
#   1),
#  ('father day', 1),
#  ('thank health thank posit', 1),
#  ('peopl judg colour english accent', 1),
#  ('9975 lostnfound got togeth want seriou long term monogam relationship', 1),
#  ('cc without aciiii eki liani fetti cc emerg team friend famili like love',
#   1),
#  ('black live matter today day', 1),
#  ('usd jpi remain weak 106 00 blog silver gold forex', 1),
#  ('charact custom confirm pokemonsunmoon e32016', 1),
#  ('emma great meet yesterday email oppoun alreadi', 1),
#  ('poor babe miss water play morn school figur water play afternoon poorbabi',
#   1),
#  ('let light hmmm prefer l spotlight vibrant aliv joy sparkl', 1),
#  ('today good day love goodday smile goodangl instasmil instagram', 1),
#  ('realli terribl mass terrorist attack usa night club black day', 1),
#  ('hear bigotri homophobia sexual assault woman treason lie hear', 1),
#  ('know posit affirm', 1),
#  ('right one suppo women nutrit romanc love date soulmat sexi', 1),
#  ('hate crisi among mani other presid elect amp co capabl', 1),
#  ('wonder saturday flower day vine', 1),
#  ('guess chip hill teach kid spell mp might littl hard u', 1),
#  ('got wine v happi', 1),
#  ('deserv much better understand endors stand much', 1),
#  ('thank reach issu resolv turn site fulli compat safari io maco', 1),
#  ('happi bday jb yesterdaycelebr fambam feel happi', 1),
#  ('bihday libat feat gay boy cute friend love', 1),
#  ('bihday majesti', 1),
#  ('sleep cri', 1),
#  ('live color check new tote bag color life totebag inspir ht', 1),
#  ('thank much realli feel amaz', 1),
#  ('pimp hoe hooker point documentari brent owen cathous seri kid lol', 1),
#  ('goomespa divulga oeparceria inshot girl cute summer blur sun fun dog hair',
#   1),
#  ('sad true true', 1),
#  ('anim cat cat grumpi cat happi camper treat play', 1),
#  ('aww poor ednahhthepug missingmommi sit wait time', 1),
#  ('nice deliveri today manfrotto peakdesign photo photographi tripod strap bag',
#   1),
#  ('smile filter instamood picoftheday behealthi summer bliss bitchpleas', 1),
#  ('pre order 3d browton beautyblogg icantwait', 1),
#  ('luther vandross danc father father day', 1),
#  ('enslav anim okay', 1),
#  ('dark', 1),
#  ('ah man sunday come round quick enough thestoneros', 1),
#  ('got first liquid lipstick love girl', 1),
#  ('first bubbl 40yr old self champagn celebr thank pete gemini bihday inde',
#   1),
#  ('patriotwatch 4 11 sherm new year gap auspol rwnj drunk refuge asylum', 1),
#  ('accept fact appl lost innov sta rip android', 1),
#  ('shock amp hear christinagrimmi past away thought amp prayer rwith famili time ripchristina',
#   1),
#  ('hey love music realli perform murder azerbaijan dictatorship', 1),
#  ('new ted baker ski top surpris hubbi lucki loa lawofattract', 1),
#  ('love hello kitti model pink girl girli yolo smile pop', 1),
#  ('ur gunna miss', 1),
#  ('meet today volunt run local librari went kid givingback pocintech', 1),
#  ('whenev sad close eye rememb happiest moment life life lifequot thought', 1),
#  ('wait see iron maiden first time next sunday', 1),
#  ('never previou secretscreen starmoviessecretscreen shh come', 1),
#  ('mikoto suoh kproject mikoto vine cassidytheduck', 1),
#  ('thought factori left right polaris trump uselections2016 leadership polit brexit blm gt 17',
#   1),
#  ('sunday', 1),
#  ('biographi step cousin denis got ear mite use payphon', 1),
#  ('4 merri behappyandsmil behappyandsmilealway behappywithm likesm', 1),
#  ('tgif ff gamedev indiedev indiegamedev squad', 1),
#  ('go eat shit dog anti american piec shit bet dad fuck mouth trump nazi', 1),
#  ('realli happi graduat childish shit graduat done', 1),
#  ('would live life grate compass love one anoth without', 1),
#  ('mani hash tag', 1),
#  ('tyler ward amp cimorelli cover pharrel william music video', 1),
#  ('huaweiceifiedspecialist pre sale accessnetwork deliv ye stress sno', 1),
#  ('look forward bean caramel macchiato definit burnt memburi servic', 1),
#  ('oh word think awar ghastli there someth broken soul need', 1),
#  ('tap gratitudejourn benefit without journal entri pressur gratit', 1),
#  ('suppos confirm even read teleprompt', 1),
#  ('great screw job 2016 cannot catch break impactonpop impactwrestl', 1),
#  ('tomoz nite hit stoke go fab night glad im go besti 3rdr', 1),
#  ('last formteach lesson byebye8year', 1),
#  ('care care alon', 1),
#  ('way door counti wisconsin weekend vacat car foreverdr indi travel vacati',
#   1),
#  ('poor world', 1),
#  ('realiz laker fan make u hate everi western confer team cant root 4 dub impetti lakers2017 kobe',
#   1),
#  ('mind boggl dontunderstandtheconswqu', 1),
#  ('like true fals stephen keshi die na waoh life eh one thing dey rememba abt say dey alwaz chew gum',
#   1),
#  ('trigger impuls decis strike haha netherworldforess tier 1', 1),
#  ('alway ministradesanidad', 1),
#  ('singl word requir wast everyth wha actual', 1),
#  ('mercuri engin amp mercuri cloudcov truli attend prestigi event data datacentr',
#   1),
#  ('cant alway alway posit inspir gepaforum', 1),
#  ('tbt capetown tablemountain dad ghel bakh bihday lafamilia', 1),
#  ('new tenant collect key 9am propeyh move apament', 1),
#  ('see u soon stratton u attend come find us wanderlust fashion', 1),
#  ('think happi stay happi', 1),
#  ('wait join us garden walk', 1),
#  ('ye today day get giddi orangeisthenewblack season4 obsess', 1),
#  ('slfl conc week away x', 1),
#  ('saturday peopl hope hungov listen newsong band unsign', 1),
#  ('recogn amp acknowledg relationship god give need succeed', 1),
#  ('book tick see cha amp dave wait', 1),
#  ('wonder wifi work anymor wifi wifiproblem wifioverload wifisuck suck network',
#   1),
#  ('idea stupid comment make invit respons death sideshow', 1),
#  ('check daddydub super father day u 1 best father 4 gr8t', 1),
#  ('black live matter group black extremist', 1),
#  ('raini day blue got get fishtaco wednesdaywisdom manhattan lunchbreak dontworrybehappi',
#   1),
#  ('spend life peopl make quot inspir', 1),
#  ('good news digitalmarket campaign use facebook ppc extrem annoy 20 rule socialmedia',
#   1),
#  ('first ever time govern build oireachta leinsterhous dublin parliment', 1),
#  ('would like thank peopl follow realli appreci author novel writerslif book sciencefict creativ',
#   1),
#  ('yeieee jito ya haro bt ur gang alreadi wo million hea fir bhi hope aapka gang jeetey',
#   1),
#  ('make choic better self selfimprov betterlif anxieti happier struggl behappi',
#   1),
#  ('typic ghetto po politician refus take paint cop poray pig feder bldg', 1),
#  ('new addit newaddit fblogger', 1),
#  ('thank transpo thank posit', 1),
#  ('latest knit clio daili thank twitterstorian', 1),
#  ('toptweet like one venusexchang', 1),
#  ('keep compani borderjack cuddl', 1),
#  ('love ron definit peopl rank amp file complac worst', 1),
#  ('father day samsung galaxi s7 shakey usa', 1),
#  ('thank love thank posit', 1),
#  ('hello 14 18pm warm oman see share sunshin', 1),
#  ('summeim gorilla simul need adapt environ need tear citi mate', 1),
#  ('lesson happi life via', 1),
#  ('got noth word weep orlando heabroken', 1),
#  ('nope uncl buster sound like jerk trumpsamerica', 1),
#  ('look old harrypott expens 200 small set alreadi open use sodisapoint', 1),
#  ('nice readi come oakland marijuana busi boom california', 1),
#  ('u rip front bumper mazzi curb day buddi', 1),
#  ('girlz wanna fun girl babi love selfi', 1),
#  ('easter meanwhil white hous', 1),
#  ('weekend sho amaz time friend famili summerisher lovedthisweekend', 1),
#  ('littl known fact miller lite ped list lbjdrinksonlyjuic', 1),
#  ('caus lost', 1),
#  ('still women wow', 1),
#  ('first day new diet gone well nice healthi salad tea relax product star', 1),
#  ('okey know latest tweet bit clitchi hey like u care idontcar', 1),
#  ('brutal rule new year manu close manu auspol australia refugeeswelcom nobord',
#   1),
#  ('find awesom shi sho broad one', 1),
#  ('sta read last day first sign summer', 1),
#  ('sad guy kill warrior team soon', 1),
#  ('agre time chang tune floor vote', 1),
#  ('tbt age sixteen success posit quot choic kind love thursday win', 1),
#  ('father day love dad may live long ameennn lifee', 1),
#  ('tweet seriou still comment', 1),
#  ('saturday', 1),
#  ('coolestlifehack brazilian gold frog smallest frog motiv', 1),
#  ('come soon amazon coloringbook oliviagraceowen', 1),
#  ('chatter girl guid choci alicia marco birong radio sholi click link', 1),
#  ('hors maximu', 1),
#  ('littlest thing make', 1),
#  ('believ man jose follow hope guy crush baltimor tonight joeybat longbal', 1),
#  ('en rout happi monday monday freshsta newweek newm glassalwaysful', 1),
#  ('frobabi frobabi naturalhair babyfev melanin love famili cute', 1),
#  ('nakedbusti love much', 1),
#  ('think beauti tricoloredamericanbulli bluetri pitbul babi', 1),
#  ('pilat perfect sunday kxpilat getfitordietri boomerang kx pilat hampton', 1),
#  ('god see u wan hype father day smh', 1),
#  ('said b4 world encash wherea india loos legaci due bicker amp politicis yoga',
#   1),
#  ('photo last year', 1),
#  ('gotta love staffi doglov mansbestfriend', 1),
#  ('brisk vagabond night dayz black mamba ng049 web 2005 ukhx int next gener web hardcor',
#   1),
#  ('thank manag', 1),
#  ('good morn dearo saturday', 1),
#  ('honor present three megratrend int l student mobil aiec2016', 1),
#  ('thing wors put word mouth dead peopl taunton hitchen atheism', 1),
#  ('spring green latest auspol election16 news friend victorian green springst auspol',
#   1),
#  ('instracistclown meme instagram funnyp nochil funnymem chill 100 de', 1),
#  ('say dad made better dad say dad gave brother amp niec nephew', 1),
#  ('kid afraid go wait', 1),
#  ('dishwash origin draw', 1),
#  ('see new webpag orlando file goodread goodbook bookclub top10 medicalthril',
#   1),
#  ('see ritzpari reopen lhw showcas amaz even royalpalmmarrakech bchotel', 1),
#  ('play game joke', 1),
#  ('play joe bongiorno mystic music song', 1),
#  ('hope wonder weekend monday good sta week', 1),
#  ('summer seem last forev summer walk sunni magic beauti natur sky', 1),
#  ('tri someth good alway end feel like shit hate', 1),
#  ('goodmorn uk today world need love hate less peac smile', 1),
#  ('gonna stop tri grow beard give rest leav pro', 1),
#  ('bihday favourit brit awesom time bbqing drink', 1),
#  ('tomorrow sta plan niec nephew babi shower', 1),
#  ('look forward repo ccm due public month', 1),
#  ('thoughtcast sac 000 26 photooftheday music instamood photographi instadaili nike famili design',
#   1),
#  ('absolut pathet trust', 1),
#  ('right 2 without stress fear human right live', 1),
#  ('amaz day surpris movement', 1),
#  ('caffein fix quick cup coffe posit appreci friend love creativ', 1),
#  ('green jamesmcavoy aton mcavoy flim', 1),
#  ('pass last exam made new lash thank studiia lakshmi student', 1),
#  ('easter new hero', 1),
#  ('peac love ooh ooh brighton woopwoop busker drummer kidsdrumm brighton', 1),
#  ('bonn f te jeff bihday happi bihday jeff happi bihday happybihdayi h', 1),
#  ('god help parent lose child antonyelchin', 1),
#  ('somebodi tell thepeopl chose hispeopl choos trump big differ', 1),
#  ('awesom humpday vibe wellbeingwednesday morn motiv', 1),
#  ('winner harriet sturgess receiv iow festiv ticket winner domino', 1),
#  ('7 step age healthi', 1),
#  ('put tear muslim muslimwomen islam america americanignor', 1),
#  ('thank abl see thank posit', 1),
#  ('word factori race denial prevent heal southafrica leadership transform inequ gt 5',
#   1),
#  ('badventcalendar day24 nov 8 trump election2016 donat f kin save 2016', 1),
#  ('happi father day daddi daughter danc sweet love dad fathersday', 1),
#  ('fed provid inadequ mentalhealth care firstnat intern memo thirdworldcanada',
#   1),
#  ('latest unsw daili thank ocean', 1),
#  ('well yvr pa time head back real life yow great trip overal much done ellatravel hotweath',
#   1),
#  ('old guy sleep safe amp', 1),
#  ('happi friday shot blog blog blogger friday fashion style', 1),
#  ('father day amaz daddi amaz fianc loadz love kim mark nd morgan xxxxxxx', 1),
#  ('happi joy sorri deepak follow love brief releas', 1),
#  ('bestsel motiv never go bed without dream wakeup without hope', 1),
#  ('healthi lunch go botan nutrit skincar health', 1),
#  ('time go make polit', 1),
#  ('much appreci dear probabl issu wrong time thank suppo standard', 1),
#  ('happi place smile inspir', 1),
#  ('preorder playingitmyway autobiographi avail nov 6th ex', 1),
#  ('resili capac recov quickli feel deflat beat self past stay', 1),
#  ('new diari dairi love write amaz love quot wordsofwisdom word happi', 1),
#  ('site lt 3 freedom isi ignor amp selfloath sick bunch', 1),
#  ('oh boy sta unattribut depend innuendo fear bait weak ralli cri', 1),
#  ('love friday ilovecarnivalseri hour weeekend fridaychil chilln', 1),
#  ('anoth sneakpeek final prepar next week', 1),
#  ('myopic guess money mean peopl need leav coach forev 1 year', 1),
#  ('realli quick 20 minut flower paint love old palett', 1),
#  ('good old fashion public shame order', 1),
#  ('sure sleep w follow everi lap know fav', 1),
#  ('refus bake cake convict get convict cou sell abo babi pa amp get reward',
#   1),
#  ('life right bless oppoun career', 1),
#  ('marathon bull domin bull direct whatev want', 1),
#  ('everybodi necessarili want admit like gej asham associ wt', 1),
#  ('thank laughter thank posit', 1),
#  ('weekend amp ramadan everyon tri find dream propey weekend us dubai uae', 1),
#  ('live carnabi store seen anyon onion kitchenlif', 1),
#  ('sat watch', 1),
#  ('twitter kind recent go ignor', 1),
#  ('troubl updat blackberri passpo 10 os 10 3 2 2836 alway stop instal 2 2 44 need help',
#   1),
#  ('cook book come soon chef b lander share hit recip privatechef', 1),
#  ('actual argument hatr rm reso name call raider', 1),
#  ('architectur attack bull game 3d realli think head empti around citi side',
#   1),
#  ('final found way delet old tweet might find use well deletetw', 1),
#  ('cuti fun manli sydney hugo friend sydneywint beer laugh', 1),
#  ('need sleep laughter antidot depress', 1),
#  ('great wait long final get join pay wale togetherstrong bbceuro2016', 1),
#  ('happi work confer rig ht mindset lead cultur develop organ work mindset',
#   1),
#  ('close book wed date cannot wait share pictur u beautifulhighbarn', 1),
#  ('one week exactli edc', 1),
#  ('today perfect day happi lifecoach reinventimposs', 1),
#  ('14th amend blm discuss thank', 1),
#  ('find fob poster decor room poster falloutboy alltimelow 5so', 1),
#  ('bob marley sang song human youth th day knw coz use smoke weed', 1),
#  ('utterli disgrac parent deal unimagin tragedi internet help', 1),
#  ('back work kinda lazi day routin lazi lazyday friday fun food', 1),
#  ('hope u guy readi request rage callofduti game youtub ragen', 1),
#  ('time tomorrow get see', 1),
#  ('100 amaz health benefit cucumb healthi altwaystoh', 1),
#  ('say got love instagood tbt follow cute photooftheday followm', 1),
#  ('offici unemploy hahahaha great bless graduationday', 1),
#  ('say exclus mix ditch label drop next week', 1),
#  ('lt 3 listen beauti best friend sing amaz voic lt 3 lt 3 lt 3 lt 3 13', 1),
#  ('get fit summer aomagazin de fit model girl hot beauti sexi love cute summer fun',
#   1),
#  ('imagin grown man want hooligan', 1),
#  ('dazzl posit affirm', 1),
#  ('delicioso 6 instamo instafollow instaiqq instaiquiqu love', 1),
#  ('challeng aap claim 70 punjabi drugaddict dare prove', 1),
#  ('cr gmm grammi offici today vedio mv music feelgood like like4lik', 1),
#  ('healthandfit attack bull game 3d realli think head empti around citi', 1),
#  ('r musician horribl w grammar teach grammar music school', 1),
#  ('brook stallion baaaaack welcom stay pleas brill', 1),
#  ('agre sentiment orlando neverpolit bounc wall furiou impot despair worstopost',
#   1),
#  ('sale piec day princ ceram plaqu reg 23 today 18 easel reg 15 today 10 father day',
#   1),
#  ('burlap farm dog fun dog anim cute funni play hay', 1),
#  ('aud usd sell ralli 0 7480 westpac blog silver gold forex', 1),
#  ('love life lucki give thank fact often', 1),
#  ('good night faith ever vaitacacommafiasdv', 1),
#  ('old old fashion love cool perfect nice crazygirl smile card oldschool', 1),
#  ('good way protect account activ 2fa bad doesnt work germani fix', 1),
#  ('mine cider weather', 1),
#  ('im sad lost soccer game penalti kick bad call badref soccer', 1),
#  ('safe flight anak may god protect throughout journey', 1),
#  ('introduct happi day day', 1),
#  ('even orlando notagain', 1),
#  ('haileysporn na sexi shi porn horni nasti naughti slut hot xxx nude wet kinki young',
#   1),
#  ('week rehears sinkthepinkfreakshow final', 1),
#  ('special train offic stop two angri dog without violenc video', 1),
#  ('stay grandma help surgeri 2day crazi plu without internet', 1),
#  ('rosi redfield next mgcb', 1),
#  ('woohoo hotel book brew amp bbq littl excit tri amaz menu', 1),
#  ('readi school firstday collegelif', 1),
#  ('queue', 1),
#  ('life simpl happi laugh sad smile alway', 1),
#  ('zealou posit affirm', 1),
#  ('one day 26 11 3 day us made terrorist attack india three day imagin ind',
#   1),
#  ('bihday licor caf', 1),
#  ('thank memori bungi think done destinythegam riseofiron x360 make', 1),
#  ('mock citizen immigr work hard earn citizenship wow take benefit freedom mock',
#   1),
#  ('trump alli made remark toward obama cnn carlpaladino', 1),
#  ('amp grate money come increas quantiti multipl sourc continu basi', 1),
#  ('got place done 3 time plu 3 marathon never london goals2017', 1),
#  ('beauti cornwal timeaway peac countrysid timetothink calm water green', 1),
#  ('despit setback shape good month anticip', 1),
#  ('bird look cool hell ax kid draw 6 year young', 1),
#  ('black folk becom enemi oppressor wonder chimurenga woh', 1),
#  ('enjoy sunday relax mallif coffe sundayfun relax', 1),
#  ('sound like hate 1st amend thinskin crybabi', 1),
#  ('thando thabeth bae bdae mem', 1),
#  ('madashel join', 1),
#  ('father day frnd', 1),
#  ('take long', 1),
#  ('trump media normal kkk alternet', 1),
#  ('play karen mari garrett daydream melancholi melancholymus', 1),
#  ('van jone tri walk back white lash remark trump suppoer tcot', 1),
#  ('goodmorn sunday like4lik likeforlik happi morn selfi trytobebett', 1),
#  ('2016 06 11 today desneysea friend sunni tire', 1),
#  ('one like option someon els clear sore euro2016 spain smile', 1),
#  ('enjoy russian rock music clean kitchen make popcorn lemonad ye 2 00am est',
#   1),
#  ('elect difficult gop consid po dem dem consid po dem face deni', 1),
#  ('today sta thought lot posit think plan today', 1),
#  ('fine william non relev', 1),
#  ('head gulliv first fenc competit epe welshfenc', 1),
#  ('via goodenough healthi holist yoga gestalt therapi', 1),
#  ('happi anniversari crisa', 1),
#  ('also leav man card', 1),
#  ('know regist amp could meet sultan beingsultan', 1),
#  ('want holi wholli commit god result greg lauri', 1),
#  ('n healthi flower everywher bother look henri matiss', 1),
#  ('mmmmm understand corn icecream edm edc beat club dj djlife waitfohedrop',
#   1),
#  ('feel see wife pass home 50 yr', 1),
#  ('super fun day set lovethiscrew evokeproduct servin old school photooftheday fun',
#   1),
#  ('love happi hour amaz cocktail brixton love', 1),
#  ('gt bihday special day say bihday us great price', 1),
#  ('sta day right happi optim posit posit love', 1),
#  ('listen fbi director seem though get talk point obama', 1),
#  ('see gay lesbian tran murder see human bee slay other human orlandoflorida',
#   1),
#  ('awesom weather awesom journey world heritag kalka shimla toy train feel life famili',
#   1),
#  ('sparkl posit affirm', 1),
#  ('spec belong us babi smile magpi glass', 1),
#  ('sad lovewin fightback orlando fuckhat', 1),
#  ('al fin viern meesperaunplanazo ganasdeviern ganasdeti friday modoon', 1),
#  ('wake smile tell today day tuesday felizma flower flower spring g', 1),
#  ('eat healthi live healthi everyday fixwhatsbrokenin5word eathealthi live healthi bodi mind soul spirit',
#   1),
#  ('5 quick fix improv mental health tip life', 1),
#  ('good luck champ cheer alway', 1),
#  ('got meet wait hear sing great way sta weekend music', 1),
#  ('thank santa best christma present ever cdnpoli abpoli yyc yeg canada ottawa',
#   1),
#  ('happi anyon 15 littl choic make', 1),
#  ('flower raini day london britain weather flower vibe', 1),
#  ('racism us amp netanyahu commit genocid explain bbcnew msnbc npr cnn wsj huffpostpol nyt wapo',
#   1),
#  ('amp 039 movi play weekend lancast counti lancasteronlin', 1),
#  ('happi father day great dad nascar year happi father day dale earnhar', 1),
#  ('ty gt midweek', 1),
#  ('happi day', 1),
#  ('see video 2013 allig sight walt disney world coronado spring reso grandfloridian gator orlando',
#   1),
#  ('bluntli tweet cologn polic announc racial profil main station wow', 1),
#  ('life make let make motiv', 1),
#  ('spectrump king led unveal brightest led world led cannabisgrow', 1),
#  ('let go ok', 1),
#  ('repres boingo mediaplatform hitecnola next week monetizewifi wifi hitec digit',
#   1),
#  ('charm posit affirm', 1),
#  ('much', 1),
#  ('day 44 final get meet ms yee morn even though', 1),
#  ('babi strawberri texasstrawberriesarebigg', 1),
#  ('grow dino size cave cricket amp wolf spider tho 9 hu7i', 1),
#  ('sunday morn classic play clubhous love smell coffe member sunday fathersday',
#   1),
#  ('tuesday how go dead flipflip rip cb radio', 1),
#  ('special deliveri go p7 tomorrow graduationbal farewellclassof2016 ticket',
#   1),
#  ('best gift god ever bless grate bless inlov grate', 1),
#  ('sex video sexi ladi fuck hard pic', 1),
#  ('think old friend unfoun circumst today send love good wish hope futur', 1),
#  ('genuin posit affirm', 1),
#  ('suck singl loyal faithful girl get hu singl', 1),
#  ('pick overwatch pc battlenet id chillmast 11180', 1),
#  ('yet make see tuesday headedtoe3', 1),
#  ('sad dukhi shairi urdu shairi love poetri gazal nice poetri daili free poetri dosti msg plz 1 tri follow snd 40404',
#   1),
#  ('saibaba day devote om sairam', 1),
#  ('us gun law', 1),
#  ('monent soldier famili countri', 1),
#  ('alreadi hit trail tomorrow nbjc jeeplif jeepmafia jeepnat jeepgirl', 1),
#  ('crazi hdrfusion dope lose game gt', 1),
#  ('tell old stori friend bring back good bad memori warstori stilldead', 1),
#  ('trainhard polar bear climb race angri polar bear climb race polar bear live cold place lo',
#   1),
#  ('kudo compliant itaxnirahisi proud taxpay', 1),
#  ('father day one', 1),
#  ('ceainli 1a tip point countri', 1),
#  ('wit 8 year old grandmoth tear huful word', 1),
#  ('wine wed wine cellar vineyard famili heritag wed drink hunter', 1),
#  ('jb3 mama role r u im ss1 im u see kettl smile sun jb3 know u amp sad shahada amp fri',
#   1),
#  ('saturday pay hawaii collar drink pay saturday sunnyday friend luv gf', 1),
#  ('everi man want order need first understand happi', 1),
#  ('sinc 1965 vote right act dem blame republican 4 biggot new buzz word racist',
#   1),
#  ('fashiondiari bull domin bull direct whatev want wh', 1),
#  ('want photo smile live model babesinabathtub lamod', 1),
#  ('bg amp e2 ubie3', 1),
#  ('daddi girl father day', 1),
#  ('takeaway order', 1),
#  ('obama amp hillari divid america arrest made burn black church black suspect arrest',
#   1),
#  ('omg sad dead understand shit fli away angel rest peac idol ripchristina',
#   1),
#  ('michel obama ape heel case begin donaldtrump america', 1),
#  ('shock loss great talent hea break usa', 1),
#  ('punjab green revolut drug revolut couesi akali congress udtapunjab', 1),
#  ('starv love right see love one heaven', 1),
#  ('p e n today 7 30am 4 30pm longweekend', 1),
#  ('ala life isnt easi press comput key', 1),
#  ('fave girl london unit kingdom', 1),
#  ('use power mind heal bodi altwaystoh healthi peac', 1),
#  ('beauti work congrat debut ep possibl teamtutti lovealwayswin', 1),
#  ('thank love follow glad share fight depress keefight', 1),
#  ('eight day week love beachwed love life beatl boatard umasemana', 1),
#  ('1 biggest dream came true today detail come tonight', 1),
#  ('watch snaptravel stori make hope fun barcelona', 1),
#  ('say offend insult yet tri back like victim white privileg', 1),
#  ('time yesaward winner announc', 1),
#  ('state 96 black sinc 2008 growth win debat either', 1),
#  ('week 7 tiu tiuteam bikiniseri letsdothi summer2016 exercis toningup', 1),
#  ('find place', 1),
#  ('order penni lane maxi kittenish line bc summer50 sale 2 good 2 pass ship q',
#   1),
#  ('long live king mad draw aist mad depress pencil', 1),
#  ('ur tryna lighthea amp ur cowrker watch detail documentari breakrm tx execut firstworldproblem',
#   1),
#  ('big pictur', 1),
#  ('holiday plan januari 3 week book work beachhut travel', 1),
#  ('love follow entrepreneur learn filmmak craft', 1),
#  ('bihday ball game redsox boston bihday', 1),
#  ('got illuminatebyashley mail wait use', 1),
#  ('good morn jiyodils rj kaik morn piyusha', 1),
#  ('go sta move thing new room monday better sta pack dreamroom freshsta springclean',
#   1),
#  ('see 100 america', 1),
#  ('road first festiv year bksfestiv letthepaybegin', 1),
#  ('fathersday open 1 7p delici special amp complimentari cocktail dad', 1),
#  ('n healthi never want impos limit work genuin love tom hiddleston ff twhiddlesto',
#   1),
#  ('miss small human noth good without u girli snug', 1),
#  ('home cook ya boy fit gym thejurney healthi wealthi wholefood', 1),
#  ('alt right promot new kind genet mt', 1),
#  ('current mood tea currentmood wetweekend sunday travel teajenni adventur',
#   1),
#  ('anoth contend join tournament pl allianc join us congrat counterstrkeglobaloffensivetourna',
#   1),
#  ('true motiv drinklifein lifestyl freedom makeadiffer', 1),
#  ('friday crack follow', 1),
#  ('happi friday selfi', 1),
#  ('messag thegreatest life fallen deaf ear louisvil violenc return week peac',
#   1),
#  ('brought aluminum equip collisionrepair aimesdoesitbest', 1),
#  ('fallout shelter head pc juli fallout 4 get new dlc via', 1),
#  ('like stat point meaningless life 57 second day bout 5 7 hour loser', 1),
#  ('go', 1),
#  ('mani toy adv show narrow limit genderstereotyp studi warn via', 1),
#  ('book see secret life pet 18 june cineworld', 1),
#  ('figur pregnant probabl one loneliest time life pregnancyproblem', 1),
#  ('wtf pretti sure ca result 100 precinct count big win hillari delusion', 1),
#  ('one love one love reason need love paulo coelho love', 1),
#  ('yeah haaaappppyyyyyy', 1),
#  ('man bad supercut worst msnbc 2016 trumptrain trump2016 wdshow maga fakenew htt',
#   1),
#  ('lawofattract heal altwaystoh healthi', 1),
#  ('place', 1),
#  ('ericfriday compar polit career humanlif depict vote democrat2016 saniti',
#   1),
#  ('congrat well done ricohopen', 1),
#  ('lawsuit alleg versac store', 1),
#  ('happi take risk happi risk chang life itg wisdom', 1),
#  ('hispan amp feel like stomp listen retweet boricua', 1),
#  ('wish time spend w gf damn job keep get way fml time', 1),
#  ('someon sta tomorrow', 1),
#  ('visit gorilla simul need adapt environ need tear citi materi', 1),
#  ('cowork alreadi book flight hotel upcom trip ric', 1),
#  ('good user', 1),
#  ('first pic took look bomb asf think take idigittho', 1),
#  ('specul sentiment index 09 06 2016 blog silver gold forex', 1),
#  ('en rout alton tower altontow sun sunni', 1),
#  ('patienc caer victim crisi actor blog silver gold forex', 1),
#  ('udta punjab film circul faster hostel drug punjab', 1),
#  ('happi babi nephew laugh', 1),
#  ('even weak abl fight zionist technolog etc use jsil amp hatr', 1),
#  ('regrann put togeth', 1),
#  ('made aviari gelato grinata shaveic foodi rayban sunglass summer cool cherri icecream',
#   1),
#  ('pougal consum price index mom dip previou 0 4 0 3 may blog silver gold forex',
#   1),
#  ('urdu poetri beuti poetri poetri 2 line poetri eid new poetri tanhai poetri follow send 40404',
#   1),
#  ('new song summermood', 1),
#  ('70 minut left', 1),
#  ('love trust wrong none friend work', 1),
#  ('music attack bull chase leav lot despit fact strong sourc fo', 1),
#  ('juststandup free justshar tsmilewithouty stand', 1),
#  ('friskyfriday sexi peopl hotwif milf sexylatina bbg rwsw', 1),
#  ('warwickfilmshow raw 1251am 10m tune', 1),
#  ('brilliant conc band make audienc happi music summer', 1),
#  ('use power mind heal bodi altwaystoh healthi', 1),
#  ('love new rod', 1),
#  ('bird flew thank european cooper brexit would sad loss gb amp finland', 1),
#  ('happi bihday babygirl lilli 7 year alreadi whoop whoop bihday girl', 1),
#  ('gettin keep go thankyoujesuschrist music teacher', 1),
#  ('lincoln amp avanleigh spend fathersday wkend beach grammaw littl beachbum grandkid famili',
#   1),
#  ('town whiteland fight nativ american school mascot notyourmascot whiteprivileg via',
#   1),
#  ('racialprejudic real exist across countri sinc begin time amp need priori',
#   1),
#  ('cool guess probabl show phone', 1),
#  ('fresh haircut selfi', 1),
#  ('best accident photo like4lik follow follow4follow blackandwhit instalik bu',
#   1),
#  ('mood goe sad time miss someon', 1),
#  ('goodnight click ramadan kareem sehri', 1),
#  ('need make one tho', 1),
#  ('news repo tonight instead day 5 trump racist campaign maga obviou', 1),
#  ('amp ate wasabi met 6 best peopl ever happi 33rd bday luke', 1),
#  ('right like presid obama go take everyon gun getsomefact', 1),
#  ('thread outlin evolut alt right movement via russia focus one member', 1),
#  ('night mood mymauritiu magic everi minut luxurytravel', 1),
#  ('wait till impeach traitor deserv jail mani thing impeachtrump traitor', 1),
#  ('got new box glove today tri gym soon workingout', 1),
#  ('ase bull domin bull direct whatev want', 1),
#  ('via', 1),
#  ('beat monday blue moethennessi mondayblu work win sta drink wine white', 1),
#  ('nigga would fck boy hit pussi', 1),
#  ('star gorilla simul need adapt environ need tear citi materi', 1),
#  ('bad wish mari glassfetish', 1),
#  ('inde cultur person celebr trump substanc', 1),
#  ('stop train make cri everi time listen lyric tru', 1),
#  ('wanna travel actual money nobodi want go nyc foreveralon', 1),
#  ('eat make koreanfood mypass', 1),
#  ('3 sleep capitalstb', 1),
#  ('help left caus feel sick suppos get help hour ago', 1),
#  ('first today bifold fit watford custom', 1),
#  ('awesom dynamicduo miss chri positivevib great time love bridg', 1),
#  ('decid happi percept mind life flow focu goe life', 1),
#  ('good morn nice weekend day weekend likem sun likeforlik', 1),
#  ('impress order late sunday came today engrav perfect amp cuss gift tag', 1),
#  ('memori day deep', 1),
#  ('happi uh friend fulfil ur wish thnkuh sweethea ht', 1),
#  ('time sweet friend kaceepopa beauti', 1),
#  ('neg peopl caus neg atmospher life sho satisfi surround posit happi lifego',
#   1),
#  ('thank thank posit', 1),
#  ('besti gorilla simul need adapt environ need tear citi materia', 1),
#  ('look bathroom mirror say donald trump three time hair drain rise sta yell',
#   1),
#  ('black amp feel like stomp retweet tampa miami', 1),
#  ('tyler perri claim revers racism critic tlc seri tyler perri claim revers critic',
#   1),
#  ('allahsoil major violenc involv quest oil emirati', 1),
#  ('look forward meet babi boy 12 hour', 1),
#  ('pivot moment life unawar damn frog made till', 1),
#  ('heard fitcity2016 day ago pop everywher great talk healthi citi today', 1),
#  ('turkey land owner money benefit propey profit invest torism love compani develop sea human',
#   1),
#  ('sex blond bj nake', 1),
#  ('check new trend funni gif kim kardashian cri', 1),
#  ('launch anim adopt today strawberri fayr', 1),
#  ('workspac matter well workplacedesign staff matter health issu staff product',
#   1),
#  ('best homeopath remedi anxieti altwaystoh heal peac', 1),
#  ('urg eci conven pay meet udtapunjab issu', 1),
#  ('find sad celebr huge fandom member lgbt commun havent comment shoot', 1),
#  ('gent want make take vehicl local napaautocar center', 1),
#  ('area man hate blame twitter user notic po', 1),
#  ('blue day drown sorrow icecream blue creami icecream hnt', 1),
#  ('yellow bone girl porn hardcor track', 1),
#  ('tweet sheet keep go korea tour amp slaughter wors yulin korea kill amp tour daili',
#   1),
#  ('assum muslim refuge kick women stair', 1),
#  ('wait vodka gummybear', 1),
#  ('peopl talk 50 gay men kill 50 peopl kill', 1),
#  ('wahhhh white ppl arent allow fuck rich care', 1),
#  ('product weekend hard work pay selfi girl smile hardwork', 1),
#  ('cool feel good univers agre 100 alway felt colleg', 1),
#  ('brother sister take note everyon quick listen slow speak slow becom jame 1 19',
#   1),
#  ('brilliant posit affirm', 1),
#  ('thank kiss thank posit', 1),
#  ('serious wrong stoptheviol 16 yr old kill vigil victim', 1),
#  ('fusionmad miss omg motiv', 1),
#  ('side guy without home', 1),
#  ('saw dean ambros money bank ladder match cash wow wow wwe stun shock', 1),
#  ('trump said understand anyth presid said trump admit stupid dumbest ever dumbasstrump',
#   1),
#  ('ripantonyelchin die car accid 27 believ likecrazi', 1),
#  ('disgust realli hope know piec crap sodon', 1),
#  ('shame watch 24h le man tv amp annoy', 1),
#  ('ationalbedfriendsday jump', 1),
#  ('happi sunday sunday workout leed weightloss weightlosstrain theedg', 1),
#  ('lot ing throw decid take plung purchas bumbag today hol retro', 1),
#  ('good morn hope great day pic girl photo instagram', 1),
#  ('get wors much wors shoot small scale wait much bigger attack kill thousand',
#   1),
#  ('happi filanfriday hope like shanefilan myedit smile like love', 1),
#  ('sydney usa root john scott wear canadian jersey', 1),
#  ('want', 1),
#  ('bday amp tupac rapflashback gemini hiphop og tbt legend june16', 1),
#  ('devi hippo calf photo sandiegozoo dream love hope health peac amp', 1),
#  ('belgium boatpay pay paytim londonescap wear asiafashion', 1),
#  ('day orlando', 1),
#  ('thank packag anybodi need anyth design amp print recommend', 1),
#  ('experiment track produc morn edm dnb trap tune fastcor', 1),
#  ('big warm shoulder cri father day', 1),
#  ('friday weekend work fast bca', 1),
#  ('warren zevon keep hea via watch docu make album thewind', 1),
#  ('terribl tragedi r p christinagrimmi world scari place heabroken', 1),
#  ('damn realli made tear littl mustread', 1),
#  ('never get busi make live forget make life thailand come home', 1),
#  ('back low cut grayhair dontcar friday yeahhh', 1),
#  ('first time take bu work new hous let see goe', 1),
#  ('sad day racist question whether candid racist live multiraci countri', 1),
#  ('disneygatorattack happen previou disney allig attack victim messag boy famili',
#   1),
#  ('gino play blue guitar', 1),
#  ('yummi apbtapizaco firstanniversari apbt', 1),
#  ('back let sta twit', 1),
#  ('ghost adventur time fo macahur nichol xx', 1),
#  ('eeek week today pick furbabi', 1),
#  ('ty join blendedlearn convers valleymm', 1),
#  ('work sunshin happi summerfeel love best summer work break', 1),
#  ('wow trump crowd half size berni turn hillari suppoer crowd', 1),
#  ('sweet stuff shown e3 year everyon look forward videogam vr', 1),
#  ('listen metorit reviv definit pianohand tonight sevenyearsofpodcast', 1),
#  ('mani tool function', 1),
#  ('rememb happi felic felicit aldil ditutto behappi rememb ricorda', 1),
#  ('win facebook meatfeast competit amp wait till next tuesday meat wine', 1),
#  ('sexless season love scene impoant see disappoint puzzl outland', 1),
#  ('bracebridg huntsvil look hous unsur happi willmisseveryon notlikeisrranyofmyfriendsanyway theirlif busi',
#   1),
#  ('hey wait get cheddar biscuit chang someth', 1),
#  ('agre everyon deserv use', 1),
#  ('could make almost 100 000 year tennesse yeah honey stay forev west virginia know',
#   1),
#  ('heather block real gem hand', 1),
#  ('lead ignor lovetrumpsh janeelliot', 1),
#  ('wohoooo staup weekend sibu staup weekend miri come q3 yall mega staup sarawak end year',
#   1),
#  ('thank food thank posit', 1),
#  ('unemploy ye 30 still use twitter tri argu teen pathet tryagain', 1),
#  ('sure meickenhorst know inspir', 1),
#  ('posit keep travel gtc mydubai dubai love smile care travel tourism abudhabi uae trip',
#   1),
#  ('heali osborn ohelptobuy scheme renam help bonus outrag shock', 1),
#  ('crack corn 8 5x11 bic pen outcast ink sketchbook sketchi sketch fear scar',
#   1),
#  ('2 week 2 day till see babe countdown iwannagonow', 1),
#  ('yep let googl hit butt way mustend', 1),
#  ('readi e32016', 1),
#  ('real friday chuckaboo picoftheday loveit day enjoy tgif danc', 1),
#  ('nationalbestfriendday marri mine bff husband love joy marriag', 1),
#  ('celebr dad today fathersday menu', 1),
#  ('hello friday fit fitfam ab health model fashion blogger', 1),
#  ('marathon gorilla simul need adapt environ need tear citi materi', 1),
#  ('wow colga u guy shoot guy headshot basketbal cou real smh doubl church smdh',
#   1),
#  ('fit fit better tip vegatopian eathealthi', 1),
#  ('friyay everyon deserv via showusthosepearlywhit', 1),
#  ('see facebookmemori remind even life pretti shit turn around amp amaz goodjob amazingboy',
#   1),
#  ('bihday bro', 1),
#  ('affluent amp million like way focu one word smh', 1),
#  ('alway run banana nut muffin', 1),
#  ('alreadi feel anoth hit', 1),
#  ('', 1),
#  ('music ban iraivi movi', 1),
#  ('happi happi lyric', 1),
#  ('gracia messi alon', 1),
#  ('elli ate 3 stalk asparagu child dream luckymom', 1),
#  ('bihday sexi girl adult hentai', 1),
#  ('found child bodi still intact hope bring closur famili', 1),
#  ('noth els get selfi lol random selfi snapchat', 1),
#  ('got haircut good day wear oakley selfi smile bore hair', 1),
#  ('sad may rest peac', 1),
#  ('see later', 1),
#  ('tyler kid 2001 annoy grew love engag inlov', 1),
#  ('poor vote gop gun religion ignor aboion fear', 1),
#  ('epic pay bihday thankyou amaz fun pay', 1),
#  ('got real firestone600 firsttimesponsor', 1),
#  ('happi day night', 1),
#  ('imagem via hea amaz food look smile', 1),
#  ('hindusena celebr messiha bihday delhi messiha talk kick indian america', 1),
#  ('canadian inconceiv easili buy assault rifl us terribl tragedi gunlaw orlandoshoot',
#   1),
#  ('greatest teacher uncondit love 2 teach 4 room amp board pet', 1),
#  ('atherapi musictherapi heal life altwaystoh healthi heal', 1),
#  ('feel music imback black guitar guy feel play till die', 1),
#  ('congratul amaz parent 35 year togeth anniversari mom dad', 1),
#  ('way hide behind broad statement folk know wrong gener', 1),
#  ('last two day norway see iaraheid move movingabroad backtoitali', 1),
#  ('know tweet harsh time give credit due say peopl afraid musicro', 1),
#  ('head london day academi addit danburi essex x', 1),
#  ('happi father day fathersday bestdaddi sunnyday smile flawless beach ocean',
#   1),
#  ('boy download 2016 dl2016 daddysonday', 1),
#  ('great day w seed scholar top come home 2 amaz neighbor surpris us kind gestur bless',
#   1),
#  ('watch us open dad miss pop fathersday love usopen first year without', 1),
#  ('sta rust offici seri half way go sta singl player game seri hype', 1),
#  ('nobdi want 2 kiss lie conaist homophob islamaphob russianhack nom', 1),
#  ('launch go well mani reader avail take l k might realli appeal', 1),
#  ('weather sydney next week bad bad sydney2016', 1),
#  ('yey new motorbik way issu park anymor stuff traffic warden yamaha', 1),
#  ('cheer argentina regard malvina messi deserv', 1),
#  ('rainbow parad 2016 vienna best open inclus divers livabl lgbtcommun publicspac',
#   1),
#  ('provo get hair cut sinc mom graduat nostalgia', 1),
#  ('1466306434 97 updat social analyt convers instadaili game', 1),
#  ('term leg room one less space think right nothappi', 1),
#  ('smile dog dogsarejoy', 1),
#  ('saw hatchl sho birdsmovi reason view film earlier shall', 1),
#  ('famili caus problem relationship pick friend reason horrif life', 1),
#  ('control love amp hip hop gangster rap music', 1),
#  ('believ brother love island notif phone loveisland', 1),
#  ('check enjoy ukulel royalti free music victoryaudio audiojungl ukulel music',
#   1),
#  ('babi kidkus driveway safeti net 30 feet bouncingbabi', 1),
#  ('let get lost find steadi', 1),
#  ('final see pictur orlando shooter realiz went high school togeth prayfororlando',
#   1),
#  ('know one squirrel mate nowher found mother natur bitch night', 1),
#  ('touch gestur watcho wwdc16', 1),
#  ('pleas like amp share agre dna dnaquot quot quoteoftheday love proverb lifestyl',
#   1),
#  ('thank show even watch catchup joke sky ruin', 1),
#  ('treat beaut sunflow make saturdayvib', 1),
#  ('allahsoil temptat blame everyth scapegoat strong resist', 1),
#  ('mother beep great day instagram posit fun awesom', 1),
#  ('donald unfavor rate 70', 1),
#  ('lot compani tara stand principl mani sell', 1),
#  ('enjoy holiday hello tokyo taiwan tokyo holiday love narita', 1),
#  ('love meet new s1 today quick learner enjoy walk dictat pa bodi transit', 1),
#  ('newstar bull domin bull direct whatev want', 1),
#  ('wait saturday night go see 2 theconjuring2 regalcinema truestori', 1),
#  ('staff member tell fib transfer number nano sim instead gave new number complaint missold',
#   1),
#  ('father day thalaivaa vijay bdayspl week', 1),
#  ('abrahamhick bring best other via kind kind help help', 1),
#  ('emoji cast vote upgrademehappi tuesdaymotiv', 1),
#  ('saturday morn like livelif love nurseonduti', 1),
#  ('find workout routin get amp problem stick fitfam summergo', 1),
#  ('amaz place alreadi greec holiday', 1),
#  ('arghhhh one weekend stay go holiday ibiza smashingit', 1),
#  ('love abrahamhick lawofattract healthi heal joytrain', 1),
#  ('care alumni reach wayward chapter amp aa amp send phipsigac credenti stat 2 hq',
#   1),
#  ('choos domain name host done main page halfway done personalwebsit', 1),
#  ('canchamp imfc mtlvtor souvenir tamereesttrist stade saputo match de l impact',
#   1),
#  ('lot racialh america provid two lunat suppo perpetu hate dumptrump', 1),
#  ('impress tester drake meme yolo mirrors16 summersixteentour view heswithh sorryday dammittop',
#   1),
#  ('post feel facebook instead pray know god help stress godslov', 1),
#  ('true friend rip dog', 1),
#  ('honestli long hell care lifefact wiz', 1),
#  ('almost time sensat sens show cheltscifest', 1),
#  ('buildabear happi go lucki frog golucki happi', 1),
#  ('finish week posit attitud even fake positivevib happi', 1),
#  ('new toy bake torch firesta bakingtool cremebrule toast', 1),
#  ('readi day takeonepictur london come', 1),
#  ('detoxdiet altwaystoh healthi', 1),
#  ('ok get format beyonc formationworldtour yaasss', 1),
#  ('beautifulsunday', 1),
#  ('sunday sunday sunday sundayfun sundaymood somethingboudoir celebritystyl',
#   1),
#  ('orlando thought affect ghr tragic event', 1),
#  ...]

# %%
count_words_train = X_train.tweet.str.split(expand=True).stack()
count_words_train
count = count_words_train.value_counts()
count
# Out:
# love       2674
# day        2607
# happi      1902
# amp        1596
# get        1146
#            ...
# pch           1
# 8lb           1
# 60mill        1
# 12mill        1
# chisolm       1
# Length: 32853, dtype: int64

# %%
count_words_test = X_test.tweet.str.split(expand=True).stack()
count_words_test
count_test = count_words_test.value_counts()
count_test
# Out:
# love                1490
# day                 1393
# happi               1087
# amp                  866
# get                  636
#                     ...
# beater                 1
# disturb                1
# obamahatesisrael       1
# toois                  1
# shoegaz                1
# Length: 22174, dtype: int64

# %% [markdown]
# From above analysis we found frequancy of words from tweets.

# %%
from nltk.probability import FreqDist
from wordcloud import WordCloud
mostcommon = FreqDist(count_words_train).most_common(100)
wordcloud = WordCloud(width=1600, height=800, background_color='white').generate(str(mostcommon))
fig = plt.figure(figsize=(30,10), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top 100 Most Common Words for Train_Data', fontsize=100)
plt.tight_layout(pad=0)
plt.show()

# %%
mostcommon_small = FreqDist(count_words_train).most_common(25)
x, y = zip(*mostcommon_small)
plt.figure(figsize=(50,30))
plt.margins(0.02)
plt.bar(x, y)
plt.xlabel('Words', fontsize=50)
plt.ylabel('Frequency of Words', fontsize=50)
plt.yticks(fontsize=40)
plt.xticks(rotation=60, fontsize=40)
plt.title('Frequency of 25 Most Common Words for Train_Data', fontsize=60)
plt.show()

# %%
from nltk.probability import FreqDist
from wordcloud import WordCloud
mostcommon = FreqDist(count_words_test).most_common(100)
wordcloud = WordCloud(width=1600, height=800, background_color='white').generate(str(mostcommon))
fig = plt.figure(figsize=(30,10), facecolor='white')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Top 100 Most Common Words for Test_Data', fontsize=100)
plt.tight_layout(pad=0)
plt.show()

# %%
mostcommon_small = FreqDist(count_words_test).most_common(25)
x, y = zip(*mostcommon_small)
plt.figure(figsize=(50,30))
plt.margins(0.02)
plt.bar(x, y)
plt.xlabel('Words', fontsize=50)
plt.ylabel('Frequency of Words', fontsize=50)
plt.yticks(fontsize=40)
plt.xticks(rotation=60, fontsize=40)
plt.title('Frequency of 25 Most Common Words for Test_Data', fontsize=60)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.title('Percentage of Possitive and Negative Tweets', fontsize=20)
X_train.label.value_counts().plot(kind='pie', labels=['Possitive_tweet','Negative_tweet'],
                              wedgeprops=dict(width=.7), autopct='%1.0f%%', startangle= -20,
                              textprops={'fontsize': 15})
# Out:
# <Axes: title={'center': 'Percentage of Possitive and Negative Tweets'}, ylabel='label'>

# %% [markdown]
# ***Featurization Techniques:***

# %% [markdown]
# **Bag of Word Model**

# %% [markdown]
# **TFIDF Technique for Feature Extraction**

# %%
from sklearn.utils import resample
train_major = X_train[X_train.label==0]
train_minor = X_train[X_train.label==1]
#Here we are upsampling the data
train_minor_upsampled = resample(train_minor,replace=True,n_samples=len(train_major),random_state=123)
train_upsampled = pd.concat([train_minor_upsampled, train_major])
#The upsampled data
train_upsampled['label'].value_counts()
# Out:
# 1    26417
# 0    26417
# Name: label, dtype: int64

# %%
plt.figure(figsize=(30,10))
plt.title('Percentage of Possitive and Negative Tweets', fontsize=20)
train_upsampled.label.value_counts().plot(kind='pie', labels=['Possitive_tweet','Negative_tweet'],
                              wedgeprops=dict(width=.7), autopct='%1.0f%%', startangle= -20,
                              textprops={'fontsize': 15})
# Out:
# <Axes: title={'center': 'Percentage of Possitive and Negative Tweets'}, ylabel='label'>
